# %%
import pdfplumber, json
import re
from datetime import datetime
import os

# %%
os.chdir(os.getcwd().split('\\notebooks')[0])
main = os.getcwd()

# %%
data = main + '\\data\\raw\\exams.pdf'

# %%
with pdfplumber.open(data) as pdf, open(main + '\\data\\interim\\exams.json', 'w', encoding='utf-8') as f:
    exams = []
    for page in pdf.pages:
        text = page.extract_text()
        exams.append(text)
    json.dump(exams, f, ensure_ascii=False, indent=4)

# %%
with open(main + '\\data\\interim\\exams.json', 'r', encoding='utf-8') as f:
    exams = json.load(f)

# %%
exams
# Out:
# ['Exam structure\nAbstract\nIn this (cid:133)le we explain how to navigate the collection of previous exams.\n1 How are the exams structured?\nFirst midterm exams October Those are the exams which are administered in\nOctober. They consist of four exercises. Exercises 1 and 2 are about vector spaces.\nExercises 3 and 4 are about metric spaces.\nGeneral exams January/February Exercise 1 is about vector spaces. Exercise 2 is\nabout metric spaces. Exercises 3 and 4 are typically about normed vector spaces and\nBanach contraction principle. Exercise 5 is typically about either convex analysis or\nBlackwell. Exercise 6 is about dynamic programming. In this case, the last 4 exercises\nform the second midterm.\nGeneral exams August/September Exercise 1 is about vector spaces. Exercise 2\nis about metric spaces. Exercises 3 and 4 are typically about normed vector spaces and\nBanach contraction principle. Exercise 5 is typically about either convex analysis or\nBlackwell. Exercise 6 is about dynamic programming.\n1',
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)August 29, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Consider a functional f : R n R. State and prove the Riesz representation theorem\n!\n(that is, the theorem that provides a characterization for linear functionals).\nSolution See the lecture notes. (cid:4)',
#  'Exercise 2 Consider R n endowed with the d 1 distance.1 Consider a nonempty subset C of X. We\nsay that x in an algebraic interior point of C if and only if for each y R n there exists (cid:14) > 0 such\n2\nthat x+(cid:14)y C. We denote the set of all algebraic interior points of C by algC.\n2\n1. Prove that intC algC.\n(cid:18)\n2. Prove that if C is convex and x algC, then x C.\n2 2\n3. Prove that if C is convex, then intC = algC.\nSolution. 1. If intC = , then trivially we have that intC algC. If intC = , consider x intC.\n; (cid:18) 6 ; 2\nIt follows that there exists " > 0 such that B " (x) (cid:18) C. Consider y 2 R n. Set (cid:14) = k y k " 1 +1 > 0. Note\nthat d (x;x+(cid:14)y) = x+(cid:14)y x = (cid:14) y < ", proving that x+(cid:14)y B (x) C. Since x and y\n1 k (cid:0) k1 k k1 2 " (cid:18)\nwere arbitrarily chosen, it follows that x is an algebraic interior point of C whenever it is an interior\npoint of C, proving the point.\n2. Consider x algC and y R n. It follows that there exist (cid:14) + ;(cid:14) > 0 such that x+(cid:14) + y;x+\n2 2 (cid:0)\n(cid:14) ( y) C. Since C is convex, we can conclude that x+((cid:13)(cid:14) +(1 (cid:13))( (cid:14) ))y = (cid:13)(x+(cid:14) y)+\n+ +\n(cid:0) (cid:0) 2 (cid:0) (cid:0) (cid:0)\n(1 (cid:13))(x+(cid:14) ( y)) C for all (cid:13) [0;1]. In other words, x+(cid:14)y C for all (cid:14) [ (cid:14) ;(cid:14) ]. Since\n+\n(cid:0) (cid:0) (cid:0) 2 2 2 2 (cid:0) (cid:0)\n(cid:14) ;(cid:14) > 0, we have that 0 [ (cid:14) ;(cid:14) ], proving that x C.\n+ +\n3. (cid:0) Consider the canon 2 ica (cid:0) l b (cid:0) asis of R n: ei n .2 2 Consider x algC for each i 1;:::;n\ni=1 2 2 f g\nthere exist (cid:14) ;(cid:14) > 0 such that x + (cid:14) ei;x + (cid:14) ei C for all i 1;:::;n . De(cid:133)ne " =\nmin min +;i (cid:0) (cid:14) ;i ;min (cid:14) > + 0 ;i . B (cid:8) yt (cid:9) hep (cid:0) r ;i oo (cid:0) fofpo 2 int2,wehave 2 th f atx+"e g i;x+" ei\ni 1;:::;n +;i i 1;:::;n ;i\n2f g 2f g (cid:0) (cid:0) (cid:1) (cid:0) 2\nC for all i 1;:::;n . Consider y B (x). De(cid:133)ne z = y x. It follows that z = y x =\nd (x (cid:8) ;y) < " 2 . D f e(cid:133)ne (cid:22) g = z =" 0 f 2 or (cid:9) a " ll i 1;:::;n and (cid:22) (cid:0) = 1 n (cid:22) . k Ob k s 1 erve k th (cid:0) a (cid:0) t k1(cid:1)\n1 i j i j (cid:21) 2 f g n+1 (cid:0) i=1 i\nn n P\n" > z = z = " (cid:22) ;\nk k1 j i j i\ni=1 i=1\nX X\nproving that (cid:22) [0;1]. Moreover, we have that n+1(cid:22) = 1. By de(cid:133)nition of (cid:22) n+1, note that\nn+1 2 i=1 i f i gi=1\nn P\ny = x+z = x+ z ei = x+ "(cid:22) ei+ "(cid:22) ei\ni i i\n(cid:0)\nX\ni=1 i:\nX\nzi\n(cid:21)\n0 i:\nX\nzi<0\n(cid:0) (cid:1)\n= (cid:22) x+ (cid:22) x+"ei + (cid:22) x+" ei :\nn+1 i i\n(cid:0)\ni:\nX\nzi\n(cid:21)\n0\n(cid:0) (cid:1)\ni:\nX\nzi<0\n(cid:0) (cid:0) (cid:1)(cid:1)\nSince C is convex and x+(cid:14) ei;x+(cid:14) ei C for all i 1;:::;n , this implies that y is a convex\n+;i ;i\n(cid:0) (cid:0) 2 2 f g\nlinear combination of points which are in C and, in particular, y C. Since y was arbitrarily chosen,\n(cid:0) (cid:1) 2\nwe have that B (x) C, proving that x intC. Since x was arbitrarily chosen, algC intC. By\n"\n(cid:18) 2 (cid:18)\npoint 1, we can conclude that algC = intC. (cid:4)\nk x k2 1 1 G R = e iv c e a n ll n i i = th 1 a j x t 1 i d j ; 1 : f : o ( :; r x n ; a y ll , ) r x = ec 2 a P l R l n i n t = h . 1 a j t y i ei (cid:0) is x t i j he fo v r e a c l t l or x; in y R 2 n R s n u . ch R t e h c a a t ll it a s ls j o -t t h ha co t m d 1 po is ne i n n t du is ce 1 d (r b e y sp t . h 0 e ) n i o f r j m = k i k ( 1 re d sp e(cid:133) . n j e = d b i) y .\nP 2f g 6',
#  'Exercise 3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\nSolution See the lecture notes. (cid:4)',
#  'Exercise 4 Consider R n endowed with the supnorm .3 We say that an operator f : R n R n is\nk k !\nmonotone if and only if 1\nx y = f(x) f(y):4\n(cid:21) ) (cid:21)\nConsider two operators f;g : R n R n and assume they are both (cid:11)-contractions with (cid:11) (0;1).\n! 2\nDenote their unique (cid:133)xed points by x and x .\nf g\n1. Prove that if f g and f is monotone,5 then x x .\nf g\n(cid:21) (cid:21)\n2. Prove that if g = 1I + 1f,6 then x = x .\n2 2 f g\nSolution 1. By the Banach contraction principle and since (R n; ) is a complete metric space and\nk k\nf and g are (cid:11)-contractions, recall that 1\nlimfn(y) = x f and limgn(y) = x g y R n: (1)\nn n 8 2\nFix x R n. By induction, we will show that fn(x) gn(x) for all n N. Since f g, the inequality\n2 (cid:21) 2 (cid:21)\nfollows for n = 1, proving the initial step. Next assume the statement is true for n. We show it is\ntrue for n+1. Observe that fn+1(x) = f(fn(x)) f(gn(x)) g(gn(x)) = gn+1(x), proving the\n(cid:21) (cid:21)\ninductive step. By induction, the statement follows. By passing to the limit and (1), we can conclude\nthat\nx = limfn(x) limgn(x) = x ;\nf g\nn (cid:21) n\nproving the point.\n2. By the Banach contraction principle, observe that f and g admit each a unique (cid:133)xed point.\nNext, since x is a (cid:133)xed point of f, observe that\nf\n1 1 1 1\ng(x ) = I(x )+ f(x ) = x + x = x ;\nf f f f f f\n2 2 2 2\nproving that x is a (cid:133)xed point of g. Since the only (cid:133)xed point of g is x , we can conclude that\nf g\nx g = x f , proving the point. (cid:4)\n3 4 R R e e c c a a l l l l t t h h a a t t k x x k1y = if a m n a d x i o2nfl 1 y ;:: i : f ;n xgj x i j y fo f r o a r l a l l x l i 2 R n 1 . ;:::;n .\ni i\n5Recall that f (cid:21) g means that f(x) (cid:21) g(x) for a 2 ll f x R n. g\n6Recall that th (cid:21) e identity operator I i (cid:21) s such that I(x) 2 =x for all x R n.\n2',
#  'Exercise 5 Consider a metric space (X;d) and a continuous function f : X R. Assume C is a\n!\nclosed and bounded subset of X. Is it always true that f admits a maximizer on C, that is,\nmaxf(x) subject to x C\n2\nadmits solution?\nSolution No! ConsiderX = Nendowedwiththediscretedistanced(cid:22).7 SetC = N. Considerf : N R\n!\nde(cid:133)ned by f(n) = n for all n N. Note that:\n2\n1. Since in any metric space X is open and closed, so is C = X.\n2. Since d = d(cid:22), we have that B 2 (1) = n N : d(cid:22)(1;n) < 2 = N = C, proving that C is bounded.\n2\nd(cid:22) (cid:8) (cid:9)\n3. Recall that x n x if and only if there exists n(cid:22) N such that x n = x for all n n(cid:22) (cf. Exercise\n! 2 (cid:21)\n4, October 2014 and 2013). Indeed, we have that\nx n\nd(cid:22)\nx " > 0; n " N s.t. d(cid:22)(x n ;x) < " n n " = n 1=2 N s.t. d(cid:22)(x n ;x) < 1=2 n n 1=2\n! () 8 9 2 8 (cid:21) ) 9 2 8 (cid:21)\n= n 1=2 N s.t. d(cid:22)(x n ;x) = 0 n n 1=2 = x n = x n n 1=2 :\n) 9 2 8 (cid:21) ) 8 (cid:21)\nViceversa, we have that\nn(cid:22) N s.t. x n = x n n(cid:22) = " > 0; n " = n(cid:22) N s.t. d(cid:22)(x n ;x) = 0 < " n n " = x n\nd(cid:22)\nx:\n9 2 8 (cid:21) ) 8 9 2 8 (cid:21) ) !\n4. By point 3, we have that\nd(cid:22)\nx n x n(cid:22) N s.t. x n = x n n(cid:22) = n(cid:22) N s.t. f(x n ) = f(x) n n(cid:22) = f(x n ) f(x);\n! () 9 2 8 (cid:21) ) 9 2 8 (cid:21) ) !\nproving continuity of f.\nThus, our choice of X, d, C, and f (cid:133)ts the requirements above. Yet, f does not admit a maximizer\non C. By contradiction, assume that n(cid:22) C = N is a maximizer, that is, f(n(cid:22)) f(n) for all\n2 (cid:21)\nn C = N. Consider n^ = n(cid:22) +1. We have that f(n^) = f(n(cid:22)+1) = n(cid:22) +1 > n(cid:22) = f(n(cid:22)) f(n^), a\n2 (cid:21)\ncontradiction. (cid:4)\n7Recall that d(cid:22)(x;y)=1 if and only if x=y and d(cid:22)(x;y)=0 if and only if x=y.\n6',
#  'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.\nSolution See the lecture notes. (cid:4)',
#  'EXTRA PAGE',
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 27, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let S be a nonempty subset of a vector space V.\n1. De(cid:133)ne spanS.\n2. Fix n\n2\nN. If S =\nf\nx\ni g\nn\ni=1\n, show that\nn\nspanS = x 2 V : 9f (cid:11) i g n i=1 (cid:18) R s.t. x = (cid:11) i x i :\n( )\ni=1\nX\nSolution See the lecture notes. (cid:4)',
#  'Exercise 2 Let (X;d) be a metric space and D a subsetof X such that cl(D) = X.1 Prove that if\nA X is closed and such that cl(intA) = A, then cl(A D) = A.\n(cid:18) \\\nSolution. Since cl(intA) = A, A is empty if and only if intA is empty. If A is empty, trivially, we\nhave that cl(A D) = cl( ) = = A. If A is not empty, we have that intA = . Fix x intA. Since\n\\ ; ; 6 ; 2\ncl(D) = X, there exists a sequence x D such that x x. Since x intA and the latter\nf n gn N (cid:18) n ! 2\nis open, this implies that there exists " >20 such that B (x) intA and, in particular, there exists\n"\n(cid:18)\nn " N such that x n B " (x) intA for all n n " . We can conclude that x cl(intA D). Since x\n2 2 (cid:18) (cid:21) 2 \\\nwas arbitrarily chosen, we have that\nintA cl(intA D) = A = cl(intA) cl(intA D) cl(A D) cl(A) = A;\n(cid:18) \\ ) (cid:18) \\ (cid:18) \\ (cid:18)\nproving the statement. (cid:4)\n1Inthisexercise,givenasubsetB ofX,bycl(B),wemeantheclosureofB,whichisalsodenotedasB(cid:22) inthelecture\nnotes.',
#  'Exercise 3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\nSolution See the lecture notes. (cid:4)',
#  'Exercise 4 Consider the space of real-valued bounded sequences, denoted ‘ , endowed with the sup-\n1\nnorm ,2 that is,\nk k\n1\n‘\n1\n= x RN : sup x\nn\n< :\n2 j j 1\n(cid:26) n N (cid:27)\n2\nLet T : ‘ ‘ be such that for each x ‘ we de(cid:133)ne ax = T (x) to be such that\n1 1 1\n! 2\nx +:::+x\nax\nn\n= 1\nn\nn\n8\nn\n2\nN: (1)\n1. Compute the operator norm of T. Motivate your answer!\n2. Is T a contraction? Motivate your answer!\nSolution 1. Fix x ‘ . Observe that\n1\n2\nn n\nx +:::+x 1 1\nj\nax\nn j\n= 1\nn\nn\n(cid:20) n j\nx\ni j (cid:20) n k\nx\nk\n=\nk\nx\nk 8\nn\n2\nN;\n(cid:12) (cid:12) i=1 i=1 1 1\n(cid:12) (cid:12) X X\n(cid:12) (cid:12)\nproving that sup ax(cid:12) x . By(cid:12)de(cid:133)nition of T and since x was arbitrarily chosen, it follows that\nn 2 Nj n j (cid:20) k k 1\nT (x) = sup ax x x ‘ :\nn 1\nk k j j (cid:20) k k 8 2\n1 n N 1\n2\nBy de(cid:133)nition of operator norm, we have that T 1. Next, consider the sequence e ‘ such that\n1\nk k (cid:20) 2\ne\nn\n= 1 for all n N. It follows that (cid:3)\n2\ne +:::+e\nae\nn\n= 1\nn\nn = 1\n8\nn\n2\nN;\nyieldingthatae = eand,inparticular, T (e) = ae = e . Bythecharacterizationofoperator\nk k k k k k\nnorm and since e = sup e = 1, we ha1ve that 1 1\nk k 1 n 2 Nj n j\nT = sup T (x) T (e) = 1:\nk k k k (cid:21) k k\n(cid:3) x ‘ : x =1 1 1\n2 1k k1\nWe can conclude that T = 1 (cf. Exercise 4, January 9th, 2023).\nk k\n(cid:3)\n2. No! Since T is linear, to be a contraction T needs to be such that T < 1, which is not the\nk k\ncase. Alternatively, you can check that it has more than one (cid:133)xed point, for ex(cid:3)ample, e and 0. (cid:4)\n2Recall that\nk\nx\nk1\n=sup\nn 2 Nj\nx\nn j\nfor all x\n2\n‘1.',
#  'Exercise 5 Consider a normed vector space X with norm and a nonempty closed subset C of X.\nk k\nDe(cid:133)ne f : X [0; ) by\n! 1\nf(x) = inf x y x X:\ny Ck (cid:0) k 8 2\n2\nProve that f is convex if and only if C is convex.\nSolution (cid:147)If(cid:148). Consider x\n0\n;x\n1\nX and (cid:21) (0;1). Consider n N. By de(cid:133)nition of inf and f, we\n2 2 2\nhave that there exist y ;y C such that\n0 1\n2\n1 1\nf(x ) = inf x y x y and f(x ) = inf x y x y :\n0 0 0 0 1 1 1 1\ny Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n y Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n\n2 2\nDe(cid:133)ne x = (cid:21)x +(1 (cid:21))x and y = (cid:21)y +(1 (cid:21))y . Since y ;y C and C is convex, we have\n(cid:21) 1 0 (cid:21) 1 0 0 1\n(cid:0) (cid:0) 2\nthat y C. By de(cid:133)nition of f, we can conclude that\n(cid:21)\n2\nf((cid:21)x +(1 (cid:21))x ) = f(x ) = inf x y x y\n1 0 (cid:21) (cid:21) (cid:21) (cid:21)\n(cid:0) y Ck (cid:0) k (cid:20) k (cid:0) k\n2\n= (cid:21)x +(1 (cid:21))x (cid:21)y (1 (cid:21))y = (cid:21)(x y )+(1 (cid:21))(x y )\n1 0 1 0 1 1 0 0\nk (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 1\n(cid:21) x y +(1 (cid:21)) x y (cid:21) f(x )+ +(1 (cid:21)) f(x )+\n1 1 0 0 0 1\n(cid:20) k (cid:0) k (cid:0) k (cid:0) k (cid:20) n (cid:0) n\n(cid:18) (cid:19) (cid:18) (cid:19)\n1\n= (cid:21)f(x )+(1 (cid:21))f(x )+ :\n0 1\n(cid:0) n\nSince x , x , (cid:21), and n were arbitrarily chosen, f is convex and the implication follows (cf. Exercise 4\n0 1\nof the exams of September 2020 or January 8th, 2020).\n(cid:147)Only if(cid:148). First, observe that\nx C f(x) = 0: (2)\n2 ()\nIn fact, by de(cid:133)nition of f, we have that\nx C = 0 = x x inf x y = f(x) 0:\n2 ) k (cid:0) k (cid:21) y Ck (cid:0) k (cid:21)\n2\nMoreover, if inf x y = 0, then there exists a sequence y C such that x y\ninf x y = y 2 f C ( k x) (cid:0) = 0 k . Since C is closed, this implies that f y n gn 2x N , (cid:18) proving that x k C (cid:0) . W n k ith #\ny C n\n2 k (cid:0) k ! 2\nthis, take x ;x C and (cid:21) (0;1). By (2) and since f is convex and x ;x C, we can conclude\n1 0 1 0\n2 2 2\nthat\n0 f((cid:21)x +(1 (cid:21))x ) (cid:21)f(x )+(1 (cid:21))f(x ) = 0 = f((cid:21)x +(1 (cid:21))x ) = 0 = (cid:21)x +(1 (cid:21))x C:\n1 0 1 0 1 0 1 0\n(cid:20) (cid:0) (cid:20) (cid:0) ) (cid:0) ) (cid:0) 2\nSince x 0 , x 1 , and (cid:21) were arbitrarily chosen, C is convex and the implication follows. (cid:4)',
#  'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. De(cid:133)ne the optimal policy correspondence and the optimal policy function.\n2. De(cid:133)ne when a path x =(x ;x ;x ;:::) is sequentially optimal for problem RF (x ).\n0 1 2 0\nSolution 1. See the lecture notes.\n2. See the lecture notes. (cid:4)',
#  'EXTRA PAGE',
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 7, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let V be a vector space.\n1. Give the de(cid:133)nition of vector subspace.\n2. Prove that the intersection of any family of vector subspaces of V is a vector subspace of V.\nSolution See the lecture notes. (cid:4)',
#  'Exercise 2 Consider a nonempty set X and assume that d and d are two di⁄erent distances on X.\na b\nAssume that the following property holds: each convergent sequence with respect to d is convergent\na\nwith respect to d and the limit is the same, that is, in symbols, for each x X\nb f n gn N (cid:18)\n2\nx\nda\nx = x\ndb\nx: (1)\nn n\n! ) !\n1. Prove that if O X is open with respect to d , then it is open with respect to d .\nb a\n(cid:18)\n2. Prove that if K is compact with respect to d , then it is compact with respect to d .\na b\nSolution 1. Consider a set O which is open with respect to d . It follows that C = Oc is closed\nb\nwith respect to d . We next show that C is closed also with respect to d . Consider a sequence\nb a\nx C such that x\nda\nx. By (1), it follows that x\ndb\nx. Since C is d -closed, we can conclude\nf n gn N (cid:18) n ! n ! b\nthat x2 C. Since x was arbitrarily chosen, it follows that C is d -closed and, in particular,\nO = (O 2 c)c = Cc is o f pe n n gn w2i N th respect to d , proving the statement. a\na\n2. Proof1. Consideracollection O suchthatO isd -openforall(cid:11) AandK O .\nIn other words, O is an open f co (cid:11) ve g r (cid:11) 2f A or K with re (cid:11) spect b to d . Since se 2 ts that are (cid:18) op [ e (cid:11) n 2 A wit (cid:11) h\nf (cid:11) g(cid:11) A b\nrespect to d are open w2ith respect to d , we have that O is an open cover for K with respect\nb a f (cid:11) g(cid:11) A\nto d . Since K is compact with respect to d , we have that the2re exists a (cid:133)nite subcover of O ,\na a f (cid:11) g(cid:11) A\nproving that K is compact with respect to d . 2\nb\nProof 2. Consider a sequence x in K. By Bolzano-Weierstrass Theorem and (1) and\nf n gn N\nsince K is compact with respect to d , th2ere exists a subsequence x x such that\na f nkgk N (cid:18) f n gn N\nx\nda\nx K, proving that x\ndb\nx K. This implies that each sequence in\n2\nK admits a\n2\nsubsequence\nnk\n! 2\nnk\n! 2\nwhich converges, with respect to d , to a point in K. By Bolzano-Weierstrass Theorem, we can\nb\nconclude that K is compact with respect to d b . (cid:4)',
#  'Exercise 3 Consider R 3 and de(cid:133)ne : R 3 [0; ) by\nk k ! 1\nk x k = j x 1 j + x2 2 +x2 3 8 x 2 R 3:\nq\nIs a norm?\nk k\nSolution Yes! De(cid:133)ne (cid:25) : R 3 R 2 by (cid:25)(x) = (x 2 ;x 3 ) for all x R 3, that is,\n! 2\nx\n0 1 0 1\n(cid:25)(x) = 0 0 1 0 x 2 1 8 x 2 R 3:\n(cid:18) (cid:19) x 3\n@ A\nIt follows that\nk x k = j x 1 j + k (cid:25)(x) k2 8 x 2 R 3\nwhere : R 2 [0; ) is the Euclidean norm, that is, z = z2+z2 for all z R 2. We now\nk k2 ! 1 k k2 1 2 2\nprove the three properties of norm.\np\n1. Since is a norm, note that\nk k2\nx = 0 x + (cid:25)(x) = 0 x = (cid:25)(x) = 0 x = 0 and (cid:25)(x) = 0\nk k () j 1 j k k2 () j 1 j k k2 () 1\nx = x = x = 0 x = 0:\n1 2 3\n() ()\n2. Since is a norm and (cid:25) is linear, for each (cid:21) R and for each x R 3, we have that\nk k2 2 2\n(cid:21)x = (cid:21)x + (cid:25)((cid:21)x) = (cid:21) x + (cid:21)(cid:25)(x) = (cid:21) ( x + (cid:25)(x) ) = (cid:21) x :\nk k j 1 j k k2 j jj 1 j k k2 j j j 1 j k k2 j jk k\n3. Since is a norm and (cid:25) is linear, for each x;y R 3, we have that\nk k2 2\nx+y = x +y + (cid:25)(x+y) = x +y + (cid:25)(x)+(cid:25)(y)\nk k j 1 1 j k k2 j 1 1 j k k2\nx + (cid:25)(x) + y + (cid:25)(y) = x + y :\n(cid:20) j 1 j k k2 j 1 j k k2 k k k k\nThe three properties prove that is a norm. (cid:4)\nk k',
#  'Exercise 4 Consider R n endowed with the supnorm .1 Let T : R n R n be such that\nk k !\n1\nT (x) T (y) x y x;y R n: (2)\nk (cid:0) k (cid:20) k (cid:0) k 8 2\n1 1\n1. If x R n and (cid:11) (0;1), prove that there exist two unique points in R n, x (cid:11) and x~ (cid:11) , such that\n2 2\nx = T ((1 (cid:11))x+(cid:11)x ) and x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11) (cid:11) (cid:11)\n(cid:0) (cid:0)\n2. Prove that x~ = (1 (cid:11))x+(cid:11)x .\n(cid:11) (cid:11)\n(cid:0)\nSolution De(cid:133)ne T (cid:11);x ;T~ (cid:11);x : R n R n by\n!\nT (cid:11);x (y) = T ((1 (cid:11))x+(cid:11)y) and T~ (cid:11);x (y) = (1 (cid:11))x+(cid:11)T (y) y R n:\n(cid:0) (cid:0) 8 2\nNote that\nx = T (x ) x = T ((1 (cid:11))x+(cid:11)x )\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nand\nx~ = T~ (x~ ) x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nIn other words, the points (x and x~ ) we are after are the (cid:133)xed points of the two operators T and\n(cid:11) (cid:11) (cid:11);x\nT~ , respectively.\n(cid:11);x\n1. Since T satis(cid:133)es (2), we have that\nT (y) T (z) = T ((1 (cid:11))x+(cid:11)y) T ((1 (cid:11))x+(cid:11)z)\n(cid:11);x (cid:11);x\nk (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 (1 (cid:11))x+(cid:11)y (1 (cid:11))x (cid:11)z = (cid:11) 1 y z y;z R n\n(cid:20) k (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) k 8 2\n1 1\nand\nT~ (y) T~ (z) = (1 (cid:11))x+(cid:11)T (y) (1 (cid:11))x (cid:11)T (z)\n(cid:11);x (cid:11);x\n(cid:0) k (cid:0) (cid:0) (cid:0) (cid:0) k\n1\n(cid:13) (cid:13) (cid:13) (cid:13) 1 = (cid:11) T (y) T (z) (cid:11) y z y;z R n:\n(cid:13) (cid:13) k (cid:0) k 1 (cid:20) k (cid:0) k 1 8 2\nInotherwords,since(cid:11) (0;1),T andT~ are(cid:11)-contractions. BytheBanachContractionprinciple\n(cid:11);x (cid:11);x\nand since (R n; ) is 2 complete, this implies that T\n(cid:11);x\nand T~\n(cid:11);x\nhave each a unique (cid:133)xed point which\nk k\nwe denote respect1ively x and x~ , that is,\n(cid:11) (cid:11)\nT ((1 (cid:11))x+(cid:11)x ) = T (x ) = x\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nand\n(1 (cid:11))x+(cid:11)T (x~ ) = T~ (x~ ) = x~ ;\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nproving that x and x~ exist and are unique.\n(cid:11) (cid:11)\n2. Set x^ = (1 (cid:11))x+(cid:11)x . We have that\n(cid:11) (cid:11)\n(cid:0)\nx^ = (1 (cid:11))x+(cid:11)x = (1 (cid:11))x+(cid:11)T ((1 (cid:11))x+(cid:11)x ) = (1 (cid:11))x+(cid:11)T (x^ ) = T~ (x^ );\n(cid:11) (cid:11) (cid:11) (cid:11) (cid:11);x (cid:11)\n(cid:0) (cid:0) (cid:0) (cid:0)\nproving that x^ is a (cid:133)xed point of T~ . Since this point is unique and is x~ . It follows that x~ =\n(cid:11) (cid:11);x (cid:11) (cid:11)\nx^ = (1 (cid:11))x+(cid:11)x , proving the equality (cf. Exercise 4 of the exams of September 2024, 2021, and\n(cid:11) (cid:11)\n(cid:0)\n2019). (cid:4)\n1Recall that k x k1 =max i 2f 1;:::;n gj x i j for all x 2 R n.',
#  'Exercise 5 State and prove the Blackwell(cid:146)s theorem.\nSolution See the lecture notes. (cid:4)',
#  'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Optimality Principle.\nSolution See the lecture notes. (cid:4)',
#  'EXTRA PAGE',
#  'Advanced Mathematics (Cod. 20136)\nMidterm Exam (cid:150)October 24, 2024\nName and Last Name\nStudent ID Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and sign my presence at\nthe exam.\nSignature:\nExercise 1 Consider the vector space RR of real valued functions over the real line. For each (cid:13) R\n2\nde(cid:133)ne the function f (cid:13) : R ! R by f (cid:13) (x) = j x (cid:0) (cid:13) j for all x 2 R.1 De(cid:133)ne S = f f n gn N .\n2\n1. Is spanS = RR? Motivate your answer!\n2. Is S linearly independent? Motivate your answer!\n3. Is S a basis of RR? Motivate your answer!\nSolution See also extra page. 1. No, spanS = RR. In fact, consider f : R R de(cid:133)ned by\n6 !\nf(x) = x2 for all x R. By contradiction, assume that f spanS. It follows that there exist\nf f nig k i=1 (cid:18) S and f (cid:11) i g 2k i=1 (cid:18) R such that f = k i=1 (cid:11) i f ni . It fol 2 lows that\nk P k\nx2 = f(x) = (cid:11)\ni\nf\nni\n(x) = (cid:11)\ni\nj\nx\n(cid:0)\nn\ni\nj 8\nx\n2\nR:\ni=1 i=1\nX X\ndef\nBy passing to the limit, if we consider x > n(cid:22) = max n : i 1;:::;k , then we have that\ni\nf 2 f gg\nk k k\nn\nx2 = (cid:11)\ni\n(x n\ni\n) x > n(cid:22) = x = (cid:11)\ni\n1 i x > n(cid:22) = = (cid:11)\ni\nR;\n(cid:0) 8 ) (cid:0) x 8 ) 1 2\nX i=1 X i=1 (cid:16) (cid:17) X i=1\na contradiction.\n2. Yes, S is linearly independent! De(cid:133)ne S = f n . We are (cid:133)rst going to show that S is\nn f i gi=1 n\nlinearly independent for all n N. We proceed by induction.\n2\nInitial step. n = 1. We need to show that (cid:11) f = 0 implies that (cid:11) = 0, that is, (cid:11) f (x) = 0 for all\n1 1 1 1 1\nx R implies that (cid:11) 1 = 0. If we consider x(cid:22) = 2, then we have that\n2\n(cid:11) f = 0 = (cid:11) = (cid:11) f (x(cid:22)) = 0;\n1 1 1 1 1\n)\nproving the statement.\n1In other words, f is such that\n(cid:13)\nx (cid:13) if x (cid:13)\nf (cid:13) (x)= (cid:13) (cid:0) x if x< (cid:21) (cid:13) 8 x 2 R:\n(cid:26) (cid:0)',
#  'Inductive step. Assume the statement is true for n. Assume that f (cid:11) i g n i= + 1 1 (cid:18) R and n i= + 1 1(cid:11) i f i = 0.\nThis means that\nn+1 n+1 P\n(cid:11)\ni\nf\ni\n(x) = (cid:11)\ni\nx i = 0 x R: (1)\nj (cid:0) j 8 2\ni=1 i=1\nX X\nWe thus have that\nn\n(cid:11)\nn+1\nf\nn+1\n(x) = (cid:11)\ni\nf\ni\n(x) x R:\n(cid:0) 8 2\ni=1\nX\nConsider now x(cid:22) = n+ 1. By the de(cid:133)nition of f , we have that n+1 > x(cid:22) > n > ::: > 1 and\n2 f n gn N\n2\n1 1\nf (n+1) = 0 and f (x(cid:22)) = and f (n+1) = n+1 i and f (x(cid:22)) = n+ i\nn+1 n+1 i i\n2 (cid:0) 2 (cid:0)\nIn this case, we have that\nn n\n1\n(cid:11) = (cid:11) f (n+1) (cid:11) f (x(cid:22)) = (cid:11) f (n+1) (cid:11) f (x(cid:22))\nn+1 n+1 n+1 n+1 n+1 i i i i\n(cid:0)2 (cid:0) (cid:0) (cid:0) (cid:0)\n!\n(cid:18) (cid:19) i=1 i=1\nX X\nn n n\n1\n= (cid:11) (f (n+1) f (x(cid:22))) = (cid:11) = (cid:11) = (cid:11) :\ni i i i n+1 i\n(cid:0) (cid:0) (cid:0) 2 )\ni=1 i=1 i=1\nX X X\nConsider now x(cid:22) = n+1+1=2. By the de(cid:133)nition of f , we have that x(cid:22) > n+1 > n > ::: > 1 and\nf n gn N\n2\n1 1\nf (x(cid:22)) = and f (n+1) = 0 and f (x(cid:22)) = n+1+ i and f (n+1) = n+1 i\nn+1 n+1 i i\n2 2 (cid:0) (cid:0)\nIn this case, we have that\nn n\n1\n(cid:11) = (cid:11) f (x(cid:22)) (cid:11) f (n+1) = (cid:11) f (x(cid:22)) (cid:11) f (n+1)\nn+1 n+1 n+1 n+1 n+1 i i i i\n2 (cid:0) (cid:0) (cid:0) (cid:0)\n!\n(cid:18) (cid:19) i=1 i=1\nX X\nn n n\n1\n= (cid:11) (f (x(cid:22)) f (n+1)) = (cid:11) = (cid:11) = (cid:11) :\ni i i i n+1 i\n(cid:0) (cid:0) (cid:0) 2 ) (cid:0)\ni=1 i=1 i=1\nX X X\nWe can conclude that n (cid:11) = (cid:11) = n (cid:11) , that is, 2 n (cid:11) = 0, yielding that (cid:11) =\nn (cid:11) = 0. By inductive i= h 1 y (cid:0) pot i hesis n a + n 1 d since i= (cid:11) 1 i = 0, we have i t = h 1 at i n+1\ni=1 i P P n+1 P\nP n n+1\n(cid:11) f = (cid:11) f = 0 = (cid:11) = 0 i 1;:::;n :\ni i i i i\n) 8 2 f g\ni=1 i=1\nX X\nThus, n+1(cid:11) f = 0 yields that (cid:11) = 0 for all i 1;:::;n+1 , proving the inductive step.\ni=1 i i i 2 f g\nBy\nP\ninduction, S\nn\nis linearly independent for all n\n2\nN. Next, consider any (cid:133)nite set\nf\nf\nnig\nk\ni=1 (cid:18)\nS.\nWithoutlossofgenerality, wecanassumethatn < ::: < n . Itfollowsthat f k f nk = S .\n1 k f nigi=1 (cid:18) f i gi=1 nk\nSince the latter set is linearly independent, any of its subsets is linearly independent. This proves the\nlinear independence of f k and, in particular, of S.\nf\nnigi=1\n3. No. To be a basis S needs to be linearly independent and spanS = RR. Since the second\nrequirement is missing, S is not a basis. (cid:4)',
#  'Exercise 2 Consider a function f : R n R m.\n!\n1. State and prove the Riesz representation theorem (that is, the theorem that provides a charac-\nterization for linear operators).\nSolution See the lecture notes. (cid:4)',
#  'Exercise 3 Consider a metric space (X;d).\n1. Prove that a neighborhood of x X and radius " > 0 is an open set.\n2\n2. Let O be a collection of open sets. Prove that O is open.\nf i gi 2 I [ i 2 I i\nSolution 1. See the lecture notes.\n2. See the lecture notes. (cid:4)',
#  'Exercise 4 Consider a metric space (X;d).\n1. Prove that if A ;A X, then intA intA int(A A ).\n1 2 1 2 1 2\n(cid:18) [ (cid:18) [\n2. Consider A X. Call B = @A. Prove that @B @A, that is, @(@A) @A.\n(cid:18) (cid:18) (cid:18)\nSolution 1. We proved in class that intA and intA are open sets such that intA A and\n1 2 1 1\n(cid:18)\nintA A . We also showed that for any set A\n2 2\n(cid:18)\nintA = O: (2)\nO is open and O A\n[ (cid:18)\nSince the union of open sets is open, it follows that intA intA is open and included in A A .\n1 2 1 2\n[ [\nBy (2), we can conclude that intA intA int(A A ).\n1 2 1 2\n[ (cid:18) [\n2. If @(@A) = , then we trivially have that @(@A) @A. Otherwise, let x @(@A). Consider\n; (cid:18) 2\n" > 0. By de(cid:133)nition of @(@A), we have that for each (cid:14) > 0\nB (x) @A = = B (x) (@A)c:\n(cid:14) (cid:14)\n\\ 6 ; 6 \\\nSet (cid:14) = "=2. Consider y B (x) @A. By de(cid:133)nition of @A and since y @A, we have that for each\n(cid:14)\n2 \\ 2\n(cid:13) > 0\nB (y) A = = B (y) Ac:\n(cid:13) (cid:13)\n\\ 6 ; 6 \\\nConsider (cid:13) = "=2 and choose z B (y) A and z B (y) AC. It follows that\n1 (cid:13) 2 (cid:13)\n2 \\ 2 \\\n" "\nd(x;z ) d(x;y)+d(y;z ) < + = " i 1;2 ;\ni i\n(cid:20) 2 2 8 2 f g\nthat is, z ;z B (x) and z A and z AC, yielding that z B (x) A = = B (x) Ac z .\n1 2 " 1 2 1 " " 2\n2 2 2 2 \\ 6 ; 6 \\ 3\nSince " was arbitrarily chosen, we have that x @A, proving that @(@A) @A. (cid:4)\n2 (cid:18)',
#  'EXTRA PAGE\nAlternative solutions and comments to Exercise 1.\nIntuition for current solution of point 2, inductive step. If (cid:11) is di⁄erent from 0, then\nn+1\nf = n (cid:11)i f . The function f is decreasing up to n + 1 and increasing after, so in a\nn+1 i=1(cid:0)(cid:11)n+1 i n+1\nneighborhood n+1 n+ 1;n+ 3 , f is (cid:133)rst decreasing and then increasing, while the functions\nP 2 2 2 n+1\nf (with i 1;:::;n ) are all increasing on n+ 1;n+ 3 . This does not seem compatible with\nf\ni\n=\nn2 f\n(cid:11)i f\ng\n.\n(cid:0)\nIt seems cou\n(cid:1)\nnterintuitive to s\n2\nay that\n2\nf is a linear combination of increasing\nn+1 i=1(cid:0)(cid:11)n+1 i (cid:0) (cid:1) n+1\nfunctions and is not increasing, but (cid:133)rst decreasing and then increasing.\nP\nAlternative solution: di⁄erentiability, as in Calculus 101, for all three points. Before\nstarting, observe that each f is di⁄erentiable everywhere apart from x = n.\nn\n1. No, spanS = RR. In fact, consider f : R R de(cid:133)ned by f(x) = x2 for all x R. The\n6 ! 2\nfunction f is di⁄erentiable everywhere. By contradiction, assume that f spanS. It follows that\nthere exist f f nig k i=1 (cid:18) S and f (cid:11) i g k i=1 (cid:18) R such that f = k i=1 (cid:11) i f ni . If (cid:11) 2 j 6 = 0, then k i=1 (cid:11) i f ni is\nnot di⁄erentiable at n . But, since f = k (cid:11) f and f is di⁄erentiable everywhere, then (cid:11) = 0 for\nj i=1 i ni P P i\nall i 1;:::;k , proving that x2 = f(x) = 0 for all x R, a contradiction.\n2 f g P 2\n2. Consider any (cid:133)nite set f k S. Assume that k (cid:11) f = 0. If (cid:11) = 0, then k (cid:11) f\nf nigi=1 (cid:18) i=1 i ni j 6 i=1 i ni\nis not di⁄erentiable at n . But, since k (cid:11) f is equal to the constant function 0, we have that\nj i=1 i ni P P\nk (cid:11) f is di⁄erentiable everywhere, yielding that (cid:11) = 0 for all i 1;:::;k , proving linear\ni=1 i ni P i 2 f g\nindependence.\nP\n3.No. To be a basis S needs to be linearly independent and spanS = RR. Since the second\nrequirement is missing, S is not a basis.\nAlternative solution: continuity, as in Calculus 101, for points 1 and 3. Before starting,\nobserve that each f is continuous.\nn\n1. No, spanS = RR. In fact, consider f : R R de(cid:133)ned by\n6 !\n1 x = 1\nf(x) = x R:\n0 x = 0 8 2\n(cid:26) 6\nThefunctionf isnotcontinuous. Bycontradiction, assumethatf spanS. Itfollowsthatthereexist\nf f nig k i=1 (cid:18) S and f (cid:11) i g k i=1 (cid:18) R such that f = k i=1 (cid:11) i f ni . Since 2 a linear combination of continuous\nfunctionsiscontinuous, wehavethat k (cid:11) f iscontinuous. Yet, f = k (cid:11) f isnotcontinuous,\ni=1 i n Pi i=1 i ni\na contradiction.\nP P\n3. No. To be a basis S needs to be linearly independent and spanS = RR. Since the second\nrequirement is missing, S is not a basis. (cid:4)',
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)August 30, 2024\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Consider the vector space V of all sequences of real numbers which are eventually 0,1 that\nis,\nV = x RN : x is eventually zero :\n2\nn o\n1. Prove that a functional ‘ : V R is linear if and only if there exists z RN such that ‘(x) =\n! 2\nx z for all x V. Moreover, z is unique.\n1n=1 n n\n2\nSolutPion Before starting, observe that the set ek V where for each k N the sequence ek is\nk N (cid:18) 2\nsuch that 2\n1 n(cid:8)=(cid:9)k\nek n = 0 n = k 8 n 2 N\n(cid:26) 6\nis a basis of V (cf. the Exam of September 2019, Exercise 1). In particular, if x V, then there exists\n2\nn x N such that x n = 0 for all n n x and\n2 (cid:21)\nnx\nx = x ek:\nk\nk=1\nX\n(cid:147)Only if(cid:148). Fix ‘ : V R. De(cid:133)ne z RN by z\nk\n= ‘ ek for all k N. Consider x V. Since x is\n! 2 2 2\nsuch that x = 0 for all n n and ‘ is linear, it follows that\nn x\n(cid:21) (cid:0) (cid:1)\nnx nx nx\n1\n‘(x) = ‘ x ek = x ‘ ek = x z = x z :\nk k k k k k\n!\nX k=1 X k=1 (cid:16) (cid:17) X k=1 X k=1\nSince x was arbitrarily chosen, the statement follows.\n(cid:147)If(cid:148). Fix z\n2\nRN. De(cid:133)ne ‘ : V\n!\nR by ‘(x) = 1n=1 x n z n for all x\n2\nV. If x;y\n2\nV and (cid:11);(cid:12)\n2\nR,\nthen it follows that\nP\n1 1 1\n‘((cid:11)x+(cid:12)y) = ((cid:11)x +(cid:12)y )z = (cid:11) x z +(cid:12) y z = (cid:11)‘(x)+(cid:12)‘(y);\nn n n n n n n\nn=1 n=1 n=1\nX X X\nproving linearity.\n(cid:147)Uniqueness(cid:148). Assume z;w\n2\nRN are such that\n1n=1\nx\nn\nz\nn\n= ‘(x) =\n1n=1\nx\nn\nw\nn\nfor all x\n2\nV. It\nfollows that\nP P\n1 1\nz\nk\n= ek\nn\nz\nn\n= ‘ ek = ek\nn\nw\nn\n= w\nk\nk N;\n8 2\nn X =1 (cid:16) (cid:17) n X =1\nproving that z = w.\nComment This is a generalization of the Riesz Representation Theorem which we proved by\nreplicating the same exact arguments we have seen for the standard version of Riesz(cid:146)s Theorem. (cid:4)\n1Recall that a sequence x is eventually zero if and only if there exists n x N s.t. x n =0 for all n n x .\n2 (cid:21)',
#  'Exercise 2 Consider a metric space (X;d).\n1. Give the de(cid:133)nition of compact set.\n2. Prove that if the subset K of X is compact, then it is closed and bounded.\nSolution 1. See the lecture notes.\n2. See the lecture notes. (cid:4)',
#  'Exercise 3 Let T : V V be a linear operator between normed vector spaces.\n1 2\n!\n1. De(cid:133)ne when T is bounded.\n2. Prove that T is bounded if and only if it is continuous.\nSolution 1. See the lecture notes.\n2. See the lecture notes. (cid:4)',
#  'Exercise 4 Consider the Banach space c of all sequences of real numbers which converge to 0, that\n0\nis,\nc\n0\n= x RN : limx\nn\n= 0\n2 n\nn o\nendowed with the supnorm .2 Consider the operator T : c c\n0 0\nk k !\n1\nT (x) = (1;x ;x ;x ;:::) x c ;\n1 2 3 0\n8 2\nthat is, if y = T (x), then y\n1\n= 1 and y\nn+1\n= x\nn\nfor all n N. Given (cid:12) (0;1], de(cid:133)ne T\n(cid:12)\n: c\n0\nc\n0\nby\n2 2 !\nT (x) = (cid:12)T (x) x c :\n(cid:12) 0\n8 2\n1. If (cid:12) (0;1), does T admit a (cid:133)xed point? Is it unique? Can you compute it? Motivate your\n(cid:12)\n2\nanswers!\n2. If (cid:12) = 1, does T admit a (cid:133)xed point? Is it unique? Can you compute it? Motivate your answers!\n(cid:12)\nSolution First, observe that\nT (x) T (y) = (1;x ;x ;x ;:::) (1;y ;y ;y ;:::) x;y c :\n1 2 3 1 2 3 0\n(cid:0) (cid:0) 8 2\nIt follows that\nT (x) T (y) = x y x;y c : (1)\n0\nk (cid:0) k k (cid:0) k 8 2\n1 1\n1. Yes, to all the three questions. Fix (cid:12) (0;1). By (1) and the de(cid:133)nition of T , note that\n(cid:12)\n2\nT (x) T (y) = (cid:12)T (x) (cid:12)T (y) (cid:12) T (x) T (y) x;y c ;\n(cid:12) (cid:12) 0\nk (cid:0) k k (cid:0) k (cid:20) k (cid:0) k 8 2\n1 1 1\nproving that T is a (cid:12)-contraction. By the Banach Contraction Principle and since c is a Banach\n(cid:12) 0\nspace, this implies that T admits a unique (cid:133)xed point. Call it x(cid:22). Note that\n(cid:12)\nx(cid:22) = T (x(cid:22)) = (cid:12)T (x(cid:22)):\n(cid:12)\nBy de(cid:133)nition of T, we have that x(cid:22)\n1\n= (cid:12) and x(cid:22)\nn+1\n= (cid:12)x(cid:22)\nn\nfor all n N. By induction, we can conclude\n2\nthat x(cid:22)\nn\n= (cid:12)n for all n N.3\n2\nComment An alternative solution is to directly compute x(cid:22), that is, to say if x(cid:22) were a (cid:133)xed point\nof T\n(cid:12)\n, then x(cid:22) = T\n(cid:12)\n(x(cid:22)) and the only solution would be x(cid:22)\nn\n= (cid:12)n for all n N. In this case, it becomes\n2\nnecessary though to verify that x(cid:22) c while before it was just a consistency check given that existence\n0\n2\nwas granted by Banach Contraction Principle.\n2. No, to all the three questions, for T does not admit (cid:133)xed points. By de(cid:133)nition of T, if T had a\n(cid:133)xed point, call it x(cid:22), we would have that x(cid:22)\n1\n= 1 and x(cid:22)\nn+1\n= x(cid:22)\nn\nfor all n N, yielding that x(cid:22)\nn\n= 1\n2\nfor all n N, but in this case, x(cid:22) would not converge to 0, that is lim\nn\nx(cid:22)\nn\n= 1, yielding that x(cid:22) c\n0\n, a\n2 62\ncontradiction. (cid:4)\n2Recall that x =sup x for all x c .\n3Since lim (cid:12) kn k =10 given n (cid:12)2 Nj ( n 0 j ;1), note 2 how 0 indeed x(cid:22) is a sequence which converges to 0, providing a consistency\nn\n2\ncheck.',
#  'Exercise 5 Let B(X) be the space of bounded functions over the set X, T : B(X) B(X) a\n!\nmonotone operator, (cid:12) (0;1).4 Endow B(X) with the supnorm. Prove that T is a (cid:12)-contraction if\n2\nand only if T has the ((cid:12)-)discounting property.\nSolution (cid:147)If(cid:148)It is Blackwell(cid:146)s Theorem. (cid:147)Only if(cid:148). By assumption, we have that\nT (g) T (f) (cid:12) g f f;g B(X):\nk (cid:0) k (cid:20) k (cid:0) k 8 2\n1 1\nBy de(cid:133)nition of supnorm, this implies that\nT (g)(x) T (f)(x) T (g)(x) T (f)(x) (cid:12) g f f;g B(X); x X:\n(cid:0) (cid:20) j (cid:0) j (cid:20) k (cid:0) k 8 2 8 2\n1\nIf we set g = f +c with c 0, then we have that\n(cid:21)\nT (f +c)(x) T (f)(x) (cid:12) f +c f = (cid:12)c f B(X); x X;\n(cid:0) (cid:20) k (cid:0) k 8 2 8 2\n1\nthat is, T (f +c)(x) T (f)(x)+(cid:12)c for all f B(X), for all x X, and for all c 0. This proves\n(cid:20) 2 2 (cid:21)\nthat T (f +c) T (f)+(cid:12)c for all f B(X) and for all c 0, that is, T has the ((cid:12)-)discounting\n(cid:20) 2 (cid:21)\nproperty. (cid:4)\n4Recall that T being monotone means that if f(x) g(x) for all x X, then T(f)(x) T(g)(x) for all x X\n(cid:20) 2 (cid:20) 2\nwhich we could write as\nf g = T(f) T(g):\n(cid:20) ) (cid:20)',
#  'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.\nSolution See the lecture notes. (cid:4)',
#  'EXTRA PAGE',
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 24, 2024\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let S be a nonempty subset of a vector space V.\n1. If S = x n is (cid:133)nite, show that\nf i gi=1\nn\nspanS = x 2 V : 9f (cid:11) i g n i=1 (cid:18) R s.t. x = (cid:11) i x i :\n( )\ni=1\nX\nSolution See the lecture notes. (cid:4)',
#  'Exercise 2 Consider a metric space (X;d).\n1. Prove that if K is a nonempty compact subset of X and x is a point of X which does not belong\nto K, that is x K, then there exist two open sets O and O such that K O , x O , and\n1 2 1 2\n62 (cid:18) 2\nO O = .\n1 2\n\\ ;\n2. Prove that if K is another nonempty compact subset of X such that K K = , then there\n0 0\n\\ ;\nexist two open sets O and O such that K O , K O , and O O = .\n1 2 1 0 2 1 2\n(cid:18) (cid:18) \\ ;\nSolution 1. For each y K set " = d(x;y)=2 > 0. Since x K, we have that x = y and " > 0\ny y\n2 62 6\nfor all y K. It follows that B (y) B (x) = . Consider the collection B (y) . Since open\n2 "y \\ "y ; "y y K\nballs are open sets and y B (y) for all y K, we have that K = y 2 B (y),\nf g (cid:18) "y 2 [(cid:8)y 2 K f g(cid:9)(cid:18) [ y 2 K "y\nthat is, B (y) is an open cover for K. Since K is compact, there exists a (cid:133)nite subcover\n"y y K\nB n B ( 2 y) and, in particular, K n B (y ). De(cid:133)ne " = min " > 0. Set\nO " = yi i n =(cid:8)1 B (cid:18) (y "(cid:9)y ) and y 2O K = B (x). Since the un (cid:18) io [ n i o = f 1 op "y e i n se i ts is open and ope i 2 n f 1 b ;: a :: l ; l n s g ar y e i open, so\n(cid:8)1 (cid:9)[i=1 "y(cid:8)i i (cid:9) 2 "\nare O and O . Moreover, K O and x O . Finally, we have that\n1 2 1 2\n(cid:18) 2\nO O = B (x) n B (y ) = n B (x) B (y )\n1\n\\\n2 "\n\\ [\ni=1 "yi i\n[\ni=1 "\n\\\n"yi i\nn B (x) B (y ) = ;\n(cid:18) [\ni=1 "y (cid:0)\ni \\\n"yi (cid:1)i\n;\n(cid:0) (cid:1)\n(cid:0) (cid:1)\nproving that O O = and the statement.\n1 2\n\\ ;\n2. Since K K = , x K for all x K . By point 1, for each x K there exist two open sets\n0 0 0\n\\ ; 62 2 2\nO and O such that K O , x O , and O O = . Since x O for all x K ,\n1;x 2;x 1;x 2;x 1;x 2;x 2;x 0\n(cid:18) 2 \\ ; f g (cid:18) 2\nwe have that K = x O , that is, O is an open cover for K . Since K is\ncompact, there 0 exist [ s x 2 a K (cid:133) 0 n f ite g s (cid:18) ub [ c x o 2 v K er 0 2 O ;x n f O 2;x gx 2 K 0 and, in particular, K 0 n O 0 .\nDe(cid:133)ne O = n O and O = n O f . 2; S xi i g n i c = e 1 th (cid:18) e f (cid:133)ni 2 t ;x e g i x n2t K er 0 section of open sets is o 0 p (cid:18) en [ , s i= o 1 is 2 a ; n xi y\n1 \\i=1 1;xi 2 [i=1 2;xi\nunion of open sets, and K O for all x K , we have that O is open, O is open, K O , and\n1;x 0 1 2 1\n(cid:18) 2 (cid:18)\nK O . Finally, we have that\n0 2\n(cid:18)\nO O = O ( n O ) = n (O O )\n1\n\\\n2 1\n\\ [\ni=1 2;xi\n[\ni=1 1\n\\\n2;xi\nn (O O ) = ;\n(cid:18) [\ni=1 1;xi\n\\\n2;xi\n;\nproving that O 1 O 2 = and the statement. (cid:4)\n\\ ;',
#  'Exercise 3 Consider the Banach space of continuous functions over [0;1] endowed with the supnorm,\nthat is, (C([0;1]); ).1 Consider n N and de(cid:133)ne the operator T n : C([0;1]) C([0;1]) by\nk k 2 !\n1\nT (f)(t) = tnf(t) t [0;1].\nn\n8 2\n1. Given n N, compute the operator norm of T\nn\n. Motivate your answer!\n2\n2. Given the sequence of bounded linear operators T , does it converge, in operator norm, to\nf n gn N\nan operator T : C([0;1]) C([0;1])? Motivate your 2answer!\n!\nSolution 1. Fix n N. Note that for each f C([0;1])\n2 2\nT (f) = max T (f)(t) = max tnf(t) = max tn f(t) max tn max f(t) 1 f ;\nn n\nk k 1 t [0;1]j j t [0;1]j j t [0;1]j jj j (cid:20) t [0;1]j jt [0;1]j j (cid:20) k k 1\n2 2 2 2 2\nproving that T\nn\n1. At the same time, note that f(cid:22) : [0;1] R, de(cid:133)ned by f(cid:22)(t) = 1 for all\nt [0;1], is su k ch k t(cid:3)ha (cid:20) t f(cid:22) C([0;1]), f(cid:22) = 1, and T f(cid:22) (t) = ! tnf(cid:22)(t) = tn for all t [0;1]. This\nn\n2 2 2\nimplies that 1\n(cid:13) (cid:13) (cid:0) (cid:1)\n(cid:13) (cid:13)\n1 T max T (f) T f(cid:22) = max tn = 1;\nn n n\n(cid:21) k k (cid:3) (cid:21) f C([0;1]): f =1k k 1 (cid:21) 1 t [0;1]j j\n2 k k1\n(cid:13) (cid:0) (cid:1)(cid:13)\n2\n(cid:13) (cid:13)\nproving that T = 1.\nn\nk k\n(cid:3)\n2. No, it does not converge. If it did, we would have that there would exist a continuous linear\noperator T such that\nT (f) T (f) = (T T)(f) T T f 0 f C([0;1])\nn n n\nk (cid:0) k k (cid:0) k (cid:20) k (cid:0) k k k ! 8 2\n1 1 (cid:3) 1\nand, in particular, lim T f(cid:22) T f(cid:22) = 0. This, in turn, would imply that\nn n\n(cid:0)\n1\ntn (cid:13) (cid:13) T (cid:0) f(cid:22)(cid:1) (t) (cid:0) (cid:1) T (cid:13) (cid:13)n f(cid:22) T f(cid:22) 0 t C([0;1]);\n(cid:0) (cid:20) (cid:0) ! 8 2\n1\n(cid:12) (cid:0) (cid:1) (cid:12) (cid:13) (cid:0) (cid:1) (cid:0) (cid:1)(cid:13)\nyielding that (cid:12) (cid:12) (cid:13) (cid:13)\n1 T f(cid:22) (t) t = 1\n0 = li n m tn (cid:0) T f(cid:22) (t) = 0 (cid:0) T f(cid:22) (t) t [0;1) :\n(cid:26) (cid:12) (cid:0) (cid:0) (cid:1) (cid:12) 2\n(cid:12) (cid:0) (cid:1) (cid:12) (cid:12) (cid:12)\nWe would obtain that (cid:12) (cid:12) (cid:12) (cid:0) (cid:1) (cid:12)\n1(cid:12) t = 1 (cid:12)\nT f(cid:22) (t) = ;\n0 t [0;1)\n(cid:26) 2\n(cid:0) (cid:1)\na contradiction with T f(cid:22) being a continuous function over [0;1]. (cid:4)\n(cid:0) (cid:1)\n1For each f C([0;1])\n2\nf = max f(t) :\nk k1 t [0;1]j j\n2',
#  'Exercise 4 Let f : R n R be a functional such that\n!\nf((cid:21)x+(1 (cid:21))y) max f(x);f(y) x;y R n; (cid:21) (0;1): (1)\n(cid:0) (cid:20) f g 8 2 8 2\n1. Given t R, prove that the set x R n : f(x) t is convex.\n2 f 2 (cid:20) g\n2. Denote by e the vector whose components are all 1. Assume that f is such that\nf(x+ke) = f(x)+k x R n; k R: (2)\n8 2 8 2\nProve that f is convex.\nSolution 1. Consider x;y x R n : f(x) t and (cid:21) (0;1). It follows that f(x) t and\n2 f 2 (cid:20) g 2 (cid:20)\nf(y) t. By (1), this implies that f((cid:21)x+(1 (cid:21))y) max f(x);f(y) t, proving that (cid:21)x+\n(cid:20) (cid:0) (cid:20) f g (cid:20)\n(1 (cid:21))y x R n : f(x) t . Since x, y, and (cid:21) were arbitrarily chosen, we can conclude that\n(cid:0) 2 f 2 (cid:20) g\nx R n : f(x) t is convex.\nf 2 (cid:20) g\n2. Consider x;y R n and (cid:21) (0;1). De(cid:133)ne k = f(x) f(y). By (2), we have that f(y+ke) =\n2 2 (cid:0)\nf(y)+k = f(y)+f(x) f(y) = f(x). It follows that\n(cid:0)\nmax f(x);f(y+ke) = (cid:21)f(x)+(1 (cid:21))f(y+ke):\nf g (cid:0)\nBy (1) and (2), this implies that\nf((cid:21)x+(1 (cid:21))y)+(1 (cid:21))k = f((cid:21)x+(1 (cid:21))(y+ke))\n(cid:0) (cid:0) (cid:0)\n(cid:21)f(x)+(1 (cid:21))f(y+ke)\n(cid:20) (cid:0)\n= (cid:21)f(x)+(1 (cid:21))f(y)+(1 (cid:21))k;\n(cid:0) (cid:0)\nthat is, f((cid:21)x+(1 (cid:21))y) (cid:21)f(x)+(1 (cid:21))f(y), proving that f is convex. (cid:4)\n(cid:0) (cid:20) (cid:0)',
#  'Exercise 5 State and prove the Banach contraction principle.\nSolution See the lecture notes. (cid:4)',
#  'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.\nSolution See the lecture notes. (cid:4)',
#  'EXTRA PAGE',
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 8, 2024\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let V be a vector space.\n1. Give the de(cid:133)nition of vector subspace.\n2. Prove that the intersection of any family of vector subspaces of V is a vector subspace of V.\nSolution See the lecture notes. (cid:4)',
# ...
#  'Exercise 6 Consider the reduced form problem\nmax 1 0t1(x ;x ) sub x 3(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 - 2\nt=0\nX\n1. DeÖne its value function and write its Bellman equation.\n2. State and prove the Bellman Theorem and discuss its importance.\nSolution. See the lecture notes. !',
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam ñ February 1, 2013\nSurname Student ID\nName Exam Code\nRules of conduct during exams or other tests:\nIherebyundertaketorespecttheregulationsdescribedintheHonorCode andundersignmypresence\nat the exam.\nSignature:\nExercise 1 Consider a function f :R n R.\n!\n1. State and prove the Riesz representation theorem (that is, the theorem that provides a charac-\nterization for linear functionals).\nSolution. See the lecture notes. !',
#  'Exercise 2 Consider a metric space (X;d).\n1. Give the deÖnition of open set.\n2. Consider x X and ">0. DeÖne\n2\nS = y X :d(y;x)>" :\nf 2 g\nProve that the set S is open.\nSolution. 1. See the lecture notes.\n2. If S is empty then there is nothing to prove. Otherwise, consider y& S. DeÖne + =d(y&;x) ".\n2 %\nIt is immediate to see that + > 0. Next, consider z B (y&), that is, z X such that d(z;y&) < +.\n"\n2 2\nSince d is a distance function, it follows that d(y&;x) d(y&;z)+d(z;x). This yields that\n&\nd(z;x) d(y&;x) d(y&;z)>d(y&;x) + =d(y&;x) d(y&;x)+"=";\n\' % % %\nproving that z S. Since zwas chosen to be generic, we can conclude that B (y&) S, proving that\n"\n2 (\ny&is an interior point. Since y&was chosen to be generic, it follows that S is open. !',
#  'Exercise 3 Consider R 3.\n1. Give the deÖnition of norm.\n2. DeÖne f :R 3 R by\n! f(x)= x 1 + x 2 x R 3:\nj j j j 8 2\nProve that f satisÖes just two of the three properties that characterize a norm.\nSolution. 1. See the lecture notes.\n2. Notice that for each / R and for each x R 3\n2 2\nf(/x)= /x + /x = / (x + x )= / f(x):\n1 2 1 2\nj j j j j j j j j j j j\nFor each x;y R 3, we have that\n2\nf(x+y)= x +y + x +y (x + x )+(y + y )=f(x)+f(y):\n1 1 2 2 1 2 1 2\nj j j j& j j j j j j j j\nThus, f satisÖes at least two of the three properties that deÖne a norm. At the same time, we have\nthat there exists a vector x = 0 such that f(x) = 0, for example, (0;0;1), proving that f does not\n6\nsatisfy all the three properties which deÖne a norm. !',
#  "Exercise 4 This exercise has two parts.\n1. Consider the linear system:\nx_ =ax+by\ny_ =cx+dy:\n!\nWith respect to the coe¢cients a;b;c;d R how many equilibria it has? Give a formula for the\n2\ngeneral solution in the case of real and distinct eigenvalues associated to the coe¢cient matrix.\n2. Consider the non linear system\nx_ =x y\n%\n8 2x\n>< y_ =\n1+x2 %\ny:\n(a) Draw the phase portrait, where\n>:you\ndetermine, in particular, the equilibria, the vertical-\nand horizontal-slope isoclines and the orientation of the trajectories. Are rotations allowed\nin the neighborhood of equilibria?\n(b) Check that the origin is a critical point; can the linearization criterion be used in order to\ndetermine its stability?\nSolution. 1. If ad bc = 0 the system has one single equilibrium (the origin) else the system\n% 6\nhas inÖnite equilibria, along one straight line (that is the eigenvector associated with the zero eigen-\nvalue). Assuming thet 3 and 3 are real and distinct eigenvalues and h and h the corresponding\n1 2 1 2\neigenvectors, the general solution is\nx(t)\n=c e#1th +c e#2th\ny(t) 1 1 2 2\n& '\nwhere c\n1\n;c\n2\nR.\n2\n2. a. The equilibria solve the algebraic system\nx y =0\n%\n8 2x\n><\n1+x2 %\ny =0;\nthey are P = (0;0), P = (1;1) and P\n>:=\n( 1; 1). The vertical-slope isocline is the straight line\n1 2 3\n% % 2x\ny = x (represented in red in the Ögure below) the horizontal-slope isocline is the curve y =\n1+x2\n(representedinblue)ThepathsorientationisshownintheÖgure. AmongthethreeequilibriaP , P ,\n1 2\nP rotations are allowed just around P .\n3 1\n2. b. We have already seen that the origin is one of the equilibria of the system. The jacobian\nmatrix is\n1 1\n%\nJ(x;y)= 2 1 x2 :\n2 % 1 3\n(1+x2)2 %\n* +\n4 5\n1 1\nSince J(0;0) = 2 % 1 has eigenvalues 3 1 = % i and 3 2 = i; hence the origin of the linearized\n& % '\nsystem is a center. On the other hand, the origin of the original system can be either a center or a\nfocus (anyway rotations are compatible with the nature of this equilibrium point). The linearization\ncriterion is not conclusive in this case. !",
#  '1. (a)\n1\n0.8\n0.6\n0.4\n0.2\n0\n-0.2\n-0.4\n-0.6\n-0.8\n-1\n-3 -2 -1 0 1 2 3\nExercise 5 Consider the space B(X) of bounded functions over a set X.\n1. State (without proof) the Blackwell Theorem.\n2. Given a function 8 : X X R such that 8(x;y) < 1 for all x;y X and a function\n, ! j j 2\n9 :X R such that 0<9(x)<1=2 for all x X, consider the operator T :B(X) B(X),\n! 2 !\ndeÖned by\nT(v)(x)= sup 8(x;y)+9(y)v(y) x X: (1)\nf g 8 2\ny X\n2\n(a) DeÖne when v& B(X) is a Öxed point for T.\n2\n(b) Is T is a contraction?\n(c) Does T have a Öxed point? Is it unique?\nSolution. Observe that B(X) is endowed with the supnorm.\n1. See the lecture notes.\n2. a. v& is a Öxed point for T if and only if T(v&)=v&.\n2. b. Observe that:\n(i). Since 9 is positive, if v w then for each x X\n& 2\n8(x;y)+9(y)v(y) 8(x;y)+9(y)w(y) y X:\n& 8 2\nThis implies that for each x X\n2\nT(v)(x) = sup 8(x;y)+9(y)v(y)\nf g\ny X\n2\nsup 8(x;y)+9(y)w(y)\n& f g\ny X\n2\n= T(w)(x);\nproving that if v w then T(v) T(w).\n& &\n(ii). If v B(X) and c R+ then\n2 2\nT(v+c)(x) = sup 8(x;y)+9(y)(v(y)+c)\nf g\ny X\n2\n1\nsup 8(x;y)+9(y)v(y)+ c\n& 2\ny 2 X! .\n1\nsup 8(x;y)+9(y)v(y) + c\n& f g 2\ny X\n2\n1\n= T(v)(x)+ c;\n2',
#  'proving that T(v+c) T(v)+ 1c.\nBy points (i) and (i & i) and the 2 Blackwell Theorem, T is a 1-contraction.\n2\n2. c. By the Banach Contraction Principle and since B(X), endowed with the distance induced\nby the supnorm, is a complete metric space and T is a contraction, it follows that T admits a unique\nÖxed point. !',
#  "Exercise 6 Consider the reduced form problem\nmax 1 9t8(x ;x ) sub x 3(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 ' 2\nt=0\nX\n1. State and prove the Optimality Principle. Discuss its importance.\n2. DeÖnetheoptimalpolicycorrespondenceandtheoptimalpolicyfunction. Discussitsimportance.\nSolution. See the lecture notes. !",
#  'Advanced Mathematics (Cod. 20136)\nGeneral Exam ñ January 23, 2013\nSurname Student ID\nName Exam Code\nRules of conduct during exams or other tests:\nIherebyundertaketorespecttheregulationsdescribedintheHonorCode andundersignmypresence\nat the exam.\nSignature:\nExercise 1 Consider R n; R m; and an operator T :R n R m.\n!\n1. Prove that T is linear if and only if there exists a matrix A with m-rows and n-columns such\nthat\nT(x)=Ax x R n;\n8 2\n2. Prove that A, in point 1, is unique;\n3. Assume that n=m=2 and T is such that T(x)=(x 1 ;0) for all x R 2. Show that T is linear\n2\nand calculate the associated matrix A.\nSolution. 1. See the lecture notes.\n2. See the lecture notes.\n3. Consider x;y R 2 and (;) R. We have that\n2 2\n(x +)y x y\nT((x+)y)= 1 1 =( 1 +) 1 =(T(x)+)T(y);\n0 0 0\n! " ! " ! "\nproving that T is linear. By the previous part, we have that there exists a matrix A with 2 rows and\n2 columns such that\nT(x)=Ax x R 2:\n8 2\n1 0\nOn top of that, we have that A= T e1 ;T e2 = . !\n0 0\n! "\n# $ % $ %&',
#  'Exercise 2 Consider a metric space (X;d).\n1. Consider two sequences, x and y in X, such that lim d(x ;y ) = 0. Prove that\nif x x then also y f n gn c2o N nverges f ; n gn 2 N n n n\nn ! 0 f n gn 2 N\n2. Assume that (X;d) is compact. Consider two sequences, x and y in X, such that\nlim d(x ;y )=0. Prove that if x is a Cauchy seq f ue n n g c n e2 N then x f n gn 2 N and y are\ncon n vergin n g s n equences. f n gn 2 N f n gn 2 N f n gn 2 N\nSolution. 1. Notice that for each n N,\n2\n0 d(y ;x ) d(y ;x )+d(x ;x ) 0;\nn 0 n n n 0\n& & !\nproving that y x .\nn 0\n!\n2. Since X is compact, (X;d) is complete. Since x is a Cauchy sequence, this implies that\nx converges. Since lim d(x ;y )=0, by the f pre n v g i n o2u N s point, we have that y converges\nf as n w g e n l2l. N n n n f n gn 2 N !',
#  "Exercise 3 Consider a metric space (X;d) and a subset K of X.\n1. Characterize compactness of K through the Bolzano-Weirstrass property;\n2. Assume K is compact and consider a closed subset C of K. Prove that C is compact.\nSolution. 1. See the lecture notes.\n2. See the lecture notes.\nAlternative proof. Consider a sequence x C. We have that x K. Since K is\ncompact and by point 1, we have that there f ex n is g t n s2 N x ' x f C n su gn ch2 N th ' at x x K.\nSinceC isclosedand x C,itfollowsthat f x nkg C k ,2p N r ' ovi f ng n g th n a2t N C ' hastheBolzan n o k -W ! eirs 2 trass\nf\nnkgk\nN ' 2\nproperty, and so it is compac2t. !",
#  'Exercise 4 Consider R n endowed with a distance d. DeÖne by - the set of all vectors x R n such\nn 2\nthat x ;:::;x 0 and x = 1. Consider also a function F : - -. Assume that there exists\n1 n i\n( !\ni=1\nk >0 such that X\n(x +y )\n1 n\nd(F(x);F(y)) d(x;y) x;y -.\n& k 8 2\n1. For which values of k are we assured that F is a contraction?\n2. Assume that k is such that F is a contraction. Prove that F is continuous.\nSolution. 1. InorderforF tobeacontraction, F mustbesuchthatthereexists) [0;1)suchthat\n2\nd(F(x);F(y)) )d(x;y) x;y -.\n& 8 2\nSince x;y -, x +y is at most equal to 2. Thus, any k >2 will be such that\n1 n\n2\n(x +y ) 2\n1 n\nd(F(x);F(y)) d(x;y) d(x;y) )d(x;y) x;y -\n& k & k & 8 2\nwhere ) = 2 (0;1).\nk 2\n2. If x x then d(x ;x) 0. Since F is a contraction, then\nn n\n! !\n0 d(F(x );F(x)) )d(x ;x) 0;\nn n\n& & !\nproving that d(F(x n );F(x)) 0. !\n!',
#  'Exercise 5 In an elementary model, let p be the price of a product and let D and S be the demand\nand supply, respectively. Let us suppose the functions of supply and demand linearly depend on p,\nfollowing the formulas\nD=a bp; S = c+dp\n) )\nwhere a;b;c;d are positive numbers. In this case, a price p of (static) equilibrium of the market exists.\nWe can Önd it by balancing supply and demand thus having\na+c\np/= :\nb+d\nLet us consider now that the market price varies in time p = p(t) and suppose that it is a linear\nfunction of the excess of demand D S. Assuming a continuous-time model, we have the equation\n)\np (t)=m(D S); (1)\n0\n)\nwhere m is a positive propensity coe¢cient.\n1. Solve the equation (1);\n2. Assuming that the initial price is p , determine the longtime behavior of the solution starting\n0\nfrom p .\n0\nSolution. Ouraimistoexaminethedynamicalstabilityconditionsofthemarket,i.e. theconditions\nthat make p(t) go the value p/while t . Replacing D and S in (1), we Önd the equation\n!1\np (t)=m(a bp+c dp):\n0\n) )\nLet us now arrange the terms and set g =m(b+d) and h=m(a+c). We get the linear di§erential\nequation with constant coe¢cients\np (t)= gp+h\n0\n)\nWe can immediately Önd the constant particular solution\np (t)=m(a bp+c dp)\n0\n) )\np(t)= h =p/whichagreeswiththestaticequilibriumprice. Usingtheintegrandfactortechnique, we\ng\ncan solve the linear di§erential equation and obtain\np(t)=ke gt+p/\n#\nwhere k R.\n2\n2. If the initial condition is p . We have that k =p p/. This implies that\n0 0\n)\np(t)=(p\n0\np/)e\n#\ngt+p/ t R:\n) 8 2\nIt follows that if t then p(t) p/. We thus deduce the asymptotic stability of the market\n! 1 !\ndynamics. Actually, the generatrix function is the straight y = gp + h, whose zero is the point\np= h g =p/. !',
#  'Exercise 6 Consider the reduced form problem\nmax 1 )t<(x ;x ) sub x 5(x ) t 0, x X given, (RF)\nt t+1 t+1 t 0\nx 2 8 ( 2\nt=0\nX\n1. DeÖne its value function and write its Bellman equation;\n2. State (without proof) the Bellman Theorem and discuss its importance;\n3. Consider the cake problem\nmax 1 )t(x x )) sub 0 x x ;x 0 given\nt t+1 t+1 t 0\nx ) & & (\nt=0\nX\nWrite its Bellman equation and solve it via the method of successive approximations.\nSolution. 1. See the lecture notes.\n2. See the lecture notes.\n3. See the lecture notes. !',
#  'Midterm Exam\nAdvanced Mathematics (Cod. 20136)\nSOLUTIONS\n22 October 2012\nExercise 1 Consider a metric space (X;d).\n1. DeÖne when a subset K of X is compact.\n2. Show that a compact subset K of X is closed.\n3. Show that a Önite set A= x ;:::;x is compact.\n1 n\nf g\nSolution.\nLecture notes. !\nExercise 2 This question has two parts:\n1. What is a basis?\n2. ShowthatasubsetS ofavectorspaceV isaÖnitebasisofV ifandonlyif\neach vector v V can be written in a unique way as a linear combination\n2\nof vectors in S.\nSolution.\nLecture notes. !\nExercise 3 Consider R n and a vector x$ R n. Say that x$ is orthogonal to y,\n2\nwritten x$ y, if and only if x$ y=0.1\n? %\n1. Prove that the set M x" = y R n :x$ y is a vector subspace of R n.\nf 2 ? g\n2. Assume that n=2 and x$ is equal to (0;1). What is M equal to?\nx"\n3. Assume that n=3 and x$ is equal to (0;0;0). What is M equal to?\nx"\n1Recallthattheinnerproductofywithx!is\nn\nx! y= x!iyi y R n:\n! 8 2\nXi=1\n1',
#  'Solution.\n1. Consider x;y M\nx"\nand .;/ R. It follows that x$ x=0=x$ y. Next,\n2 2 % %\nobserve that\nx$ (.x+/y)=x$ (.x)+x$ (/y)=.(x$ x)+/(x$ y)=.0+/0=0:\n% % % % %\nWe can conclude that x$ (.x+/y) = 0, that is, x$ (.x+/y), proving that\n% ?\nM is a vector subspace.\nx"\n2. If x$=(0;1), then x$ y if and only if x$ y=0, that is, y =0y +1y =\n2 1 2\n? %\nx$ y=0. It follows that M x" = y R 2 :y 2 =0 , the horizontal axis.\n% 2\n3. Observe that each vector y R 3 is such that (0;0;0) y = 0. Hence,\n! 2 " %\nM x" =R 3. !\nExercise 4 Consider a space X and two distances d and d . DeÖne d:X\n1 2\n&\nX [0; ) by d(x;y)=d (x;y)+d (x;y) for all x;y X.\n1 2\n! 1 2\n1. Prove that d is a distance.\n2. Show that a sequence x converges to x with respect to the distance\nd if and only if it conv f er n ge g s n 2to N x with respect to both distances d and d .\n1 2\nSolution.\n1. In order to prove that d is a distance we need to prove three things:\n(a) d(x;y)=0 if and only if x=y.\n(b) d(x;y)=d(y;x) for all x;y X.\n2\n(c) d(x;z) d(x;y)+d(y;z) for all x;y;z X.\n) 2\nProof of (a). Since d and d are two distances, d ;d 0, d (x;y) = 0 if\n1 2 1 2 1\n*\nand only if x = y, and d (x;y) = 0 if and only if x = y. If d(x;y) = 0 then\n2\nd (x;y)+d (x;y)=0. Sinced ;d 0,itfollowsthatd (x;y)=0=d (x;y).\n1 2 1 2 1 2\n*\nWe can conclude that x=y. On the other hand, if x=y then d (x;y)=0=\n1\nd 2 (x;y). It follows that d(x;y)=d 1 (x;y)+d 2 (x;y)=0. "\nProof of (b). Since d and d are two distances, d (x;y) = d (y;x) for all\n1 2 1 1\nx;y X and d (x;y) = d (y;x) for all x;y X. By deÖnition of d, we have\n2 2\n2 2\nthat for each x;y X\n2\nd(x;y)=d (x;y)+d (x;y)=d (y;x)+d (y;x)=d(y;x);\n1 2 1 2\nproving the statement. "\nProof of (c). Since d and d are two distances, we have that\n1 2\nd (x;z) d (x;y)+d (y;z) x;y;z X\n1 1 1\n) 8 2\nand\nd (x;z) d (x;y)+d (y;z) x;y;z X:\n2 2 2\n) 8 2\n2',
#  'By deÖnition of d, we have that for each x;y;z X\n2\nd(x;z) = d (x;z)+d (x;z)\n1 2\nd (x;y)+d (y;z)+d (x;y)+d (y;z)\n1 1 2 2\n)\n= d(x;y)+d(y;z);\nproving the statement. "\n2. "If". Since lim d (x ;x)=lim d (x ;x)=0, it follows that2\nn 1 n n 2 n\nlimd(x ;x)=lim(d (x ;x)+d (x ;x))=limd (x ;x)+limd (x ;x)=0\nn 1 n 2 n 1 n 2 n\nn n n n\nd\nproving that x x.\nn\n!\nd\n"Only if". Fix ">0. Since x n x, there exists n " N such that\n! 2\nd(x;x )<" n n :\nn "\n8 *\nBy deÖnition of d, we have that\n0 d (x;x )+d (x;x )<" n n :\n1 n 2 n "\n) 8 *\nWe can conclude that\nd (x;x ) < " n n\n1 n "\n8 *\nand\nd (x;x ) < " n n ;\n2 n "\n8 *\nproving that x n\nd1\nx and x n\nd2\nx, since " was arbitrary. !\n! !\n2Recallthatthelimitofasum ofsequencesisthesum oftheirlimitsprovidedtheyexist.\nTheconverseis,ingeneral,false(e.g., n and n divergethoughtheirsumistheconstant\nf g f& g\nsequenceofzeros).\n3']

# %%
exam_pattern = r'(General|Midterm)\s+Exam.*?([A-Za-z]+\s+\d{1,2},\s+\d{4})'
#exam_pattern = r'(Advanced Mathematics)\s+Exam.*?([A-Za-z]+\s+\d{1,2},\s+\d{4})'
question_pattern = r'(Exercise)\s+Exam.*?([A-Za-z])'
solution_pattern = r'(Solution)\s+Exam.*?([A-Za-z]+\s+\d{1,2},\s+\d{4})'

# %%
# Dictionary to store classified exam data
classified_exams = {}

for exam_text in exams[1:]:
    #lines = exam_text.split('Exercise')
    current_exam_type = None
    current_date = None

    match = re.search(exam_pattern, exam_text)
    if match:
        exam_type = match.group(1)
        date_str = match.group(2)

        # Parse the date
        try:
            date_obj = datetime.strptime(date_str, '%B %d, %Y')
            formatted_date = date_obj.strftime('%Y-%m-%d')

            exam_key = f"{exam_type}_{formatted_date}"
            
            if exam_key not in classified_exams:
                classified_exams[exam_key] = {
                    'type': exam_type,
                    'date': formatted_date,
                    'year': date_obj.year,
                    'month': date_obj.month,
                    'day': date_obj.day,
                    'content': []
                }
            current_exam_type = exam_type
            current_date = formatted_date
        except ValueError:
            continue
    
    else:
        content_ = classified_exams[exam_key]['content']
        content_ += [exam_text]
        classified_exams[exam_key] = {
                            'type': exam_type,
                            'date': formatted_date,
                            'year': date_obj.year,
                            'month': date_obj.month,
                            'day': date_obj.day,
                            'content': content_
                        }
        
        # If we have identified an exam type/date, store the line
    if current_exam_type and current_date:
        exam_key = f"{current_exam_type}_{current_date}"
        classified_exams[exam_key]['content'].append(exam_text)

# %%
del classified_exams['General_2013-01-23']

# %%
solution_pattern = r'(Solution)\s+Exam.*?([A-Za-z]+\s+\d{1,2},\s+\d{4})'

# %%
for question in classified_exams['General_2025-08-29']['content']:
    lines = exam_text.split('Exercise')
    match = re.search(question_pattern, question)

# %%
temp = classified_exams['General_2025-08-29']['content']

# %%
text_ = ' '.join(temp)

# %%
match = re.search('Exercise', text_)

# %%
match.group()
# Out:
# 'Exercise'

# %%
[x.strip() for x in text_.split('Exercise ')[1:]]
# Out:
# ['1 Consider a functional f : R n R. State and prove the Riesz representation theorem\n!\n(that is, the theorem that provides a characterization for linear functionals).\nSolution See the lecture notes. (cid:4)',
#  '2 Consider R n endowed with the d 1 distance.1 Consider a nonempty subset C of X. We\nsay that x in an algebraic interior point of C if and only if for each y R n there exists (cid:14) > 0 such\n2\nthat x+(cid:14)y C. We denote the set of all algebraic interior points of C by algC.\n2\n1. Prove that intC algC.\n(cid:18)\n2. Prove that if C is convex and x algC, then x C.\n2 2\n3. Prove that if C is convex, then intC = algC.\nSolution. 1. If intC = , then trivially we have that intC algC. If intC = , consider x intC.\n; (cid:18) 6 ; 2\nIt follows that there exists " > 0 such that B " (x) (cid:18) C. Consider y 2 R n. Set (cid:14) = k y k " 1 +1 > 0. Note\nthat d (x;x+(cid:14)y) = x+(cid:14)y x = (cid:14) y < ", proving that x+(cid:14)y B (x) C. Since x and y\n1 k (cid:0) k1 k k1 2 " (cid:18)\nwere arbitrarily chosen, it follows that x is an algebraic interior point of C whenever it is an interior\npoint of C, proving the point.\n2. Consider x algC and y R n. It follows that there exist (cid:14) + ;(cid:14) > 0 such that x+(cid:14) + y;x+\n2 2 (cid:0)\n(cid:14) ( y) C. Since C is convex, we can conclude that x+((cid:13)(cid:14) +(1 (cid:13))( (cid:14) ))y = (cid:13)(x+(cid:14) y)+\n+ +\n(cid:0) (cid:0) 2 (cid:0) (cid:0) (cid:0)\n(1 (cid:13))(x+(cid:14) ( y)) C for all (cid:13) [0;1]. In other words, x+(cid:14)y C for all (cid:14) [ (cid:14) ;(cid:14) ]. Since\n+\n(cid:0) (cid:0) (cid:0) 2 2 2 2 (cid:0) (cid:0)\n(cid:14) ;(cid:14) > 0, we have that 0 [ (cid:14) ;(cid:14) ], proving that x C.\n+ +\n3. (cid:0) Consider the canon 2 ica (cid:0) l b (cid:0) asis of R n: ei n .2 2 Consider x algC for each i 1;:::;n\ni=1 2 2 f g\nthere exist (cid:14) ;(cid:14) > 0 such that x + (cid:14) ei;x + (cid:14) ei C for all i 1;:::;n . De(cid:133)ne " =\nmin min +;i (cid:0) (cid:14) ;i ;min (cid:14) > + 0 ;i . B (cid:8) yt (cid:9) hep (cid:0) r ;i oo (cid:0) fofpo 2 int2,wehave 2 th f atx+"e g i;x+" ei\ni 1;:::;n +;i i 1;:::;n ;i\n2f g 2f g (cid:0) (cid:0) (cid:1) (cid:0) 2\nC for all i 1;:::;n . Consider y B (x). De(cid:133)ne z = y x. It follows that z = y x =\nd (x (cid:8) ;y) < " 2 . D f e(cid:133)ne (cid:22) g = z =" 0 f 2 or (cid:9) a " ll i 1;:::;n and (cid:22) (cid:0) = 1 n (cid:22) . k Ob k s 1 erve k th (cid:0) a (cid:0) t k1(cid:1)\n1 i j i j (cid:21) 2 f g n+1 (cid:0) i=1 i\nn n P\n" > z = z = " (cid:22) ;\nk k1 j i j i\ni=1 i=1\nX X\nproving that (cid:22) [0;1]. Moreover, we have that n+1(cid:22) = 1. By de(cid:133)nition of (cid:22) n+1, note that\nn+1 2 i=1 i f i gi=1\nn P\ny = x+z = x+ z ei = x+ "(cid:22) ei+ "(cid:22) ei\ni i i\n(cid:0)\nX\ni=1 i:\nX\nzi\n(cid:21)\n0 i:\nX\nzi<0\n(cid:0) (cid:1)\n= (cid:22) x+ (cid:22) x+"ei + (cid:22) x+" ei :\nn+1 i i\n(cid:0)\ni:\nX\nzi\n(cid:21)\n0\n(cid:0) (cid:1)\ni:\nX\nzi<0\n(cid:0) (cid:0) (cid:1)(cid:1)\nSince C is convex and x+(cid:14) ei;x+(cid:14) ei C for all i 1;:::;n , this implies that y is a convex\n+;i ;i\n(cid:0) (cid:0) 2 2 f g\nlinear combination of points which are in C and, in particular, y C. Since y was arbitrarily chosen,\n(cid:0) (cid:1) 2\nwe have that B (x) C, proving that x intC. Since x was arbitrarily chosen, algC intC. By\n"\n(cid:18) 2 (cid:18)\npoint 1, we can conclude that algC = intC. (cid:4)\nk x k2 1 1 G R = e iv c e a n ll n i i = th 1 a j x t 1 i d j ; 1 : f : o ( :; r x n ; a y ll , ) r x = ec 2 a P l R l n i n t = h . 1 a j t y i ei (cid:0) is x t i j he fo v r e a c l t l or x; in y R 2 n R s n u . ch R t e h c a a t ll it a s ls j o -t t h ha co t m d 1 po is ne i n n t du is ce 1 d (r b e y sp t . h 0 e ) n i o f r j m = k i k ( 1 re d sp e(cid:133) . n j e = d b i) y .\nP 2f g 6',
#  '3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\nSolution See the lecture notes. (cid:4)',
#  '4 Consider R n endowed with the supnorm .3 We say that an operator f : R n R n is\nk k !\nmonotone if and only if 1\nx y = f(x) f(y):4\n(cid:21) ) (cid:21)\nConsider two operators f;g : R n R n and assume they are both (cid:11)-contractions with (cid:11) (0;1).\n! 2\nDenote their unique (cid:133)xed points by x and x .\nf g\n1. Prove that if f g and f is monotone,5 then x x .\nf g\n(cid:21) (cid:21)\n2. Prove that if g = 1I + 1f,6 then x = x .\n2 2 f g\nSolution 1. By the Banach contraction principle and since (R n; ) is a complete metric space and\nk k\nf and g are (cid:11)-contractions, recall that 1\nlimfn(y) = x f and limgn(y) = x g y R n: (1)\nn n 8 2\nFix x R n. By induction, we will show that fn(x) gn(x) for all n N. Since f g, the inequality\n2 (cid:21) 2 (cid:21)\nfollows for n = 1, proving the initial step. Next assume the statement is true for n. We show it is\ntrue for n+1. Observe that fn+1(x) = f(fn(x)) f(gn(x)) g(gn(x)) = gn+1(x), proving the\n(cid:21) (cid:21)\ninductive step. By induction, the statement follows. By passing to the limit and (1), we can conclude\nthat\nx = limfn(x) limgn(x) = x ;\nf g\nn (cid:21) n\nproving the point.\n2. By the Banach contraction principle, observe that f and g admit each a unique (cid:133)xed point.\nNext, since x is a (cid:133)xed point of f, observe that\nf\n1 1 1 1\ng(x ) = I(x )+ f(x ) = x + x = x ;\nf f f f f f\n2 2 2 2\nproving that x is a (cid:133)xed point of g. Since the only (cid:133)xed point of g is x , we can conclude that\nf g\nx g = x f , proving the point. (cid:4)\n3 4 R R e e c c a a l l l l t t h h a a t t k x x k1y = if a m n a d x i o2nfl 1 y ;:: i : f ;n xgj x i j y fo f r o a r l a l l x l i 2 R n 1 . ;:::;n .\ni i\n5Recall that f (cid:21) g means that f(x) (cid:21) g(x) for a 2 ll f x R n. g\n6Recall that th (cid:21) e identity operator I i (cid:21) s such that I(x) 2 =x for all x R n.\n2',
#  '5 Consider a metric space (X;d) and a continuous function f : X R. Assume C is a\n!\nclosed and bounded subset of X. Is it always true that f admits a maximizer on C, that is,\nmaxf(x) subject to x C\n2\nadmits solution?\nSolution No! ConsiderX = Nendowedwiththediscretedistanced(cid:22).7 SetC = N. Considerf : N R\n!\nde(cid:133)ned by f(n) = n for all n N. Note that:\n2\n1. Since in any metric space X is open and closed, so is C = X.\n2. Since d = d(cid:22), we have that B 2 (1) = n N : d(cid:22)(1;n) < 2 = N = C, proving that C is bounded.\n2\nd(cid:22) (cid:8) (cid:9)\n3. Recall that x n x if and only if there exists n(cid:22) N such that x n = x for all n n(cid:22) (cf. Exercise\n! 2 (cid:21)\n4, October 2014 and 2013). Indeed, we have that\nx n\nd(cid:22)\nx " > 0; n " N s.t. d(cid:22)(x n ;x) < " n n " = n 1=2 N s.t. d(cid:22)(x n ;x) < 1=2 n n 1=2\n! () 8 9 2 8 (cid:21) ) 9 2 8 (cid:21)\n= n 1=2 N s.t. d(cid:22)(x n ;x) = 0 n n 1=2 = x n = x n n 1=2 :\n) 9 2 8 (cid:21) ) 8 (cid:21)\nViceversa, we have that\nn(cid:22) N s.t. x n = x n n(cid:22) = " > 0; n " = n(cid:22) N s.t. d(cid:22)(x n ;x) = 0 < " n n " = x n\nd(cid:22)\nx:\n9 2 8 (cid:21) ) 8 9 2 8 (cid:21) ) !\n4. By point 3, we have that\nd(cid:22)\nx n x n(cid:22) N s.t. x n = x n n(cid:22) = n(cid:22) N s.t. f(x n ) = f(x) n n(cid:22) = f(x n ) f(x);\n! () 9 2 8 (cid:21) ) 9 2 8 (cid:21) ) !\nproving continuity of f.\nThus, our choice of X, d, C, and f (cid:133)ts the requirements above. Yet, f does not admit a maximizer\non C. By contradiction, assume that n(cid:22) C = N is a maximizer, that is, f(n(cid:22)) f(n) for all\n2 (cid:21)\nn C = N. Consider n^ = n(cid:22) +1. We have that f(n^) = f(n(cid:22)+1) = n(cid:22) +1 > n(cid:22) = f(n(cid:22)) f(n^), a\n2 (cid:21)\ncontradiction. (cid:4)\n7Recall that d(cid:22)(x;y)=1 if and only if x=y and d(cid:22)(x;y)=0 if and only if x=y.\n6',
#  '6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.\nSolution See the lecture notes. (cid:4) EXTRA PAGE']

# %%
for x in [x.split('Solution') for x in [x.strip() for x in text_.split('Exercise ')[1:]] ]:
    print(x)
# Out:
# ['1 Consider a functional f : R n R. State and prove the Riesz representation theorem\n!\n(that is, the theorem that provides a characterization for linear functionals).\n', ' See the lecture notes. (cid:4)']
# ['2 Consider R n endowed with the d 1 distance.1 Consider a nonempty subset C of X. We\nsay that x in an algebraic interior point of C if and only if for each y R n there exists (cid:14) > 0 such\n2\nthat x+(cid:14)y C. We denote the set of all algebraic interior points of C by algC.\n2\n1. Prove that intC algC.\n(cid:18)\n2. Prove that if C is convex and x algC, then x C.\n2 2\n3. Prove that if C is convex, then intC = algC.\n', '. 1. If intC = , then trivially we have that intC algC. If intC = , consider x intC.\n; (cid:18) 6 ; 2\nIt follows that there exists " > 0 such that B " (x) (cid:18) C. Consider y 2 R n. Set (cid:14) = k y k " 1 +1 > 0. Note\nthat d (x;x+(cid:14)y) = x+(cid:14)y x = (cid:14) y < ", proving that x+(cid:14)y B (x) C. Since x and y\n1 k (cid:0) k1 k k1 2 " (cid:18)\nwere arbitrarily chosen, it follows that x is an algebraic interior point of C whenever it is an interior\npoint of C, proving the point.\n2. Consider x algC and y R n. It follows that there exist (cid:14) + ;(cid:14) > 0 such that x+(cid:14) + y;x+\n2 2 (cid:0)\n(cid:14) ( y) C. Since C is convex, we can conclude that x+((cid:13)(cid:14) +(1 (cid:13))( (cid:14) ))y = (cid:13)(x+(cid:14) y)+\n+ +\n(cid:0) (cid:0) 2 (cid:0) (cid:0) (cid:0)\n(1 (cid:13))(x+(cid:14) ( y)) C for all (cid:13) [0;1]. In other words, x+(cid:14)y C for all (cid:14) [ (cid:14) ;(cid:14) ]. Since\n+\n(cid:0) (cid:0) (cid:0) 2 2 2 2 (cid:0) (cid:0)\n(cid:14) ;(cid:14) > 0, we have that 0 [ (cid:14) ;(cid:14) ], proving that x C.\n+ +\n3. (cid:0) Consider the canon 2 ica (cid:0) l b (cid:0) asis of R n: ei n .2 2 Consider x algC for each i 1;:::;n\ni=1 2 2 f g\nthere exist (cid:14) ;(cid:14) > 0 such that x + (cid:14) ei;x + (cid:14) ei C for all i 1;:::;n . De(cid:133)ne " =\nmin min +;i (cid:0) (cid:14) ;i ;min (cid:14) > + 0 ;i . B (cid:8) yt (cid:9) hep (cid:0) r ;i oo (cid:0) fofpo 2 int2,wehave 2 th f atx+"e g i;x+" ei\ni 1;:::;n +;i i 1;:::;n ;i\n2f g 2f g (cid:0) (cid:0) (cid:1) (cid:0) 2\nC for all i 1;:::;n . Consider y B (x). De(cid:133)ne z = y x. It follows that z = y x =\nd (x (cid:8) ;y) < " 2 . D f e(cid:133)ne (cid:22) g = z =" 0 f 2 or (cid:9) a " ll i 1;:::;n and (cid:22) (cid:0) = 1 n (cid:22) . k Ob k s 1 erve k th (cid:0) a (cid:0) t k1(cid:1)\n1 i j i j (cid:21) 2 f g n+1 (cid:0) i=1 i\nn n P\n" > z = z = " (cid:22) ;\nk k1 j i j i\ni=1 i=1\nX X\nproving that (cid:22) [0;1]. Moreover, we have that n+1(cid:22) = 1. By de(cid:133)nition of (cid:22) n+1, note that\nn+1 2 i=1 i f i gi=1\nn P\ny = x+z = x+ z ei = x+ "(cid:22) ei+ "(cid:22) ei\ni i i\n(cid:0)\nX\ni=1 i:\nX\nzi\n(cid:21)\n0 i:\nX\nzi<0\n(cid:0) (cid:1)\n= (cid:22) x+ (cid:22) x+"ei + (cid:22) x+" ei :\nn+1 i i\n(cid:0)\ni:\nX\nzi\n(cid:21)\n0\n(cid:0) (cid:1)\ni:\nX\nzi<0\n(cid:0) (cid:0) (cid:1)(cid:1)\nSince C is convex and x+(cid:14) ei;x+(cid:14) ei C for all i 1;:::;n , this implies that y is a convex\n+;i ;i\n(cid:0) (cid:0) 2 2 f g\nlinear combination of points which are in C and, in particular, y C. Since y was arbitrarily chosen,\n(cid:0) (cid:1) 2\nwe have that B (x) C, proving that x intC. Since x was arbitrarily chosen, algC intC. By\n"\n(cid:18) 2 (cid:18)\npoint 1, we can conclude that algC = intC. (cid:4)\nk x k2 1 1 G R = e iv c e a n ll n i i = th 1 a j x t 1 i d j ; 1 : f : o ( :; r x n ; a y ll , ) r x = ec 2 a P l R l n i n t = h . 1 a j t y i ei (cid:0) is x t i j he fo v r e a c l t l or x; in y R 2 n R s n u . ch R t e h c a a t ll it a s ls j o -t t h ha co t m d 1 po is ne i n n t du is ce 1 d (r b e y sp t . h 0 e ) n i o f r j m = k i k ( 1 re d sp e(cid:133) . n j e = d b i) y .\nP 2f g 6']
# ['3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\n', ' See the lecture notes. (cid:4)']
# ['4 Consider R n endowed with the supnorm .3 We say that an operator f : R n R n is\nk k !\nmonotone if and only if 1\nx y = f(x) f(y):4\n(cid:21) ) (cid:21)\nConsider two operators f;g : R n R n and assume they are both (cid:11)-contractions with (cid:11) (0;1).\n! 2\nDenote their unique (cid:133)xed points by x and x .\nf g\n1. Prove that if f g and f is monotone,5 then x x .\nf g\n(cid:21) (cid:21)\n2. Prove that if g = 1I + 1f,6 then x = x .\n2 2 f g\n', ' 1. By the Banach contraction principle and since (R n; ) is a complete metric space and\nk k\nf and g are (cid:11)-contractions, recall that 1\nlimfn(y) = x f and limgn(y) = x g y R n: (1)\nn n 8 2\nFix x R n. By induction, we will show that fn(x) gn(x) for all n N. Since f g, the inequality\n2 (cid:21) 2 (cid:21)\nfollows for n = 1, proving the initial step. Next assume the statement is true for n. We show it is\ntrue for n+1. Observe that fn+1(x) = f(fn(x)) f(gn(x)) g(gn(x)) = gn+1(x), proving the\n(cid:21) (cid:21)\ninductive step. By induction, the statement follows. By passing to the limit and (1), we can conclude\nthat\nx = limfn(x) limgn(x) = x ;\nf g\nn (cid:21) n\nproving the point.\n2. By the Banach contraction principle, observe that f and g admit each a unique (cid:133)xed point.\nNext, since x is a (cid:133)xed point of f, observe that\nf\n1 1 1 1\ng(x ) = I(x )+ f(x ) = x + x = x ;\nf f f f f f\n2 2 2 2\nproving that x is a (cid:133)xed point of g. Since the only (cid:133)xed point of g is x , we can conclude that\nf g\nx g = x f , proving the point. (cid:4)\n3 4 R R e e c c a a l l l l t t h h a a t t k x x k1y = if a m n a d x i o2nfl 1 y ;:: i : f ;n xgj x i j y fo f r o a r l a l l x l i 2 R n 1 . ;:::;n .\ni i\n5Recall that f (cid:21) g means that f(x) (cid:21) g(x) for a 2 ll f x R n. g\n6Recall that th (cid:21) e identity operator I i (cid:21) s such that I(x) 2 =x for all x R n.\n2']
# ['5 Consider a metric space (X;d) and a continuous function f : X R. Assume C is a\n!\nclosed and bounded subset of X. Is it always true that f admits a maximizer on C, that is,\nmaxf(x) subject to x C\n2\nadmits solution?\n', ' No! ConsiderX = Nendowedwiththediscretedistanced(cid:22).7 SetC = N. Considerf : N R\n!\nde(cid:133)ned by f(n) = n for all n N. Note that:\n2\n1. Since in any metric space X is open and closed, so is C = X.\n2. Since d = d(cid:22), we have that B 2 (1) = n N : d(cid:22)(1;n) < 2 = N = C, proving that C is bounded.\n2\nd(cid:22) (cid:8) (cid:9)\n3. Recall that x n x if and only if there exists n(cid:22) N such that x n = x for all n n(cid:22) (cf. Exercise\n! 2 (cid:21)\n4, October 2014 and 2013). Indeed, we have that\nx n\nd(cid:22)\nx " > 0; n " N s.t. d(cid:22)(x n ;x) < " n n " = n 1=2 N s.t. d(cid:22)(x n ;x) < 1=2 n n 1=2\n! () 8 9 2 8 (cid:21) ) 9 2 8 (cid:21)\n= n 1=2 N s.t. d(cid:22)(x n ;x) = 0 n n 1=2 = x n = x n n 1=2 :\n) 9 2 8 (cid:21) ) 8 (cid:21)\nViceversa, we have that\nn(cid:22) N s.t. x n = x n n(cid:22) = " > 0; n " = n(cid:22) N s.t. d(cid:22)(x n ;x) = 0 < " n n " = x n\nd(cid:22)\nx:\n9 2 8 (cid:21) ) 8 9 2 8 (cid:21) ) !\n4. By point 3, we have that\nd(cid:22)\nx n x n(cid:22) N s.t. x n = x n n(cid:22) = n(cid:22) N s.t. f(x n ) = f(x) n n(cid:22) = f(x n ) f(x);\n! () 9 2 8 (cid:21) ) 9 2 8 (cid:21) ) !\nproving continuity of f.\nThus, our choice of X, d, C, and f (cid:133)ts the requirements above. Yet, f does not admit a maximizer\non C. By contradiction, assume that n(cid:22) C = N is a maximizer, that is, f(n(cid:22)) f(n) for all\n2 (cid:21)\nn C = N. Consider n^ = n(cid:22) +1. We have that f(n^) = f(n(cid:22)+1) = n(cid:22) +1 > n(cid:22) = f(n(cid:22)) f(n^), a\n2 (cid:21)\ncontradiction. (cid:4)\n7Recall that d(cid:22)(x;y)=1 if and only if x=y and d(cid:22)(x;y)=0 if and only if x=y.\n6']
# ['6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.\n', ' See the lecture notes. (cid:4) EXTRA PAGE']

# %%
for exam_key in classified_exams:
    full_text = ' '.join(classified_exams[exam_key]['content'])
    #classified_exams[exam_key]['questions'] = {}
    
    questions = [x.strip() for x in re.split(r'Exercise\s*\d+', full_text)[1:]]
    questions = [x.split('Solution') for x in questions ]

    classified_exams[exam_key]['questions'] = {}

    for i,q in enumerate(questions):
        classified_exams[exam_key]['questions']['Exercise '+str(i+1)] = {}
        classified_exams[exam_key]['questions']['Exercise '+str(i+1)]['question'] = q[0].strip()
        if len(q) > 1:
            classified_exams[exam_key]['questions']['Exercise '+str(i+1)]['solution'] = q[1].strip()

# %%
classified_exams
# Out:
# {'General_2025-08-29': {'type': 'General',
#   'date': '2025-08-29',
#   'year': 2025,
#   'month': 8,
#   'day': 29,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)August 29, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Consider a functional f : R n R. State and prove the Riesz representation theorem\n!\n(that is, the theorem that provides a characterization for linear functionals).\nSolution See the lecture notes. (cid:4)',
#    'Exercise 2 Consider R n endowed with the d 1 distance.1 Consider a nonempty subset C of X. We\nsay that x in an algebraic interior point of C if and only if for each y R n there exists (cid:14) > 0 such\n2\nthat x+(cid:14)y C. We denote the set of all algebraic interior points of C by algC.\n2\n1. Prove that intC algC.\n(cid:18)\n2. Prove that if C is convex and x algC, then x C.\n2 2\n3. Prove that if C is convex, then intC = algC.\nSolution. 1. If intC = , then trivially we have that intC algC. If intC = , consider x intC.\n; (cid:18) 6 ; 2\nIt follows that there exists " > 0 such that B " (x) (cid:18) C. Consider y 2 R n. Set (cid:14) = k y k " 1 +1 > 0. Note\nthat d (x;x+(cid:14)y) = x+(cid:14)y x = (cid:14) y < ", proving that x+(cid:14)y B (x) C. Since x and y\n1 k (cid:0) k1 k k1 2 " (cid:18)\nwere arbitrarily chosen, it follows that x is an algebraic interior point of C whenever it is an interior\npoint of C, proving the point.\n2. Consider x algC and y R n. It follows that there exist (cid:14) + ;(cid:14) > 0 such that x+(cid:14) + y;x+\n2 2 (cid:0)\n(cid:14) ( y) C. Since C is convex, we can conclude that x+((cid:13)(cid:14) +(1 (cid:13))( (cid:14) ))y = (cid:13)(x+(cid:14) y)+\n+ +\n(cid:0) (cid:0) 2 (cid:0) (cid:0) (cid:0)\n(1 (cid:13))(x+(cid:14) ( y)) C for all (cid:13) [0;1]. In other words, x+(cid:14)y C for all (cid:14) [ (cid:14) ;(cid:14) ]. Since\n+\n(cid:0) (cid:0) (cid:0) 2 2 2 2 (cid:0) (cid:0)\n(cid:14) ;(cid:14) > 0, we have that 0 [ (cid:14) ;(cid:14) ], proving that x C.\n+ +\n3. (cid:0) Consider the canon 2 ica (cid:0) l b (cid:0) asis of R n: ei n .2 2 Consider x algC for each i 1;:::;n\ni=1 2 2 f g\nthere exist (cid:14) ;(cid:14) > 0 such that x + (cid:14) ei;x + (cid:14) ei C for all i 1;:::;n . De(cid:133)ne " =\nmin min +;i (cid:0) (cid:14) ;i ;min (cid:14) > + 0 ;i . B (cid:8) yt (cid:9) hep (cid:0) r ;i oo (cid:0) fofpo 2 int2,wehave 2 th f atx+"e g i;x+" ei\ni 1;:::;n +;i i 1;:::;n ;i\n2f g 2f g (cid:0) (cid:0) (cid:1) (cid:0) 2\nC for all i 1;:::;n . Consider y B (x). De(cid:133)ne z = y x. It follows that z = y x =\nd (x (cid:8) ;y) < " 2 . D f e(cid:133)ne (cid:22) g = z =" 0 f 2 or (cid:9) a " ll i 1;:::;n and (cid:22) (cid:0) = 1 n (cid:22) . k Ob k s 1 erve k th (cid:0) a (cid:0) t k1(cid:1)\n1 i j i j (cid:21) 2 f g n+1 (cid:0) i=1 i\nn n P\n" > z = z = " (cid:22) ;\nk k1 j i j i\ni=1 i=1\nX X\nproving that (cid:22) [0;1]. Moreover, we have that n+1(cid:22) = 1. By de(cid:133)nition of (cid:22) n+1, note that\nn+1 2 i=1 i f i gi=1\nn P\ny = x+z = x+ z ei = x+ "(cid:22) ei+ "(cid:22) ei\ni i i\n(cid:0)\nX\ni=1 i:\nX\nzi\n(cid:21)\n0 i:\nX\nzi<0\n(cid:0) (cid:1)\n= (cid:22) x+ (cid:22) x+"ei + (cid:22) x+" ei :\nn+1 i i\n(cid:0)\ni:\nX\nzi\n(cid:21)\n0\n(cid:0) (cid:1)\ni:\nX\nzi<0\n(cid:0) (cid:0) (cid:1)(cid:1)\nSince C is convex and x+(cid:14) ei;x+(cid:14) ei C for all i 1;:::;n , this implies that y is a convex\n+;i ;i\n(cid:0) (cid:0) 2 2 f g\nlinear combination of points which are in C and, in particular, y C. Since y was arbitrarily chosen,\n(cid:0) (cid:1) 2\nwe have that B (x) C, proving that x intC. Since x was arbitrarily chosen, algC intC. By\n"\n(cid:18) 2 (cid:18)\npoint 1, we can conclude that algC = intC. (cid:4)\nk x k2 1 1 G R = e iv c e a n ll n i i = th 1 a j x t 1 i d j ; 1 : f : o ( :; r x n ; a y ll , ) r x = ec 2 a P l R l n i n t = h . 1 a j t y i ei (cid:0) is x t i j he fo v r e a c l t l or x; in y R 2 n R s n u . ch R t e h c a a t ll it a s ls j o -t t h ha co t m d 1 po is ne i n n t du is ce 1 d (r b e y sp t . h 0 e ) n i o f r j m = k i k ( 1 re d sp e(cid:133) . n j e = d b i) y .\nP 2f g 6',
#    'Exercise 3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\nSolution See the lecture notes. (cid:4)',
#    'Exercise 4 Consider R n endowed with the supnorm .3 We say that an operator f : R n R n is\nk k !\nmonotone if and only if 1\nx y = f(x) f(y):4\n(cid:21) ) (cid:21)\nConsider two operators f;g : R n R n and assume they are both (cid:11)-contractions with (cid:11) (0;1).\n! 2\nDenote their unique (cid:133)xed points by x and x .\nf g\n1. Prove that if f g and f is monotone,5 then x x .\nf g\n(cid:21) (cid:21)\n2. Prove that if g = 1I + 1f,6 then x = x .\n2 2 f g\nSolution 1. By the Banach contraction principle and since (R n; ) is a complete metric space and\nk k\nf and g are (cid:11)-contractions, recall that 1\nlimfn(y) = x f and limgn(y) = x g y R n: (1)\nn n 8 2\nFix x R n. By induction, we will show that fn(x) gn(x) for all n N. Since f g, the inequality\n2 (cid:21) 2 (cid:21)\nfollows for n = 1, proving the initial step. Next assume the statement is true for n. We show it is\ntrue for n+1. Observe that fn+1(x) = f(fn(x)) f(gn(x)) g(gn(x)) = gn+1(x), proving the\n(cid:21) (cid:21)\ninductive step. By induction, the statement follows. By passing to the limit and (1), we can conclude\nthat\nx = limfn(x) limgn(x) = x ;\nf g\nn (cid:21) n\nproving the point.\n2. By the Banach contraction principle, observe that f and g admit each a unique (cid:133)xed point.\nNext, since x is a (cid:133)xed point of f, observe that\nf\n1 1 1 1\ng(x ) = I(x )+ f(x ) = x + x = x ;\nf f f f f f\n2 2 2 2\nproving that x is a (cid:133)xed point of g. Since the only (cid:133)xed point of g is x , we can conclude that\nf g\nx g = x f , proving the point. (cid:4)\n3 4 R R e e c c a a l l l l t t h h a a t t k x x k1y = if a m n a d x i o2nfl 1 y ;:: i : f ;n xgj x i j y fo f r o a r l a l l x l i 2 R n 1 . ;:::;n .\ni i\n5Recall that f (cid:21) g means that f(x) (cid:21) g(x) for a 2 ll f x R n. g\n6Recall that th (cid:21) e identity operator I i (cid:21) s such that I(x) 2 =x for all x R n.\n2',
#    'Exercise 5 Consider a metric space (X;d) and a continuous function f : X R. Assume C is a\n!\nclosed and bounded subset of X. Is it always true that f admits a maximizer on C, that is,\nmaxf(x) subject to x C\n2\nadmits solution?\nSolution No! ConsiderX = Nendowedwiththediscretedistanced(cid:22).7 SetC = N. Considerf : N R\n!\nde(cid:133)ned by f(n) = n for all n N. Note that:\n2\n1. Since in any metric space X is open and closed, so is C = X.\n2. Since d = d(cid:22), we have that B 2 (1) = n N : d(cid:22)(1;n) < 2 = N = C, proving that C is bounded.\n2\nd(cid:22) (cid:8) (cid:9)\n3. Recall that x n x if and only if there exists n(cid:22) N such that x n = x for all n n(cid:22) (cf. Exercise\n! 2 (cid:21)\n4, October 2014 and 2013). Indeed, we have that\nx n\nd(cid:22)\nx " > 0; n " N s.t. d(cid:22)(x n ;x) < " n n " = n 1=2 N s.t. d(cid:22)(x n ;x) < 1=2 n n 1=2\n! () 8 9 2 8 (cid:21) ) 9 2 8 (cid:21)\n= n 1=2 N s.t. d(cid:22)(x n ;x) = 0 n n 1=2 = x n = x n n 1=2 :\n) 9 2 8 (cid:21) ) 8 (cid:21)\nViceversa, we have that\nn(cid:22) N s.t. x n = x n n(cid:22) = " > 0; n " = n(cid:22) N s.t. d(cid:22)(x n ;x) = 0 < " n n " = x n\nd(cid:22)\nx:\n9 2 8 (cid:21) ) 8 9 2 8 (cid:21) ) !\n4. By point 3, we have that\nd(cid:22)\nx n x n(cid:22) N s.t. x n = x n n(cid:22) = n(cid:22) N s.t. f(x n ) = f(x) n n(cid:22) = f(x n ) f(x);\n! () 9 2 8 (cid:21) ) 9 2 8 (cid:21) ) !\nproving continuity of f.\nThus, our choice of X, d, C, and f (cid:133)ts the requirements above. Yet, f does not admit a maximizer\non C. By contradiction, assume that n(cid:22) C = N is a maximizer, that is, f(n(cid:22)) f(n) for all\n2 (cid:21)\nn C = N. Consider n^ = n(cid:22) +1. We have that f(n^) = f(n(cid:22)+1) = n(cid:22) +1 > n(cid:22) = f(n(cid:22)) f(n^), a\n2 (cid:21)\ncontradiction. (cid:4)\n7Recall that d(cid:22)(x;y)=1 if and only if x=y and d(cid:22)(x;y)=0 if and only if x=y.\n6',
#    'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.\nSolution See the lecture notes. (cid:4)',
#    'EXTRA PAGE'],
#   'questions': {'Exercise 1': {'question': 'Consider a functional f : R n R. State and prove the Riesz representation theorem\n!\n(that is, the theorem that provides a characterization for linear functionals).',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 2': {'question': 'Consider R n endowed with the d 1 distance.1 Consider a nonempty subset C of X. We\nsay that x in an algebraic interior point of C if and only if for each y R n there exists (cid:14) > 0 such\n2\nthat x+(cid:14)y C. We denote the set of all algebraic interior points of C by algC.\n2\n1. Prove that intC algC.\n(cid:18)\n2. Prove that if C is convex and x algC, then x C.\n2 2\n3. Prove that if C is convex, then intC = algC.',
#     'solution': '. 1. If intC = , then trivially we have that intC algC. If intC = , consider x intC.\n; (cid:18) 6 ; 2\nIt follows that there exists " > 0 such that B " (x) (cid:18) C. Consider y 2 R n. Set (cid:14) = k y k " 1 +1 > 0. Note\nthat d (x;x+(cid:14)y) = x+(cid:14)y x = (cid:14) y < ", proving that x+(cid:14)y B (x) C. Since x and y\n1 k (cid:0) k1 k k1 2 " (cid:18)\nwere arbitrarily chosen, it follows that x is an algebraic interior point of C whenever it is an interior\npoint of C, proving the point.\n2. Consider x algC and y R n. It follows that there exist (cid:14) + ;(cid:14) > 0 such that x+(cid:14) + y;x+\n2 2 (cid:0)\n(cid:14) ( y) C. Since C is convex, we can conclude that x+((cid:13)(cid:14) +(1 (cid:13))( (cid:14) ))y = (cid:13)(x+(cid:14) y)+\n+ +\n(cid:0) (cid:0) 2 (cid:0) (cid:0) (cid:0)\n(1 (cid:13))(x+(cid:14) ( y)) C for all (cid:13) [0;1]. In other words, x+(cid:14)y C for all (cid:14) [ (cid:14) ;(cid:14) ]. Since\n+\n(cid:0) (cid:0) (cid:0) 2 2 2 2 (cid:0) (cid:0)\n(cid:14) ;(cid:14) > 0, we have that 0 [ (cid:14) ;(cid:14) ], proving that x C.\n+ +\n3. (cid:0) Consider the canon 2 ica (cid:0) l b (cid:0) asis of R n: ei n .2 2 Consider x algC for each i 1;:::;n\ni=1 2 2 f g\nthere exist (cid:14) ;(cid:14) > 0 such that x + (cid:14) ei;x + (cid:14) ei C for all i 1;:::;n . De(cid:133)ne " =\nmin min +;i (cid:0) (cid:14) ;i ;min (cid:14) > + 0 ;i . B (cid:8) yt (cid:9) hep (cid:0) r ;i oo (cid:0) fofpo 2 int2,wehave 2 th f atx+"e g i;x+" ei\ni 1;:::;n +;i i 1;:::;n ;i\n2f g 2f g (cid:0) (cid:0) (cid:1) (cid:0) 2\nC for all i 1;:::;n . Consider y B (x). De(cid:133)ne z = y x. It follows that z = y x =\nd (x (cid:8) ;y) < " 2 . D f e(cid:133)ne (cid:22) g = z =" 0 f 2 or (cid:9) a " ll i 1;:::;n and (cid:22) (cid:0) = 1 n (cid:22) . k Ob k s 1 erve k th (cid:0) a (cid:0) t k1(cid:1)\n1 i j i j (cid:21) 2 f g n+1 (cid:0) i=1 i\nn n P\n" > z = z = " (cid:22) ;\nk k1 j i j i\ni=1 i=1\nX X\nproving that (cid:22) [0;1]. Moreover, we have that n+1(cid:22) = 1. By de(cid:133)nition of (cid:22) n+1, note that\nn+1 2 i=1 i f i gi=1\nn P\ny = x+z = x+ z ei = x+ "(cid:22) ei+ "(cid:22) ei\ni i i\n(cid:0)\nX\ni=1 i:\nX\nzi\n(cid:21)\n0 i:\nX\nzi<0\n(cid:0) (cid:1)\n= (cid:22) x+ (cid:22) x+"ei + (cid:22) x+" ei :\nn+1 i i\n(cid:0)\ni:\nX\nzi\n(cid:21)\n0\n(cid:0) (cid:1)\ni:\nX\nzi<0\n(cid:0) (cid:0) (cid:1)(cid:1)\nSince C is convex and x+(cid:14) ei;x+(cid:14) ei C for all i 1;:::;n , this implies that y is a convex\n+;i ;i\n(cid:0) (cid:0) 2 2 f g\nlinear combination of points which are in C and, in particular, y C. Since y was arbitrarily chosen,\n(cid:0) (cid:1) 2\nwe have that B (x) C, proving that x intC. Since x was arbitrarily chosen, algC intC. By\n"\n(cid:18) 2 (cid:18)\npoint 1, we can conclude that algC = intC. (cid:4)\nk x k2 1 1 G R = e iv c e a n ll n i i = th 1 a j x t 1 i d j ; 1 : f : o ( :; r x n ; a y ll , ) r x = ec 2 a P l R l n i n t = h . 1 a j t y i ei (cid:0) is x t i j he fo v r e a c l t l or x; in y R 2 n R s n u . ch R t e h c a a t ll it a s ls j o -t t h ha co t m d 1 po is ne i n n t du is ce 1 d (r b e y sp t . h 0 e ) n i o f r j m = k i k ( 1 re d sp e(cid:133) . n j e = d b i) y .\nP 2f g 6'},
#    'Exercise 3': {'question': 'Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 4': {'question': 'Consider R n endowed with the supnorm .3 We say that an operator f : R n R n is\nk k !\nmonotone if and only if 1\nx y = f(x) f(y):4\n(cid:21) ) (cid:21)\nConsider two operators f;g : R n R n and assume they are both (cid:11)-contractions with (cid:11) (0;1).\n! 2\nDenote their unique (cid:133)xed points by x and x .\nf g\n1. Prove that if f g and f is monotone,5 then x x .\nf g\n(cid:21) (cid:21)\n2. Prove that if g = 1I + 1f,6 then x = x .\n2 2 f g',
#     'solution': '1. By the Banach contraction principle and since (R n; ) is a complete metric space and\nk k\nf and g are (cid:11)-contractions, recall that 1\nlimfn(y) = x f and limgn(y) = x g y R n: (1)\nn n 8 2\nFix x R n. By induction, we will show that fn(x) gn(x) for all n N. Since f g, the inequality\n2 (cid:21) 2 (cid:21)\nfollows for n = 1, proving the initial step. Next assume the statement is true for n. We show it is\ntrue for n+1. Observe that fn+1(x) = f(fn(x)) f(gn(x)) g(gn(x)) = gn+1(x), proving the\n(cid:21) (cid:21)\ninductive step. By induction, the statement follows. By passing to the limit and (1), we can conclude\nthat\nx = limfn(x) limgn(x) = x ;\nf g\nn (cid:21) n\nproving the point.\n2. By the Banach contraction principle, observe that f and g admit each a unique (cid:133)xed point.\nNext, since x is a (cid:133)xed point of f, observe that\nf\n1 1 1 1\ng(x ) = I(x )+ f(x ) = x + x = x ;\nf f f f f f\n2 2 2 2\nproving that x is a (cid:133)xed point of g. Since the only (cid:133)xed point of g is x , we can conclude that\nf g\nx g = x f , proving the point. (cid:4)\n3 4 R R e e c c a a l l l l t t h h a a t t k x x k1y = if a m n a d x i o2nfl 1 y ;:: i : f ;n xgj x i j y fo f r o a r l a l l x l i 2 R n 1 . ;:::;n .\ni i\n5Recall that f (cid:21) g means that f(x) (cid:21) g(x) for a 2 ll f x R n. g\n6Recall that th (cid:21) e identity operator I i (cid:21) s such that I(x) 2 =x for all x R n.\n2'},
#    'Exercise 5': {'question': 'Consider a metric space (X;d) and a continuous function f : X R. Assume C is a\n!\nclosed and bounded subset of X. Is it always true that f admits a maximizer on C, that is,\nmaxf(x) subject to x C\n2\nadmits solution?',
#     'solution': 'No! ConsiderX = Nendowedwiththediscretedistanced(cid:22).7 SetC = N. Considerf : N R\n!\nde(cid:133)ned by f(n) = n for all n N. Note that:\n2\n1. Since in any metric space X is open and closed, so is C = X.\n2. Since d = d(cid:22), we have that B 2 (1) = n N : d(cid:22)(1;n) < 2 = N = C, proving that C is bounded.\n2\nd(cid:22) (cid:8) (cid:9)\n3. Recall that x n x if and only if there exists n(cid:22) N such that x n = x for all n n(cid:22) (cf. Exercise\n! 2 (cid:21)\n4, October 2014 and 2013). Indeed, we have that\nx n\nd(cid:22)\nx " > 0; n " N s.t. d(cid:22)(x n ;x) < " n n " = n 1=2 N s.t. d(cid:22)(x n ;x) < 1=2 n n 1=2\n! () 8 9 2 8 (cid:21) ) 9 2 8 (cid:21)\n= n 1=2 N s.t. d(cid:22)(x n ;x) = 0 n n 1=2 = x n = x n n 1=2 :\n) 9 2 8 (cid:21) ) 8 (cid:21)\nViceversa, we have that\nn(cid:22) N s.t. x n = x n n(cid:22) = " > 0; n " = n(cid:22) N s.t. d(cid:22)(x n ;x) = 0 < " n n " = x n\nd(cid:22)\nx:\n9 2 8 (cid:21) ) 8 9 2 8 (cid:21) ) !\n4. By point 3, we have that\nd(cid:22)\nx n x n(cid:22) N s.t. x n = x n n(cid:22) = n(cid:22) N s.t. f(x n ) = f(x) n n(cid:22) = f(x n ) f(x);\n! () 9 2 8 (cid:21) ) 9 2 8 (cid:21) ) !\nproving continuity of f.\nThus, our choice of X, d, C, and f (cid:133)ts the requirements above. Yet, f does not admit a maximizer\non C. By contradiction, assume that n(cid:22) C = N is a maximizer, that is, f(n(cid:22)) f(n) for all\n2 (cid:21)\nn C = N. Consider n^ = n(cid:22) +1. We have that f(n^) = f(n(cid:22)+1) = n(cid:22) +1 > n(cid:22) = f(n(cid:22)) f(n^), a\n2 (cid:21)\ncontradiction. (cid:4)\n7Recall that d(cid:22)(x;y)=1 if and only if x=y and d(cid:22)(x;y)=0 if and only if x=y.\n6'},
#    'Exercise 6': {'question': 'Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.',
#     'solution': 'See the lecture notes. (cid:4) EXTRA PAGE'}}},
#  'General_2025-01-27': {'type': 'General',
#   'date': '2025-01-27',
#   'year': 2025,
#   'month': 1,
#   'day': 27,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 27, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let S be a nonempty subset of a vector space V.\n1. De(cid:133)ne spanS.\n2. Fix n\n2\nN. If S =\nf\nx\ni g\nn\ni=1\n, show that\nn\nspanS = x 2 V : 9f (cid:11) i g n i=1 (cid:18) R s.t. x = (cid:11) i x i :\n( )\ni=1\nX\nSolution See the lecture notes. (cid:4)',
#    'Exercise 2 Let (X;d) be a metric space and D a subsetof X such that cl(D) = X.1 Prove that if\nA X is closed and such that cl(intA) = A, then cl(A D) = A.\n(cid:18) \\\nSolution. Since cl(intA) = A, A is empty if and only if intA is empty. If A is empty, trivially, we\nhave that cl(A D) = cl( ) = = A. If A is not empty, we have that intA = . Fix x intA. Since\n\\ ; ; 6 ; 2\ncl(D) = X, there exists a sequence x D such that x x. Since x intA and the latter\nf n gn N (cid:18) n ! 2\nis open, this implies that there exists " >20 such that B (x) intA and, in particular, there exists\n"\n(cid:18)\nn " N such that x n B " (x) intA for all n n " . We can conclude that x cl(intA D). Since x\n2 2 (cid:18) (cid:21) 2 \\\nwas arbitrarily chosen, we have that\nintA cl(intA D) = A = cl(intA) cl(intA D) cl(A D) cl(A) = A;\n(cid:18) \\ ) (cid:18) \\ (cid:18) \\ (cid:18)\nproving the statement. (cid:4)\n1Inthisexercise,givenasubsetB ofX,bycl(B),wemeantheclosureofB,whichisalsodenotedasB(cid:22) inthelecture\nnotes.',
#    'Exercise 3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\nSolution See the lecture notes. (cid:4)',
#    'Exercise 4 Consider the space of real-valued bounded sequences, denoted ‘ , endowed with the sup-\n1\nnorm ,2 that is,\nk k\n1\n‘\n1\n= x RN : sup x\nn\n< :\n2 j j 1\n(cid:26) n N (cid:27)\n2\nLet T : ‘ ‘ be such that for each x ‘ we de(cid:133)ne ax = T (x) to be such that\n1 1 1\n! 2\nx +:::+x\nax\nn\n= 1\nn\nn\n8\nn\n2\nN: (1)\n1. Compute the operator norm of T. Motivate your answer!\n2. Is T a contraction? Motivate your answer!\nSolution 1. Fix x ‘ . Observe that\n1\n2\nn n\nx +:::+x 1 1\nj\nax\nn j\n= 1\nn\nn\n(cid:20) n j\nx\ni j (cid:20) n k\nx\nk\n=\nk\nx\nk 8\nn\n2\nN;\n(cid:12) (cid:12) i=1 i=1 1 1\n(cid:12) (cid:12) X X\n(cid:12) (cid:12)\nproving that sup ax(cid:12) x . By(cid:12)de(cid:133)nition of T and since x was arbitrarily chosen, it follows that\nn 2 Nj n j (cid:20) k k 1\nT (x) = sup ax x x ‘ :\nn 1\nk k j j (cid:20) k k 8 2\n1 n N 1\n2\nBy de(cid:133)nition of operator norm, we have that T 1. Next, consider the sequence e ‘ such that\n1\nk k (cid:20) 2\ne\nn\n= 1 for all n N. It follows that (cid:3)\n2\ne +:::+e\nae\nn\n= 1\nn\nn = 1\n8\nn\n2\nN;\nyieldingthatae = eand,inparticular, T (e) = ae = e . Bythecharacterizationofoperator\nk k k k k k\nnorm and since e = sup e = 1, we ha1ve that 1 1\nk k 1 n 2 Nj n j\nT = sup T (x) T (e) = 1:\nk k k k (cid:21) k k\n(cid:3) x ‘ : x =1 1 1\n2 1k k1\nWe can conclude that T = 1 (cf. Exercise 4, January 9th, 2023).\nk k\n(cid:3)\n2. No! Since T is linear, to be a contraction T needs to be such that T < 1, which is not the\nk k\ncase. Alternatively, you can check that it has more than one (cid:133)xed point, for ex(cid:3)ample, e and 0. (cid:4)\n2Recall that\nk\nx\nk1\n=sup\nn 2 Nj\nx\nn j\nfor all x\n2\n‘1.',
#    'Exercise 5 Consider a normed vector space X with norm and a nonempty closed subset C of X.\nk k\nDe(cid:133)ne f : X [0; ) by\n! 1\nf(x) = inf x y x X:\ny Ck (cid:0) k 8 2\n2\nProve that f is convex if and only if C is convex.\nSolution (cid:147)If(cid:148). Consider x\n0\n;x\n1\nX and (cid:21) (0;1). Consider n N. By de(cid:133)nition of inf and f, we\n2 2 2\nhave that there exist y ;y C such that\n0 1\n2\n1 1\nf(x ) = inf x y x y and f(x ) = inf x y x y :\n0 0 0 0 1 1 1 1\ny Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n y Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n\n2 2\nDe(cid:133)ne x = (cid:21)x +(1 (cid:21))x and y = (cid:21)y +(1 (cid:21))y . Since y ;y C and C is convex, we have\n(cid:21) 1 0 (cid:21) 1 0 0 1\n(cid:0) (cid:0) 2\nthat y C. By de(cid:133)nition of f, we can conclude that\n(cid:21)\n2\nf((cid:21)x +(1 (cid:21))x ) = f(x ) = inf x y x y\n1 0 (cid:21) (cid:21) (cid:21) (cid:21)\n(cid:0) y Ck (cid:0) k (cid:20) k (cid:0) k\n2\n= (cid:21)x +(1 (cid:21))x (cid:21)y (1 (cid:21))y = (cid:21)(x y )+(1 (cid:21))(x y )\n1 0 1 0 1 1 0 0\nk (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 1\n(cid:21) x y +(1 (cid:21)) x y (cid:21) f(x )+ +(1 (cid:21)) f(x )+\n1 1 0 0 0 1\n(cid:20) k (cid:0) k (cid:0) k (cid:0) k (cid:20) n (cid:0) n\n(cid:18) (cid:19) (cid:18) (cid:19)\n1\n= (cid:21)f(x )+(1 (cid:21))f(x )+ :\n0 1\n(cid:0) n\nSince x , x , (cid:21), and n were arbitrarily chosen, f is convex and the implication follows (cf. Exercise 4\n0 1\nof the exams of September 2020 or January 8th, 2020).\n(cid:147)Only if(cid:148). First, observe that\nx C f(x) = 0: (2)\n2 ()\nIn fact, by de(cid:133)nition of f, we have that\nx C = 0 = x x inf x y = f(x) 0:\n2 ) k (cid:0) k (cid:21) y Ck (cid:0) k (cid:21)\n2\nMoreover, if inf x y = 0, then there exists a sequence y C such that x y\ninf x y = y 2 f C ( k x) (cid:0) = 0 k . Since C is closed, this implies that f y n gn 2x N , (cid:18) proving that x k C (cid:0) . W n k ith #\ny C n\n2 k (cid:0) k ! 2\nthis, take x ;x C and (cid:21) (0;1). By (2) and since f is convex and x ;x C, we can conclude\n1 0 1 0\n2 2 2\nthat\n0 f((cid:21)x +(1 (cid:21))x ) (cid:21)f(x )+(1 (cid:21))f(x ) = 0 = f((cid:21)x +(1 (cid:21))x ) = 0 = (cid:21)x +(1 (cid:21))x C:\n1 0 1 0 1 0 1 0\n(cid:20) (cid:0) (cid:20) (cid:0) ) (cid:0) ) (cid:0) 2\nSince x 0 , x 1 , and (cid:21) were arbitrarily chosen, C is convex and the implication follows. (cid:4)',
#    'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. De(cid:133)ne the optimal policy correspondence and the optimal policy function.\n2. De(cid:133)ne when a path x =(x ;x ;x ;:::) is sequentially optimal for problem RF (x ).\n0 1 2 0\nSolution 1. See the lecture notes.\n2. See the lecture notes. (cid:4)',
#    'EXTRA PAGE'],
#   'questions': {'Exercise 1': {'question': 'Let S be a nonempty subset of a vector space V.\n1. De(cid:133)ne spanS.\n2. Fix n\n2\nN. If S =\nf\nx\ni g\nn\ni=1\n, show that\nn\nspanS = x 2 V : 9f (cid:11) i g n i=1 (cid:18) R s.t. x = (cid:11) i x i :\n( )\ni=1\nX',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 2': {'question': 'Let (X;d) be a metric space and D a subsetof X such that cl(D) = X.1 Prove that if\nA X is closed and such that cl(intA) = A, then cl(A D) = A.\n(cid:18) \\',
#     'solution': '. Since cl(intA) = A, A is empty if and only if intA is empty. If A is empty, trivially, we\nhave that cl(A D) = cl( ) = = A. If A is not empty, we have that intA = . Fix x intA. Since\n\\ ; ; 6 ; 2\ncl(D) = X, there exists a sequence x D such that x x. Since x intA and the latter\nf n gn N (cid:18) n ! 2\nis open, this implies that there exists " >20 such that B (x) intA and, in particular, there exists\n"\n(cid:18)\nn " N such that x n B " (x) intA for all n n " . We can conclude that x cl(intA D). Since x\n2 2 (cid:18) (cid:21) 2 \\\nwas arbitrarily chosen, we have that\nintA cl(intA D) = A = cl(intA) cl(intA D) cl(A D) cl(A) = A;\n(cid:18) \\ ) (cid:18) \\ (cid:18) \\ (cid:18)\nproving the statement. (cid:4)\n1Inthisexercise,givenasubsetB ofX,bycl(B),wemeantheclosureofB,whichisalsodenotedasB(cid:22) inthelecture\nnotes.'},
#    'Exercise 3': {'question': 'Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 4': {'question': 'Consider the space of real-valued bounded sequences, denoted ‘ , endowed with the sup-\n1\nnorm ,2 that is,\nk k\n1\n‘\n1\n= x RN : sup x\nn\n< :\n2 j j 1\n(cid:26) n N (cid:27)\n2\nLet T : ‘ ‘ be such that for each x ‘ we de(cid:133)ne ax = T (x) to be such that\n1 1 1\n! 2\nx +:::+x\nax\nn\n= 1\nn\nn\n8\nn\n2\nN: (1)\n1. Compute the operator norm of T. Motivate your answer!\n2. Is T a contraction? Motivate your answer!',
#     'solution': '1. Fix x ‘ . Observe that\n1\n2\nn n\nx +:::+x 1 1\nj\nax\nn j\n= 1\nn\nn\n(cid:20) n j\nx\ni j (cid:20) n k\nx\nk\n=\nk\nx\nk 8\nn\n2\nN;\n(cid:12) (cid:12) i=1 i=1 1 1\n(cid:12) (cid:12) X X\n(cid:12) (cid:12)\nproving that sup ax(cid:12) x . By(cid:12)de(cid:133)nition of T and since x was arbitrarily chosen, it follows that\nn 2 Nj n j (cid:20) k k 1\nT (x) = sup ax x x ‘ :\nn 1\nk k j j (cid:20) k k 8 2\n1 n N 1\n2\nBy de(cid:133)nition of operator norm, we have that T 1. Next, consider the sequence e ‘ such that\n1\nk k (cid:20) 2\ne\nn\n= 1 for all n N. It follows that (cid:3)\n2\ne +:::+e\nae\nn\n= 1\nn\nn = 1\n8\nn\n2\nN;\nyieldingthatae = eand,inparticular, T (e) = ae = e . Bythecharacterizationofoperator\nk k k k k k\nnorm and since e = sup e = 1, we ha1ve that 1 1\nk k 1 n 2 Nj n j\nT = sup T (x) T (e) = 1:\nk k k k (cid:21) k k\n(cid:3) x ‘ : x =1 1 1\n2 1k k1\nWe can conclude that T = 1 (cf.'},
#    'Exercise 5': {'question': ', January 9th, 2023).\nk k\n(cid:3)\n2. No! Since T is linear, to be a contraction T needs to be such that T < 1, which is not the\nk k\ncase. Alternatively, you can check that it has more than one (cid:133)xed point, for ex(cid:3)ample, e and 0. (cid:4)\n2Recall that\nk\nx\nk1\n=sup\nn 2 Nj\nx\nn j\nfor all x\n2\n‘1.'},
#    'Exercise 6': {'question': 'Consider a normed vector space X with norm and a nonempty closed subset C of X.\nk k\nDe(cid:133)ne f : X [0; ) by\n! 1\nf(x) = inf x y x X:\ny Ck (cid:0) k 8 2\n2\nProve that f is convex if and only if C is convex.',
#     'solution': '(cid:147)If(cid:148). Consider x\n0\n;x\n1\nX and (cid:21) (0;1). Consider n N. By de(cid:133)nition of inf and f, we\n2 2 2\nhave that there exist y ;y C such that\n0 1\n2\n1 1\nf(x ) = inf x y x y and f(x ) = inf x y x y :\n0 0 0 0 1 1 1 1\ny Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n y Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n\n2 2\nDe(cid:133)ne x = (cid:21)x +(1 (cid:21))x and y = (cid:21)y +(1 (cid:21))y . Since y ;y C and C is convex, we have\n(cid:21) 1 0 (cid:21) 1 0 0 1\n(cid:0) (cid:0) 2\nthat y C. By de(cid:133)nition of f, we can conclude that\n(cid:21)\n2\nf((cid:21)x +(1 (cid:21))x ) = f(x ) = inf x y x y\n1 0 (cid:21) (cid:21) (cid:21) (cid:21)\n(cid:0) y Ck (cid:0) k (cid:20) k (cid:0) k\n2\n= (cid:21)x +(1 (cid:21))x (cid:21)y (1 (cid:21))y = (cid:21)(x y )+(1 (cid:21))(x y )\n1 0 1 0 1 1 0 0\nk (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 1\n(cid:21) x y +(1 (cid:21)) x y (cid:21) f(x )+ +(1 (cid:21)) f(x )+\n1 1 0 0 0 1\n(cid:20) k (cid:0) k (cid:0) k (cid:0) k (cid:20) n (cid:0) n\n(cid:18) (cid:19) (cid:18) (cid:19)\n1\n= (cid:21)f(x )+(1 (cid:21))f(x )+ :\n0 1\n(cid:0) n\nSince x , x , (cid:21), and n were arbitrarily chosen, f is convex and the implication follows (cf.'},
#    'Exercise 7': {'question': '0 1\nof the exams of September 2020 or January 8th, 2020).\n(cid:147)Only if(cid:148). First, observe that\nx C f(x) = 0: (2)\n2 ()\nIn fact, by de(cid:133)nition of f, we have that\nx C = 0 = x x inf x y = f(x) 0:\n2 ) k (cid:0) k (cid:21) y Ck (cid:0) k (cid:21)\n2\nMoreover, if inf x y = 0, then there exists a sequence y C such that x y\ninf x y = y 2 f C ( k x) (cid:0) = 0 k . Since C is closed, this implies that f y n gn 2x N , (cid:18) proving that x k C (cid:0) . W n k ith #\ny C n\n2 k (cid:0) k ! 2\nthis, take x ;x C and (cid:21) (0;1). By (2) and since f is convex and x ;x C, we can conclude\n1 0 1 0\n2 2 2\nthat\n0 f((cid:21)x +(1 (cid:21))x ) (cid:21)f(x )+(1 (cid:21))f(x ) = 0 = f((cid:21)x +(1 (cid:21))x ) = 0 = (cid:21)x +(1 (cid:21))x C:\n1 0 1 0 1 0 1 0\n(cid:20) (cid:0) (cid:20) (cid:0) ) (cid:0) ) (cid:0) 2\nSince x 0 , x 1 , and (cid:21) were arbitrarily chosen, C is convex and the implication follows. (cid:4)'},
#    'Exercise 8': {'question': 'Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. De(cid:133)ne the optimal policy correspondence and the optimal policy function.\n2. De(cid:133)ne when a path x =(x ;x ;x ;:::) is sequentially optimal for problem RF (x ).\n0 1 2 0',
#     'solution': '1. See the lecture notes.\n2. See the lecture notes. (cid:4) EXTRA PAGE'}}},
#  'General_2025-01-07': {'type': 'General',
#   'date': '2025-01-07',
#   'year': 2025,
#   'month': 1,
#   'day': 7,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 7, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let V be a vector space.\n1. Give the de(cid:133)nition of vector subspace.\n2. Prove that the intersection of any family of vector subspaces of V is a vector subspace of V.\nSolution See the lecture notes. (cid:4)',
#    'Exercise 2 Consider a nonempty set X and assume that d and d are two di⁄erent distances on X.\na b\nAssume that the following property holds: each convergent sequence with respect to d is convergent\na\nwith respect to d and the limit is the same, that is, in symbols, for each x X\nb f n gn N (cid:18)\n2\nx\nda\nx = x\ndb\nx: (1)\nn n\n! ) !\n1. Prove that if O X is open with respect to d , then it is open with respect to d .\nb a\n(cid:18)\n2. Prove that if K is compact with respect to d , then it is compact with respect to d .\na b\nSolution 1. Consider a set O which is open with respect to d . It follows that C = Oc is closed\nb\nwith respect to d . We next show that C is closed also with respect to d . Consider a sequence\nb a\nx C such that x\nda\nx. By (1), it follows that x\ndb\nx. Since C is d -closed, we can conclude\nf n gn N (cid:18) n ! n ! b\nthat x2 C. Since x was arbitrarily chosen, it follows that C is d -closed and, in particular,\nO = (O 2 c)c = Cc is o f pe n n gn w2i N th respect to d , proving the statement. a\na\n2. Proof1. Consideracollection O suchthatO isd -openforall(cid:11) AandK O .\nIn other words, O is an open f co (cid:11) ve g r (cid:11) 2f A or K with re (cid:11) spect b to d . Since se 2 ts that are (cid:18) op [ e (cid:11) n 2 A wit (cid:11) h\nf (cid:11) g(cid:11) A b\nrespect to d are open w2ith respect to d , we have that O is an open cover for K with respect\nb a f (cid:11) g(cid:11) A\nto d . Since K is compact with respect to d , we have that the2re exists a (cid:133)nite subcover of O ,\na a f (cid:11) g(cid:11) A\nproving that K is compact with respect to d . 2\nb\nProof 2. Consider a sequence x in K. By Bolzano-Weierstrass Theorem and (1) and\nf n gn N\nsince K is compact with respect to d , th2ere exists a subsequence x x such that\na f nkgk N (cid:18) f n gn N\nx\nda\nx K, proving that x\ndb\nx K. This implies that each sequence in\n2\nK admits a\n2\nsubsequence\nnk\n! 2\nnk\n! 2\nwhich converges, with respect to d , to a point in K. By Bolzano-Weierstrass Theorem, we can\nb\nconclude that K is compact with respect to d b . (cid:4)',
#    'Exercise 3 Consider R 3 and de(cid:133)ne : R 3 [0; ) by\nk k ! 1\nk x k = j x 1 j + x2 2 +x2 3 8 x 2 R 3:\nq\nIs a norm?\nk k\nSolution Yes! De(cid:133)ne (cid:25) : R 3 R 2 by (cid:25)(x) = (x 2 ;x 3 ) for all x R 3, that is,\n! 2\nx\n0 1 0 1\n(cid:25)(x) = 0 0 1 0 x 2 1 8 x 2 R 3:\n(cid:18) (cid:19) x 3\n@ A\nIt follows that\nk x k = j x 1 j + k (cid:25)(x) k2 8 x 2 R 3\nwhere : R 2 [0; ) is the Euclidean norm, that is, z = z2+z2 for all z R 2. We now\nk k2 ! 1 k k2 1 2 2\nprove the three properties of norm.\np\n1. Since is a norm, note that\nk k2\nx = 0 x + (cid:25)(x) = 0 x = (cid:25)(x) = 0 x = 0 and (cid:25)(x) = 0\nk k () j 1 j k k2 () j 1 j k k2 () 1\nx = x = x = 0 x = 0:\n1 2 3\n() ()\n2. Since is a norm and (cid:25) is linear, for each (cid:21) R and for each x R 3, we have that\nk k2 2 2\n(cid:21)x = (cid:21)x + (cid:25)((cid:21)x) = (cid:21) x + (cid:21)(cid:25)(x) = (cid:21) ( x + (cid:25)(x) ) = (cid:21) x :\nk k j 1 j k k2 j jj 1 j k k2 j j j 1 j k k2 j jk k\n3. Since is a norm and (cid:25) is linear, for each x;y R 3, we have that\nk k2 2\nx+y = x +y + (cid:25)(x+y) = x +y + (cid:25)(x)+(cid:25)(y)\nk k j 1 1 j k k2 j 1 1 j k k2\nx + (cid:25)(x) + y + (cid:25)(y) = x + y :\n(cid:20) j 1 j k k2 j 1 j k k2 k k k k\nThe three properties prove that is a norm. (cid:4)\nk k',
#    'Exercise 4 Consider R n endowed with the supnorm .1 Let T : R n R n be such that\nk k !\n1\nT (x) T (y) x y x;y R n: (2)\nk (cid:0) k (cid:20) k (cid:0) k 8 2\n1 1\n1. If x R n and (cid:11) (0;1), prove that there exist two unique points in R n, x (cid:11) and x~ (cid:11) , such that\n2 2\nx = T ((1 (cid:11))x+(cid:11)x ) and x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11) (cid:11) (cid:11)\n(cid:0) (cid:0)\n2. Prove that x~ = (1 (cid:11))x+(cid:11)x .\n(cid:11) (cid:11)\n(cid:0)\nSolution De(cid:133)ne T (cid:11);x ;T~ (cid:11);x : R n R n by\n!\nT (cid:11);x (y) = T ((1 (cid:11))x+(cid:11)y) and T~ (cid:11);x (y) = (1 (cid:11))x+(cid:11)T (y) y R n:\n(cid:0) (cid:0) 8 2\nNote that\nx = T (x ) x = T ((1 (cid:11))x+(cid:11)x )\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nand\nx~ = T~ (x~ ) x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nIn other words, the points (x and x~ ) we are after are the (cid:133)xed points of the two operators T and\n(cid:11) (cid:11) (cid:11);x\nT~ , respectively.\n(cid:11);x\n1. Since T satis(cid:133)es (2), we have that\nT (y) T (z) = T ((1 (cid:11))x+(cid:11)y) T ((1 (cid:11))x+(cid:11)z)\n(cid:11);x (cid:11);x\nk (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 (1 (cid:11))x+(cid:11)y (1 (cid:11))x (cid:11)z = (cid:11) 1 y z y;z R n\n(cid:20) k (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) k 8 2\n1 1\nand\nT~ (y) T~ (z) = (1 (cid:11))x+(cid:11)T (y) (1 (cid:11))x (cid:11)T (z)\n(cid:11);x (cid:11);x\n(cid:0) k (cid:0) (cid:0) (cid:0) (cid:0) k\n1\n(cid:13) (cid:13) (cid:13) (cid:13) 1 = (cid:11) T (y) T (z) (cid:11) y z y;z R n:\n(cid:13) (cid:13) k (cid:0) k 1 (cid:20) k (cid:0) k 1 8 2\nInotherwords,since(cid:11) (0;1),T andT~ are(cid:11)-contractions. BytheBanachContractionprinciple\n(cid:11);x (cid:11);x\nand since (R n; ) is 2 complete, this implies that T\n(cid:11);x\nand T~\n(cid:11);x\nhave each a unique (cid:133)xed point which\nk k\nwe denote respect1ively x and x~ , that is,\n(cid:11) (cid:11)\nT ((1 (cid:11))x+(cid:11)x ) = T (x ) = x\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nand\n(1 (cid:11))x+(cid:11)T (x~ ) = T~ (x~ ) = x~ ;\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nproving that x and x~ exist and are unique.\n(cid:11) (cid:11)\n2. Set x^ = (1 (cid:11))x+(cid:11)x . We have that\n(cid:11) (cid:11)\n(cid:0)\nx^ = (1 (cid:11))x+(cid:11)x = (1 (cid:11))x+(cid:11)T ((1 (cid:11))x+(cid:11)x ) = (1 (cid:11))x+(cid:11)T (x^ ) = T~ (x^ );\n(cid:11) (cid:11) (cid:11) (cid:11) (cid:11);x (cid:11)\n(cid:0) (cid:0) (cid:0) (cid:0)\nproving that x^ is a (cid:133)xed point of T~ . Since this point is unique and is x~ . It follows that x~ =\n(cid:11) (cid:11);x (cid:11) (cid:11)\nx^ = (1 (cid:11))x+(cid:11)x , proving the equality (cf. Exercise 4 of the exams of September 2024, 2021, and\n(cid:11) (cid:11)\n(cid:0)\n2019). (cid:4)\n1Recall that k x k1 =max i 2f 1;:::;n gj x i j for all x 2 R n.',
#    'Exercise 5 State and prove the Blackwell(cid:146)s theorem.\nSolution See the lecture notes. (cid:4)',
#    'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Optimality Principle.\nSolution See the lecture notes. (cid:4)',
#    'EXTRA PAGE'],
#   'questions': {'Exercise 1': {'question': 'Let V be a vector space.\n1. Give the de(cid:133)nition of vector subspace.\n2. Prove that the intersection of any family of vector subspaces of V is a vector subspace of V.',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 2': {'question': 'Consider a nonempty set X and assume that d and d are two di⁄erent distances on X.\na b\nAssume that the following property holds: each convergent sequence with respect to d is convergent\na\nwith respect to d and the limit is the same, that is, in symbols, for each x X\nb f n gn N (cid:18)\n2\nx\nda\nx = x\ndb\nx: (1)\nn n\n! ) !\n1. Prove that if O X is open with respect to d , then it is open with respect to d .\nb a\n(cid:18)\n2. Prove that if K is compact with respect to d , then it is compact with respect to d .\na b',
#     'solution': '1. Consider a set O which is open with respect to d . It follows that C = Oc is closed\nb\nwith respect to d . We next show that C is closed also with respect to d . Consider a sequence\nb a\nx C such that x\nda\nx. By (1), it follows that x\ndb\nx. Since C is d -closed, we can conclude\nf n gn N (cid:18) n ! n ! b\nthat x2 C. Since x was arbitrarily chosen, it follows that C is d -closed and, in particular,\nO = (O 2 c)c = Cc is o f pe n n gn w2i N th respect to d , proving the statement. a\na\n2. Proof1. Consideracollection O suchthatO isd -openforall(cid:11) AandK O .\nIn other words, O is an open f co (cid:11) ve g r (cid:11) 2f A or K with re (cid:11) spect b to d . Since se 2 ts that are (cid:18) op [ e (cid:11) n 2 A wit (cid:11) h\nf (cid:11) g(cid:11) A b\nrespect to d are open w2ith respect to d , we have that O is an open cover for K with respect\nb a f (cid:11) g(cid:11) A\nto d . Since K is compact with respect to d , we have that the2re exists a (cid:133)nite subcover of O ,\na a f (cid:11) g(cid:11) A\nproving that K is compact with respect to d . 2\nb\nProof 2. Consider a sequence x in K. By Bolzano-Weierstrass Theorem and (1) and\nf n gn N\nsince K is compact with respect to d , th2ere exists a subsequence x x such that\na f nkgk N (cid:18) f n gn N\nx\nda\nx K, proving that x\ndb\nx K. This implies that each sequence in\n2\nK admits a\n2\nsubsequence\nnk\n! 2\nnk\n! 2\nwhich converges, with respect to d , to a point in K. By Bolzano-Weierstrass Theorem, we can\nb\nconclude that K is compact with respect to d b . (cid:4)'},
#    'Exercise 3': {'question': 'Consider R 3 and de(cid:133)ne : R 3 [0; ) by\nk k ! 1\nk x k = j x 1 j + x2 2 +x2 3 8 x 2 R 3:\nq\nIs a norm?\nk k',
#     'solution': 'Yes! De(cid:133)ne (cid:25) : R 3 R 2 by (cid:25)(x) = (x 2 ;x 3 ) for all x R 3, that is,\n! 2\nx\n0 1 0 1\n(cid:25)(x) = 0 0 1 0 x 2 1 8 x 2 R 3:\n(cid:18) (cid:19) x 3\n@ A\nIt follows that\nk x k = j x 1 j + k (cid:25)(x) k2 8 x 2 R 3\nwhere : R 2 [0; ) is the Euclidean norm, that is, z = z2+z2 for all z R 2. We now\nk k2 ! 1 k k2 1 2 2\nprove the three properties of norm.\np\n1. Since is a norm, note that\nk k2\nx = 0 x + (cid:25)(x) = 0 x = (cid:25)(x) = 0 x = 0 and (cid:25)(x) = 0\nk k () j 1 j k k2 () j 1 j k k2 () 1\nx = x = x = 0 x = 0:\n1 2 3\n() ()\n2. Since is a norm and (cid:25) is linear, for each (cid:21) R and for each x R 3, we have that\nk k2 2 2\n(cid:21)x = (cid:21)x + (cid:25)((cid:21)x) = (cid:21) x + (cid:21)(cid:25)(x) = (cid:21) ( x + (cid:25)(x) ) = (cid:21) x :\nk k j 1 j k k2 j jj 1 j k k2 j j j 1 j k k2 j jk k\n3. Since is a norm and (cid:25) is linear, for each x;y R 3, we have that\nk k2 2\nx+y = x +y + (cid:25)(x+y) = x +y + (cid:25)(x)+(cid:25)(y)\nk k j 1 1 j k k2 j 1 1 j k k2\nx + (cid:25)(x) + y + (cid:25)(y) = x + y :\n(cid:20) j 1 j k k2 j 1 j k k2 k k k k\nThe three properties prove that is a norm. (cid:4)\nk k'},
#    'Exercise 4': {'question': 'Consider R n endowed with the supnorm .1 Let T : R n R n be such that\nk k !\n1\nT (x) T (y) x y x;y R n: (2)\nk (cid:0) k (cid:20) k (cid:0) k 8 2\n1 1\n1. If x R n and (cid:11) (0;1), prove that there exist two unique points in R n, x (cid:11) and x~ (cid:11) , such that\n2 2\nx = T ((1 (cid:11))x+(cid:11)x ) and x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11) (cid:11) (cid:11)\n(cid:0) (cid:0)\n2. Prove that x~ = (1 (cid:11))x+(cid:11)x .\n(cid:11) (cid:11)\n(cid:0)',
#     'solution': 'De(cid:133)ne T (cid:11);x ;T~ (cid:11);x : R n R n by\n!\nT (cid:11);x (y) = T ((1 (cid:11))x+(cid:11)y) and T~ (cid:11);x (y) = (1 (cid:11))x+(cid:11)T (y) y R n:\n(cid:0) (cid:0) 8 2\nNote that\nx = T (x ) x = T ((1 (cid:11))x+(cid:11)x )\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nand\nx~ = T~ (x~ ) x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nIn other words, the points (x and x~ ) we are after are the (cid:133)xed points of the two operators T and\n(cid:11) (cid:11) (cid:11);x\nT~ , respectively.\n(cid:11);x\n1. Since T satis(cid:133)es (2), we have that\nT (y) T (z) = T ((1 (cid:11))x+(cid:11)y) T ((1 (cid:11))x+(cid:11)z)\n(cid:11);x (cid:11);x\nk (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 (1 (cid:11))x+(cid:11)y (1 (cid:11))x (cid:11)z = (cid:11) 1 y z y;z R n\n(cid:20) k (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) k 8 2\n1 1\nand\nT~ (y) T~ (z) = (1 (cid:11))x+(cid:11)T (y) (1 (cid:11))x (cid:11)T (z)\n(cid:11);x (cid:11);x\n(cid:0) k (cid:0) (cid:0) (cid:0) (cid:0) k\n1\n(cid:13) (cid:13) (cid:13) (cid:13) 1 = (cid:11) T (y) T (z) (cid:11) y z y;z R n:\n(cid:13) (cid:13) k (cid:0) k 1 (cid:20) k (cid:0) k 1 8 2\nInotherwords,since(cid:11) (0;1),T andT~ are(cid:11)-contractions. BytheBanachContractionprinciple\n(cid:11);x (cid:11);x\nand since (R n; ) is 2 complete, this implies that T\n(cid:11);x\nand T~\n(cid:11);x\nhave each a unique (cid:133)xed point which\nk k\nwe denote respect1ively x and x~ , that is,\n(cid:11) (cid:11)\nT ((1 (cid:11))x+(cid:11)x ) = T (x ) = x\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nand\n(1 (cid:11))x+(cid:11)T (x~ ) = T~ (x~ ) = x~ ;\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nproving that x and x~ exist and are unique.\n(cid:11) (cid:11)\n2. Set x^ = (1 (cid:11))x+(cid:11)x . We have that\n(cid:11) (cid:11)\n(cid:0)\nx^ = (1 (cid:11))x+(cid:11)x = (1 (cid:11))x+(cid:11)T ((1 (cid:11))x+(cid:11)x ) = (1 (cid:11))x+(cid:11)T (x^ ) = T~ (x^ );\n(cid:11) (cid:11) (cid:11) (cid:11) (cid:11);x (cid:11)\n(cid:0) (cid:0) (cid:0) (cid:0)\nproving that x^ is a (cid:133)xed point of T~ . Since this point is unique and is x~ . It follows that x~ =\n(cid:11) (cid:11);x (cid:11) (cid:11)\nx^ = (1 (cid:11))x+(cid:11)x , proving the equality (cf.'},
#    'Exercise 5': {'question': 'of the exams of September 2024, 2021, and\n(cid:11) (cid:11)\n(cid:0)\n2019). (cid:4)\n1Recall that k x k1 =max i 2f 1;:::;n gj x i j for all x 2 R n.'},
#    'Exercise 6': {'question': 'State and prove the Blackwell(cid:146)s theorem.',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 7': {'question': 'Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Optimality Principle.',
#     'solution': 'See the lecture notes. (cid:4) EXTRA PAGE'}}},
#  'Midterm_2024-10-24': {'type': 'Midterm',
#   'date': '2024-10-24',
#   'year': 2024,
#   'month': 10,
#   'day': 24,
#   'content': ['Advanced Mathematics (Cod. 20136)\nMidterm Exam (cid:150)October 24, 2024\nName and Last Name\nStudent ID Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and sign my presence at\nthe exam.\nSignature:\nExercise 1 Consider the vector space RR of real valued functions over the real line. For each (cid:13) R\n2\nde(cid:133)ne the function f (cid:13) : R ! R by f (cid:13) (x) = j x (cid:0) (cid:13) j for all x 2 R.1 De(cid:133)ne S = f f n gn N .\n2\n1. Is spanS = RR? Motivate your answer!\n2. Is S linearly independent? Motivate your answer!\n3. Is S a basis of RR? Motivate your answer!\nSolution See also extra page. 1. No, spanS = RR. In fact, consider f : R R de(cid:133)ned by\n6 !\nf(x) = x2 for all x R. By contradiction, assume that f spanS. It follows that there exist\nf f nig k i=1 (cid:18) S and f (cid:11) i g 2k i=1 (cid:18) R such that f = k i=1 (cid:11) i f ni . It fol 2 lows that\nk P k\nx2 = f(x) = (cid:11)\ni\nf\nni\n(x) = (cid:11)\ni\nj\nx\n(cid:0)\nn\ni\nj 8\nx\n2\nR:\ni=1 i=1\nX X\ndef\nBy passing to the limit, if we consider x > n(cid:22) = max n : i 1;:::;k , then we have that\ni\nf 2 f gg\nk k k\nn\nx2 = (cid:11)\ni\n(x n\ni\n) x > n(cid:22) = x = (cid:11)\ni\n1 i x > n(cid:22) = = (cid:11)\ni\nR;\n(cid:0) 8 ) (cid:0) x 8 ) 1 2\nX i=1 X i=1 (cid:16) (cid:17) X i=1\na contradiction.\n2. Yes, S is linearly independent! De(cid:133)ne S = f n . We are (cid:133)rst going to show that S is\nn f i gi=1 n\nlinearly independent for all n N. We proceed by induction.\n2\nInitial step. n = 1. We need to show that (cid:11) f = 0 implies that (cid:11) = 0, that is, (cid:11) f (x) = 0 for all\n1 1 1 1 1\nx R implies that (cid:11) 1 = 0. If we consider x(cid:22) = 2, then we have that\n2\n(cid:11) f = 0 = (cid:11) = (cid:11) f (x(cid:22)) = 0;\n1 1 1 1 1\n)\nproving the statement.\n1In other words, f is such that\n(cid:13)\nx (cid:13) if x (cid:13)\nf (cid:13) (x)= (cid:13) (cid:0) x if x< (cid:21) (cid:13) 8 x 2 R:\n(cid:26) (cid:0)',
# ...
#     'solution': '. 1. See the lecture notes.\n2. Since X and the empty set are always open, X, being the complement of the empty set, is\nclosed. Sinced(0;x) 1forallx R,X isalsobounded. Nevertheless,X isnotcompact. Underthe\n% 2\ndiscretemetric,singletonsareopensets. Itfollowsthat x isanopencoverforX,but,clearly,\nw co e nt c r a a n d n i o ct t io s n el . ect a Önite subcover for X out of ff x ggx 2 f R f , g o g th x 2er R wise X = R itself would be Önite, ! a'},
#    'Exercise 3': {'question': 'Consider R 3. Let L 1 ;L 2 :R 3 R be the linear functionals deÖned by\n!\nL 1 (x)=x 1 +x 2 x R 3\n8 2\nand\nL 2 (x)=x 2 +x 3 x R 3:\n8 2\n1. Give the deÖnition of norm.\n2. DeÖne p:R 3 R by\n! p(x)= max L i (x) x R 3:\ni 1;2 j j 8 2\n2f g\nShow that p satisÖes all the properties of a norm but one.',
#     'solution': '. 1. See the lecture notes.\n2. We prove that p satisÖes just two of the three properties deÖning a norm.\na) Since L and L are linear, L and L are additive. Thus, we can conclude that\n1 2 1 2\np(x+y) = max L (x+y) = max L (x)+L (y)\ni i i\ni 1;2 j j i 1;2 j j\n2f g 2f g\nmax [L (x) + L (y)] max L (x) + max L (y)\ni i i i\n% i 1;2 j j j j %i 1;2 j j i 1;2 j j\n2f g 2f g 2f g\n= p(x)+p(y) x;y R 3;\n8 2\nthat is, p is subadditive.\nb) Since L and L are linear, L and L are homogeneous. Thus, we can also conclude that\n1 2 1 2\np(+x) = max L (+x) = max +L (x) = max + L (x)\ni i i\ni 1;2 j j i 1;2 j j i 1;2 j jj j\n2f g 2f g 2f g\n= + max L i (x) = + p(x) x R 3; + R;\nj ji 1;2 j j j j 8 2 8 2\n2f g\nthat is, p has the same properties of homogeneity of a norm.\nc) Finally, notice that x- = (1; 1;1) = 0 is such that L (x-) = 0 = L (x-). We thus have that\n1 2\n) 6\np(x-)=0 and x- =0. On the other hand, if p were to be a norm we would have that p(x)=0 if and\n6\nonly if x=0. !'},
#    'Exercise 4': {'question': 'This exercise has two parts.\n1. For the autonomous di§erence equation:\nx =f(x )\nt+1 t\nstate the stability criterion by linearization for an equilibrium point.\n2. Consider\nax\nt\nx\nt+1\n=\n1+x2\n; a\n2\nR; a\n6\n=0:\nt\n(a) With respect to the parameter a; determine the equilibria and study their nature.\n(b) Fora=1;representthegeneratrixfunctionandthephasediagramtovisualizethestairstep\nbehavior of some signiÖcative orbit.'},
#    'Exercise 5': {'question': 'Consider R 3 endowed with the norm k+k1 .1\n1. Give the deÖnition of contraction for a map T :R 3 R 3.\n!\n2. Consider T :R 3 R 3 deÖned by\n!\nT(x)=(x 3 ;x 2 ;x 1 ) x R 3:\n8 2\n(a) Show that T is linear.\n(b) DeÖne when x- R 3 is a Öxed point for T.\n2\n(c) Is T a contraction?\n(d) Does T have a Öxed point? Is it unique?\n(e) DeÖne L= x- R 3 :x- is a Öxed point for T . Is L a vector subspace of R 3?\n2',
#     'solution': '. DeÖne d(x; " y)= k x ) y k1 for all x;y 2 R 3. #\n1. See the lecture notes.\n0 0 1\n2.a DeÖne the 3 3 matrix A = 0 1 0 . It is immediate to see that T(x) = Ax for all\n, 0 1\n1 0 0\nx R 3. By Rieszís representation theo@rem, it folloAws that T is linear.\n2\n2. b. x- is a Öxed point for T if and only if T(x-)=x-.\n2. c. No, it is not. In fact, we have that k T(x) k1 = k x k1 for all x 2 R 3.\n2. d. BydeÖnitionofT, allvectorsoftheformx=(k;k;k)withk inRareÖxedpoints. Forsuch\na reason, T has inÖnitely many Öxed points.\n2.e. Yes, it is. In fact, pick x-\n1\n;x-\n2\nL and +\n1\n;+\n2\nR. Since T is a linear map and T(x-\ni\n)=x-\ni\nfor\n2 2\ni 1;2 , it follows that\n2f g\nT(+ x- ++ x- )=+ T(x- )++ T(x- )=+ x- ++ x- ;\n1 1 2 2 1 1 2 2 1 1 2 2\nproving that, + 1 x- 1 ++ 2 x- 2 L. !\n2\n1Recallthat\nk x k1 = j x1 j + j x2 j + j x3 j 8 x 2 R 3:'},
#    'Exercise 6': {'question': 'Consider the reduced form problem\nmax 1 0t1(x ;x ) sub x 3(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 - 2\nt=0\nX\n1. DeÖne its value function and write its Bellman equation.\n2. State and prove the Bellman Theorem and discuss its importance.',
#     'solution': '. See the lecture notes. !'}}},
#  'General_2013-02-01': {'type': 'General',
#   'date': '2013-02-01',
#   'year': 2013,
#   'month': 2,
#   'day': 1,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam ñ February 1, 2013\nSurname Student ID\nName Exam Code\nRules of conduct during exams or other tests:\nIherebyundertaketorespecttheregulationsdescribedintheHonorCode andundersignmypresence\nat the exam.\nSignature:\nExercise 1 Consider a function f :R n R.\n!\n1. State and prove the Riesz representation theorem (that is, the theorem that provides a charac-\nterization for linear functionals).\nSolution. See the lecture notes. !',
#    'Exercise 2 Consider a metric space (X;d).\n1. Give the deÖnition of open set.\n2. Consider x X and ">0. DeÖne\n2\nS = y X :d(y;x)>" :\nf 2 g\nProve that the set S is open.\nSolution. 1. See the lecture notes.\n2. If S is empty then there is nothing to prove. Otherwise, consider y& S. DeÖne + =d(y&;x) ".\n2 %\nIt is immediate to see that + > 0. Next, consider z B (y&), that is, z X such that d(z;y&) < +.\n"\n2 2\nSince d is a distance function, it follows that d(y&;x) d(y&;z)+d(z;x). This yields that\n&\nd(z;x) d(y&;x) d(y&;z)>d(y&;x) + =d(y&;x) d(y&;x)+"=";\n\' % % %\nproving that z S. Since zwas chosen to be generic, we can conclude that B (y&) S, proving that\n"\n2 (\ny&is an interior point. Since y&was chosen to be generic, it follows that S is open. !',
#    'Exercise 3 Consider R 3.\n1. Give the deÖnition of norm.\n2. DeÖne f :R 3 R by\n! f(x)= x 1 + x 2 x R 3:\nj j j j 8 2\nProve that f satisÖes just two of the three properties that characterize a norm.\nSolution. 1. See the lecture notes.\n2. Notice that for each / R and for each x R 3\n2 2\nf(/x)= /x + /x = / (x + x )= / f(x):\n1 2 1 2\nj j j j j j j j j j j j\nFor each x;y R 3, we have that\n2\nf(x+y)= x +y + x +y (x + x )+(y + y )=f(x)+f(y):\n1 1 2 2 1 2 1 2\nj j j j& j j j j j j j j\nThus, f satisÖes at least two of the three properties that deÖne a norm. At the same time, we have\nthat there exists a vector x = 0 such that f(x) = 0, for example, (0;0;1), proving that f does not\n6\nsatisfy all the three properties which deÖne a norm. !',
#    "Exercise 4 This exercise has two parts.\n1. Consider the linear system:\nx_ =ax+by\ny_ =cx+dy:\n!\nWith respect to the coe¢cients a;b;c;d R how many equilibria it has? Give a formula for the\n2\ngeneral solution in the case of real and distinct eigenvalues associated to the coe¢cient matrix.\n2. Consider the non linear system\nx_ =x y\n%\n8 2x\n>< y_ =\n1+x2 %\ny:\n(a) Draw the phase portrait, where\n>:you\ndetermine, in particular, the equilibria, the vertical-\nand horizontal-slope isoclines and the orientation of the trajectories. Are rotations allowed\nin the neighborhood of equilibria?\n(b) Check that the origin is a critical point; can the linearization criterion be used in order to\ndetermine its stability?\nSolution. 1. If ad bc = 0 the system has one single equilibrium (the origin) else the system\n% 6\nhas inÖnite equilibria, along one straight line (that is the eigenvector associated with the zero eigen-\nvalue). Assuming thet 3 and 3 are real and distinct eigenvalues and h and h the corresponding\n1 2 1 2\neigenvectors, the general solution is\nx(t)\n=c e#1th +c e#2th\ny(t) 1 1 2 2\n& '\nwhere c\n1\n;c\n2\nR.\n2\n2. a. The equilibria solve the algebraic system\nx y =0\n%\n8 2x\n><\n1+x2 %\ny =0;\nthey are P = (0;0), P = (1;1) and P\n>:=\n( 1; 1). The vertical-slope isocline is the straight line\n1 2 3\n% % 2x\ny = x (represented in red in the Ögure below) the horizontal-slope isocline is the curve y =\n1+x2\n(representedinblue)ThepathsorientationisshownintheÖgure. AmongthethreeequilibriaP , P ,\n1 2\nP rotations are allowed just around P .\n3 1\n2. b. We have already seen that the origin is one of the equilibria of the system. The jacobian\nmatrix is\n1 1\n%\nJ(x;y)= 2 1 x2 :\n2 % 1 3\n(1+x2)2 %\n* +\n4 5\n1 1\nSince J(0;0) = 2 % 1 has eigenvalues 3 1 = % i and 3 2 = i; hence the origin of the linearized\n& % '\nsystem is a center. On the other hand, the origin of the original system can be either a center or a\nfocus (anyway rotations are compatible with the nature of this equilibrium point). The linearization\ncriterion is not conclusive in this case. !",
#    '1. (a)\n1\n0.8\n0.6\n0.4\n0.2\n0\n-0.2\n-0.4\n-0.6\n-0.8\n-1\n-3 -2 -1 0 1 2 3\nExercise 5 Consider the space B(X) of bounded functions over a set X.\n1. State (without proof) the Blackwell Theorem.\n2. Given a function 8 : X X R such that 8(x;y) < 1 for all x;y X and a function\n, ! j j 2\n9 :X R such that 0<9(x)<1=2 for all x X, consider the operator T :B(X) B(X),\n! 2 !\ndeÖned by\nT(v)(x)= sup 8(x;y)+9(y)v(y) x X: (1)\nf g 8 2\ny X\n2\n(a) DeÖne when v& B(X) is a Öxed point for T.\n2\n(b) Is T is a contraction?\n(c) Does T have a Öxed point? Is it unique?\nSolution. Observe that B(X) is endowed with the supnorm.\n1. See the lecture notes.\n2. a. v& is a Öxed point for T if and only if T(v&)=v&.\n2. b. Observe that:\n(i). Since 9 is positive, if v w then for each x X\n& 2\n8(x;y)+9(y)v(y) 8(x;y)+9(y)w(y) y X:\n& 8 2\nThis implies that for each x X\n2\nT(v)(x) = sup 8(x;y)+9(y)v(y)\nf g\ny X\n2\nsup 8(x;y)+9(y)w(y)\n& f g\ny X\n2\n= T(w)(x);\nproving that if v w then T(v) T(w).\n& &\n(ii). If v B(X) and c R+ then\n2 2\nT(v+c)(x) = sup 8(x;y)+9(y)(v(y)+c)\nf g\ny X\n2\n1\nsup 8(x;y)+9(y)v(y)+ c\n& 2\ny 2 X! .\n1\nsup 8(x;y)+9(y)v(y) + c\n& f g 2\ny X\n2\n1\n= T(v)(x)+ c;\n2',
#    'proving that T(v+c) T(v)+ 1c.\nBy points (i) and (i & i) and the 2 Blackwell Theorem, T is a 1-contraction.\n2\n2. c. By the Banach Contraction Principle and since B(X), endowed with the distance induced\nby the supnorm, is a complete metric space and T is a contraction, it follows that T admits a unique\nÖxed point. !',
#    "Exercise 6 Consider the reduced form problem\nmax 1 9t8(x ;x ) sub x 3(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 ' 2\nt=0\nX\n1. State and prove the Optimality Principle. Discuss its importance.\n2. DeÖnetheoptimalpolicycorrespondenceandtheoptimalpolicyfunction. Discussitsimportance.\nSolution. See the lecture notes. !"],
#   'questions': {'Exercise 1': {'question': 'Consider a function f :R n R.\n!\n1. State and prove the Riesz representation theorem (that is, the theorem that provides a charac-\nterization for linear functionals).',
#     'solution': '. See the lecture notes. !'},
#    'Exercise 2': {'question': 'Consider a metric space (X;d).\n1. Give the deÖnition of open set.\n2. Consider x X and ">0. DeÖne\n2\nS = y X :d(y;x)>" :\nf 2 g\nProve that the set S is open.',
#     'solution': '. 1. See the lecture notes.\n2. If S is empty then there is nothing to prove. Otherwise, consider y& S. DeÖne + =d(y&;x) ".\n2 %\nIt is immediate to see that + > 0. Next, consider z B (y&), that is, z X such that d(z;y&) < +.\n"\n2 2\nSince d is a distance function, it follows that d(y&;x) d(y&;z)+d(z;x). This yields that\n&\nd(z;x) d(y&;x) d(y&;z)>d(y&;x) + =d(y&;x) d(y&;x)+"=";\n\' % % %\nproving that z S. Since zwas chosen to be generic, we can conclude that B (y&) S, proving that\n"\n2 (\ny&is an interior point. Since y&was chosen to be generic, it follows that S is open. !'},
#    'Exercise 3': {'question': 'Consider R 3.\n1. Give the deÖnition of norm.\n2. DeÖne f :R 3 R by\n! f(x)= x 1 + x 2 x R 3:\nj j j j 8 2\nProve that f satisÖes just two of the three properties that characterize a norm.',
#     'solution': '. 1. See the lecture notes.\n2. Notice that for each / R and for each x R 3\n2 2\nf(/x)= /x + /x = / (x + x )= / f(x):\n1 2 1 2\nj j j j j j j j j j j j\nFor each x;y R 3, we have that\n2\nf(x+y)= x +y + x +y (x + x )+(y + y )=f(x)+f(y):\n1 1 2 2 1 2 1 2\nj j j j& j j j j j j j j\nThus, f satisÖes at least two of the three properties that deÖne a norm. At the same time, we have\nthat there exists a vector x = 0 such that f(x) = 0, for example, (0;0;1), proving that f does not\n6\nsatisfy all the three properties which deÖne a norm. !'},
#    'Exercise 4': {'question': 'This exercise has two parts.\n1. Consider the linear system:\nx_ =ax+by\ny_ =cx+dy:\n!\nWith respect to the coe¢cients a;b;c;d R how many equilibria it has? Give a formula for the\n2\ngeneral solution in the case of real and distinct eigenvalues associated to the coe¢cient matrix.\n2. Consider the non linear system\nx_ =x y\n%\n8 2x\n>< y_ =\n1+x2 %\ny:\n(a) Draw the phase portrait, where\n>:you\ndetermine, in particular, the equilibria, the vertical-\nand horizontal-slope isoclines and the orientation of the trajectories. Are rotations allowed\nin the neighborhood of equilibria?\n(b) Check that the origin is a critical point; can the linearization criterion be used in order to\ndetermine its stability?',
#     'solution': ". 1. If ad bc = 0 the system has one single equilibrium (the origin) else the system\n% 6\nhas inÖnite equilibria, along one straight line (that is the eigenvector associated with the zero eigen-\nvalue). Assuming thet 3 and 3 are real and distinct eigenvalues and h and h the corresponding\n1 2 1 2\neigenvectors, the general solution is\nx(t)\n=c e#1th +c e#2th\ny(t) 1 1 2 2\n& '\nwhere c\n1\n;c\n2\nR.\n2\n2. a. The equilibria solve the algebraic system\nx y =0\n%\n8 2x\n><\n1+x2 %\ny =0;\nthey are P = (0;0), P = (1;1) and P\n>:=\n( 1; 1). The vertical-slope isocline is the straight line\n1 2 3\n% % 2x\ny = x (represented in red in the Ögure below) the horizontal-slope isocline is the curve y =\n1+x2\n(representedinblue)ThepathsorientationisshownintheÖgure. AmongthethreeequilibriaP , P ,\n1 2\nP rotations are allowed just around P .\n3 1\n2. b. We have already seen that the origin is one of the equilibria of the system. The jacobian\nmatrix is\n1 1\n%\nJ(x;y)= 2 1 x2 :\n2 % 1 3\n(1+x2)2 %\n* +\n4 5\n1 1\nSince J(0;0) = 2 % 1 has eigenvalues 3 1 = % i and 3 2 = i; hence the origin of the linearized\n& % '\nsystem is a center. On the other hand, the origin of the original system can be either a center or a\nfocus (anyway rotations are compatible with the nature of this equilibrium point). The linearization\ncriterion is not conclusive in this case. ! 1. (a)\n1\n0.8\n0.6\n0.4\n0.2\n0\n-0.2\n-0.4\n-0.6\n-0.8\n-1\n-3 -2 -1 0 1 2 3"},
#    'Exercise 5': {'question': 'Consider the space B(X) of bounded functions over a set X.\n1. State (without proof) the Blackwell Theorem.\n2. Given a function 8 : X X R such that 8(x;y) < 1 for all x;y X and a function\n, ! j j 2\n9 :X R such that 0<9(x)<1=2 for all x X, consider the operator T :B(X) B(X),\n! 2 !\ndeÖned by\nT(v)(x)= sup 8(x;y)+9(y)v(y) x X: (1)\nf g 8 2\ny X\n2\n(a) DeÖne when v& B(X) is a Öxed point for T.\n2\n(b) Is T is a contraction?\n(c) Does T have a Öxed point? Is it unique?',
#     'solution': '. Observe that B(X) is endowed with the supnorm.\n1. See the lecture notes.\n2. a. v& is a Öxed point for T if and only if T(v&)=v&.\n2. b. Observe that:\n(i). Since 9 is positive, if v w then for each x X\n& 2\n8(x;y)+9(y)v(y) 8(x;y)+9(y)w(y) y X:\n& 8 2\nThis implies that for each x X\n2\nT(v)(x) = sup 8(x;y)+9(y)v(y)\nf g\ny X\n2\nsup 8(x;y)+9(y)w(y)\n& f g\ny X\n2\n= T(w)(x);\nproving that if v w then T(v) T(w).\n& &\n(ii). If v B(X) and c R+ then\n2 2\nT(v+c)(x) = sup 8(x;y)+9(y)(v(y)+c)\nf g\ny X\n2\n1\nsup 8(x;y)+9(y)v(y)+ c\n& 2\ny 2 X! .\n1\nsup 8(x;y)+9(y)v(y) + c\n& f g 2\ny X\n2\n1\n= T(v)(x)+ c;\n2 proving that T(v+c) T(v)+ 1c.\nBy points (i) and (i & i) and the 2 Blackwell Theorem, T is a 1-contraction.\n2\n2. c. By the Banach Contraction Principle and since B(X), endowed with the distance induced\nby the supnorm, is a complete metric space and T is a contraction, it follows that T admits a unique\nÖxed point. !'},
#    'Exercise 6': {'question': "Consider the reduced form problem\nmax 1 9t8(x ;x ) sub x 3(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 ' 2\nt=0\nX\n1. State and prove the Optimality Principle. Discuss its importance.\n2. DeÖnetheoptimalpolicycorrespondenceandtheoptimalpolicyfunction. Discussitsimportance.",
#     'solution': '. See the lecture notes. !'}}}}

# %%
# First, add a helper function to clean text
def clean_text(text):
    # Remove "EXTRA PAGE" with any surrounding whitespace
    cleaned = re.sub(r'\s*EXTRA PAGE\s*', ' ', text)
    # Clean up any double spaces that might result
    cleaned = re.sub(r'\s+', ' ', cleaned)
    return cleaned.strip()

# Update the exam processing loop
for exam_key in classified_exams:
    # Clean the full text
    full_text = ' '.join(classified_exams[exam_key]['content'])
    full_text = clean_text(full_text)
    
    # Split and process questions
    questions = [x.strip() for x in re.split(r'Exercise\s*\d+', full_text)[1:]]
    questions = [x.split('Solution') for x in questions]

    classified_exams[exam_key]['questions'] = {}

    for i, q in enumerate(questions):
        classified_exams[exam_key]['questions']['Exercise '+str(i+1)] = {}
        # Clean question text
        classified_exams[exam_key]['questions']['Exercise '+str(i+1)]['question'] = clean_text(q[0])
        # Clean solution text if it exists
        if len(q) > 1:
            classified_exams[exam_key]['questions']['Exercise '+str(i+1)]['solution'] = clean_text(q[1])

# %%
classified_exams
# Out:
# {'General_2025-08-29': {'type': 'General',
#   'date': '2025-08-29',
#   'year': 2025,
#   'month': 8,
#   'day': 29,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)August 29, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Consider a functional f : R n R. State and prove the Riesz representation theorem\n!\n(that is, the theorem that provides a characterization for linear functionals).\nSolution See the lecture notes. (cid:4)',
#    'Exercise 2 Consider R n endowed with the d 1 distance.1 Consider a nonempty subset C of X. We\nsay that x in an algebraic interior point of C if and only if for each y R n there exists (cid:14) > 0 such\n2\nthat x+(cid:14)y C. We denote the set of all algebraic interior points of C by algC.\n2\n1. Prove that intC algC.\n(cid:18)\n2. Prove that if C is convex and x algC, then x C.\n2 2\n3. Prove that if C is convex, then intC = algC.\nSolution. 1. If intC = , then trivially we have that intC algC. If intC = , consider x intC.\n; (cid:18) 6 ; 2\nIt follows that there exists " > 0 such that B " (x) (cid:18) C. Consider y 2 R n. Set (cid:14) = k y k " 1 +1 > 0. Note\nthat d (x;x+(cid:14)y) = x+(cid:14)y x = (cid:14) y < ", proving that x+(cid:14)y B (x) C. Since x and y\n1 k (cid:0) k1 k k1 2 " (cid:18)\nwere arbitrarily chosen, it follows that x is an algebraic interior point of C whenever it is an interior\npoint of C, proving the point.\n2. Consider x algC and y R n. It follows that there exist (cid:14) + ;(cid:14) > 0 such that x+(cid:14) + y;x+\n2 2 (cid:0)\n(cid:14) ( y) C. Since C is convex, we can conclude that x+((cid:13)(cid:14) +(1 (cid:13))( (cid:14) ))y = (cid:13)(x+(cid:14) y)+\n+ +\n(cid:0) (cid:0) 2 (cid:0) (cid:0) (cid:0)\n(1 (cid:13))(x+(cid:14) ( y)) C for all (cid:13) [0;1]. In other words, x+(cid:14)y C for all (cid:14) [ (cid:14) ;(cid:14) ]. Since\n+\n(cid:0) (cid:0) (cid:0) 2 2 2 2 (cid:0) (cid:0)\n(cid:14) ;(cid:14) > 0, we have that 0 [ (cid:14) ;(cid:14) ], proving that x C.\n+ +\n3. (cid:0) Consider the canon 2 ica (cid:0) l b (cid:0) asis of R n: ei n .2 2 Consider x algC for each i 1;:::;n\ni=1 2 2 f g\nthere exist (cid:14) ;(cid:14) > 0 such that x + (cid:14) ei;x + (cid:14) ei C for all i 1;:::;n . De(cid:133)ne " =\nmin min +;i (cid:0) (cid:14) ;i ;min (cid:14) > + 0 ;i . B (cid:8) yt (cid:9) hep (cid:0) r ;i oo (cid:0) fofpo 2 int2,wehave 2 th f atx+"e g i;x+" ei\ni 1;:::;n +;i i 1;:::;n ;i\n2f g 2f g (cid:0) (cid:0) (cid:1) (cid:0) 2\nC for all i 1;:::;n . Consider y B (x). De(cid:133)ne z = y x. It follows that z = y x =\nd (x (cid:8) ;y) < " 2 . D f e(cid:133)ne (cid:22) g = z =" 0 f 2 or (cid:9) a " ll i 1;:::;n and (cid:22) (cid:0) = 1 n (cid:22) . k Ob k s 1 erve k th (cid:0) a (cid:0) t k1(cid:1)\n1 i j i j (cid:21) 2 f g n+1 (cid:0) i=1 i\nn n P\n" > z = z = " (cid:22) ;\nk k1 j i j i\ni=1 i=1\nX X\nproving that (cid:22) [0;1]. Moreover, we have that n+1(cid:22) = 1. By de(cid:133)nition of (cid:22) n+1, note that\nn+1 2 i=1 i f i gi=1\nn P\ny = x+z = x+ z ei = x+ "(cid:22) ei+ "(cid:22) ei\ni i i\n(cid:0)\nX\ni=1 i:\nX\nzi\n(cid:21)\n0 i:\nX\nzi<0\n(cid:0) (cid:1)\n= (cid:22) x+ (cid:22) x+"ei + (cid:22) x+" ei :\nn+1 i i\n(cid:0)\ni:\nX\nzi\n(cid:21)\n0\n(cid:0) (cid:1)\ni:\nX\nzi<0\n(cid:0) (cid:0) (cid:1)(cid:1)\nSince C is convex and x+(cid:14) ei;x+(cid:14) ei C for all i 1;:::;n , this implies that y is a convex\n+;i ;i\n(cid:0) (cid:0) 2 2 f g\nlinear combination of points which are in C and, in particular, y C. Since y was arbitrarily chosen,\n(cid:0) (cid:1) 2\nwe have that B (x) C, proving that x intC. Since x was arbitrarily chosen, algC intC. By\n"\n(cid:18) 2 (cid:18)\npoint 1, we can conclude that algC = intC. (cid:4)\nk x k2 1 1 G R = e iv c e a n ll n i i = th 1 a j x t 1 i d j ; 1 : f : o ( :; r x n ; a y ll , ) r x = ec 2 a P l R l n i n t = h . 1 a j t y i ei (cid:0) is x t i j he fo v r e a c l t l or x; in y R 2 n R s n u . ch R t e h c a a t ll it a s ls j o -t t h ha co t m d 1 po is ne i n n t du is ce 1 d (r b e y sp t . h 0 e ) n i o f r j m = k i k ( 1 re d sp e(cid:133) . n j e = d b i) y .\nP 2f g 6',
#    'Exercise 3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\nSolution See the lecture notes. (cid:4)',
#    'Exercise 4 Consider R n endowed with the supnorm .3 We say that an operator f : R n R n is\nk k !\nmonotone if and only if 1\nx y = f(x) f(y):4\n(cid:21) ) (cid:21)\nConsider two operators f;g : R n R n and assume they are both (cid:11)-contractions with (cid:11) (0;1).\n! 2\nDenote their unique (cid:133)xed points by x and x .\nf g\n1. Prove that if f g and f is monotone,5 then x x .\nf g\n(cid:21) (cid:21)\n2. Prove that if g = 1I + 1f,6 then x = x .\n2 2 f g\nSolution 1. By the Banach contraction principle and since (R n; ) is a complete metric space and\nk k\nf and g are (cid:11)-contractions, recall that 1\nlimfn(y) = x f and limgn(y) = x g y R n: (1)\nn n 8 2\nFix x R n. By induction, we will show that fn(x) gn(x) for all n N. Since f g, the inequality\n2 (cid:21) 2 (cid:21)\nfollows for n = 1, proving the initial step. Next assume the statement is true for n. We show it is\ntrue for n+1. Observe that fn+1(x) = f(fn(x)) f(gn(x)) g(gn(x)) = gn+1(x), proving the\n(cid:21) (cid:21)\ninductive step. By induction, the statement follows. By passing to the limit and (1), we can conclude\nthat\nx = limfn(x) limgn(x) = x ;\nf g\nn (cid:21) n\nproving the point.\n2. By the Banach contraction principle, observe that f and g admit each a unique (cid:133)xed point.\nNext, since x is a (cid:133)xed point of f, observe that\nf\n1 1 1 1\ng(x ) = I(x )+ f(x ) = x + x = x ;\nf f f f f f\n2 2 2 2\nproving that x is a (cid:133)xed point of g. Since the only (cid:133)xed point of g is x , we can conclude that\nf g\nx g = x f , proving the point. (cid:4)\n3 4 R R e e c c a a l l l l t t h h a a t t k x x k1y = if a m n a d x i o2nfl 1 y ;:: i : f ;n xgj x i j y fo f r o a r l a l l x l i 2 R n 1 . ;:::;n .\ni i\n5Recall that f (cid:21) g means that f(x) (cid:21) g(x) for a 2 ll f x R n. g\n6Recall that th (cid:21) e identity operator I i (cid:21) s such that I(x) 2 =x for all x R n.\n2',
#    'Exercise 5 Consider a metric space (X;d) and a continuous function f : X R. Assume C is a\n!\nclosed and bounded subset of X. Is it always true that f admits a maximizer on C, that is,\nmaxf(x) subject to x C\n2\nadmits solution?\nSolution No! ConsiderX = Nendowedwiththediscretedistanced(cid:22).7 SetC = N. Considerf : N R\n!\nde(cid:133)ned by f(n) = n for all n N. Note that:\n2\n1. Since in any metric space X is open and closed, so is C = X.\n2. Since d = d(cid:22), we have that B 2 (1) = n N : d(cid:22)(1;n) < 2 = N = C, proving that C is bounded.\n2\nd(cid:22) (cid:8) (cid:9)\n3. Recall that x n x if and only if there exists n(cid:22) N such that x n = x for all n n(cid:22) (cf. Exercise\n! 2 (cid:21)\n4, October 2014 and 2013). Indeed, we have that\nx n\nd(cid:22)\nx " > 0; n " N s.t. d(cid:22)(x n ;x) < " n n " = n 1=2 N s.t. d(cid:22)(x n ;x) < 1=2 n n 1=2\n! () 8 9 2 8 (cid:21) ) 9 2 8 (cid:21)\n= n 1=2 N s.t. d(cid:22)(x n ;x) = 0 n n 1=2 = x n = x n n 1=2 :\n) 9 2 8 (cid:21) ) 8 (cid:21)\nViceversa, we have that\nn(cid:22) N s.t. x n = x n n(cid:22) = " > 0; n " = n(cid:22) N s.t. d(cid:22)(x n ;x) = 0 < " n n " = x n\nd(cid:22)\nx:\n9 2 8 (cid:21) ) 8 9 2 8 (cid:21) ) !\n4. By point 3, we have that\nd(cid:22)\nx n x n(cid:22) N s.t. x n = x n n(cid:22) = n(cid:22) N s.t. f(x n ) = f(x) n n(cid:22) = f(x n ) f(x);\n! () 9 2 8 (cid:21) ) 9 2 8 (cid:21) ) !\nproving continuity of f.\nThus, our choice of X, d, C, and f (cid:133)ts the requirements above. Yet, f does not admit a maximizer\non C. By contradiction, assume that n(cid:22) C = N is a maximizer, that is, f(n(cid:22)) f(n) for all\n2 (cid:21)\nn C = N. Consider n^ = n(cid:22) +1. We have that f(n^) = f(n(cid:22)+1) = n(cid:22) +1 > n(cid:22) = f(n(cid:22)) f(n^), a\n2 (cid:21)\ncontradiction. (cid:4)\n7Recall that d(cid:22)(x;y)=1 if and only if x=y and d(cid:22)(x;y)=0 if and only if x=y.\n6',
#    'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Bellman Theorem.\nSolution See the lecture notes. (cid:4)',
#    'EXTRA PAGE'],
#   'questions': {'Exercise 1': {'question': 'Consider a functional f : R n R. State and prove the Riesz representation theorem ! (that is, the theorem that provides a characterization for linear functionals).',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 2': {'question': 'Consider R n endowed with the d 1 distance.1 Consider a nonempty subset C of X. We say that x in an algebraic interior point of C if and only if for each y R n there exists (cid:14) > 0 such 2 that x+(cid:14)y C. We denote the set of all algebraic interior points of C by algC. 2 1. Prove that intC algC. (cid:18) 2. Prove that if C is convex and x algC, then x C. 2 2 3. Prove that if C is convex, then intC = algC.',
#     'solution': '. 1. If intC = , then trivially we have that intC algC. If intC = , consider x intC. ; (cid:18) 6 ; 2 It follows that there exists " > 0 such that B " (x) (cid:18) C. Consider y 2 R n. Set (cid:14) = k y k " 1 +1 > 0. Note that d (x;x+(cid:14)y) = x+(cid:14)y x = (cid:14) y < ", proving that x+(cid:14)y B (x) C. Since x and y 1 k (cid:0) k1 k k1 2 " (cid:18) were arbitrarily chosen, it follows that x is an algebraic interior point of C whenever it is an interior point of C, proving the point. 2. Consider x algC and y R n. It follows that there exist (cid:14) + ;(cid:14) > 0 such that x+(cid:14) + y;x+ 2 2 (cid:0) (cid:14) ( y) C. Since C is convex, we can conclude that x+((cid:13)(cid:14) +(1 (cid:13))( (cid:14) ))y = (cid:13)(x+(cid:14) y)+ + + (cid:0) (cid:0) 2 (cid:0) (cid:0) (cid:0) (1 (cid:13))(x+(cid:14) ( y)) C for all (cid:13) [0;1]. In other words, x+(cid:14)y C for all (cid:14) [ (cid:14) ;(cid:14) ]. Since + (cid:0) (cid:0) (cid:0) 2 2 2 2 (cid:0) (cid:0) (cid:14) ;(cid:14) > 0, we have that 0 [ (cid:14) ;(cid:14) ], proving that x C. + + 3. (cid:0) Consider the canon 2 ica (cid:0) l b (cid:0) asis of R n: ei n .2 2 Consider x algC for each i 1;:::;n i=1 2 2 f g there exist (cid:14) ;(cid:14) > 0 such that x + (cid:14) ei;x + (cid:14) ei C for all i 1;:::;n . De(cid:133)ne " = min min +;i (cid:0) (cid:14) ;i ;min (cid:14) > + 0 ;i . B (cid:8) yt (cid:9) hep (cid:0) r ;i oo (cid:0) fofpo 2 int2,wehave 2 th f atx+"e g i;x+" ei i 1;:::;n +;i i 1;:::;n ;i 2f g 2f g (cid:0) (cid:0) (cid:1) (cid:0) 2 C for all i 1;:::;n . Consider y B (x). De(cid:133)ne z = y x. It follows that z = y x = d (x (cid:8) ;y) < " 2 . D f e(cid:133)ne (cid:22) g = z =" 0 f 2 or (cid:9) a " ll i 1;:::;n and (cid:22) (cid:0) = 1 n (cid:22) . k Ob k s 1 erve k th (cid:0) a (cid:0) t k1(cid:1) 1 i j i j (cid:21) 2 f g n+1 (cid:0) i=1 i n n P " > z = z = " (cid:22) ; k k1 j i j i i=1 i=1 X X proving that (cid:22) [0;1]. Moreover, we have that n+1(cid:22) = 1. By de(cid:133)nition of (cid:22) n+1, note that n+1 2 i=1 i f i gi=1 n P y = x+z = x+ z ei = x+ "(cid:22) ei+ "(cid:22) ei i i i (cid:0) X i=1 i: X zi (cid:21) 0 i: X zi<0 (cid:0) (cid:1) = (cid:22) x+ (cid:22) x+"ei + (cid:22) x+" ei : n+1 i i (cid:0) i: X zi (cid:21) 0 (cid:0) (cid:1) i: X zi<0 (cid:0) (cid:0) (cid:1)(cid:1) Since C is convex and x+(cid:14) ei;x+(cid:14) ei C for all i 1;:::;n , this implies that y is a convex +;i ;i (cid:0) (cid:0) 2 2 f g linear combination of points which are in C and, in particular, y C. Since y was arbitrarily chosen, (cid:0) (cid:1) 2 we have that B (x) C, proving that x intC. Since x was arbitrarily chosen, algC intC. By " (cid:18) 2 (cid:18) point 1, we can conclude that algC = intC. (cid:4) k x k2 1 1 G R = e iv c e a n ll n i i = th 1 a j x t 1 i d j ; 1 : f : o ( :; r x n ; a y ll , ) r x = ec 2 a P l R l n i n t = h . 1 a j t y i ei (cid:0) is x t i j he fo v r e a c l t l or x; in y R 2 n R s n u . ch R t e h c a a t ll it a s ls j o -t t h ha co t m d 1 po is ne i n n t du is ce 1 d (r b e y sp t . h 0 e ) n i o f r j m = k i k ( 1 re d sp e(cid:133) . n j e = d b i) y . P 2f g 6'},
#    'Exercise 3': {'question': 'Prove that a linear operator T : V V between normed vector spaces is continuous at 1 2 ! a point v V if and only if it is continuous on V . 1 1 2',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 4': {'question': 'Consider R n endowed with the supnorm .3 We say that an operator f : R n R n is k k ! monotone if and only if 1 x y = f(x) f(y):4 (cid:21) ) (cid:21) Consider two operators f;g : R n R n and assume they are both (cid:11)-contractions with (cid:11) (0;1). ! 2 Denote their unique (cid:133)xed points by x and x . f g 1. Prove that if f g and f is monotone,5 then x x . f g (cid:21) (cid:21) 2. Prove that if g = 1I + 1f,6 then x = x . 2 2 f g',
#     'solution': '1. By the Banach contraction principle and since (R n; ) is a complete metric space and k k f and g are (cid:11)-contractions, recall that 1 limfn(y) = x f and limgn(y) = x g y R n: (1) n n 8 2 Fix x R n. By induction, we will show that fn(x) gn(x) for all n N. Since f g, the inequality 2 (cid:21) 2 (cid:21) follows for n = 1, proving the initial step. Next assume the statement is true for n. We show it is true for n+1. Observe that fn+1(x) = f(fn(x)) f(gn(x)) g(gn(x)) = gn+1(x), proving the (cid:21) (cid:21) inductive step. By induction, the statement follows. By passing to the limit and (1), we can conclude that x = limfn(x) limgn(x) = x ; f g n (cid:21) n proving the point. 2. By the Banach contraction principle, observe that f and g admit each a unique (cid:133)xed point. Next, since x is a (cid:133)xed point of f, observe that f 1 1 1 1 g(x ) = I(x )+ f(x ) = x + x = x ; f f f f f f 2 2 2 2 proving that x is a (cid:133)xed point of g. Since the only (cid:133)xed point of g is x , we can conclude that f g x g = x f , proving the point. (cid:4) 3 4 R R e e c c a a l l l l t t h h a a t t k x x k1y = if a m n a d x i o2nfl 1 y ;:: i : f ;n xgj x i j y fo f r o a r l a l l x l i 2 R n 1 . ;:::;n . i i 5Recall that f (cid:21) g means that f(x) (cid:21) g(x) for a 2 ll f x R n. g 6Recall that th (cid:21) e identity operator I i (cid:21) s such that I(x) 2 =x for all x R n. 2'},
#    'Exercise 5': {'question': 'Consider a metric space (X;d) and a continuous function f : X R. Assume C is a ! closed and bounded subset of X. Is it always true that f admits a maximizer on C, that is, maxf(x) subject to x C 2 admits solution?',
#     'solution': 'No! ConsiderX = Nendowedwiththediscretedistanced(cid:22).7 SetC = N. Considerf : N R ! de(cid:133)ned by f(n) = n for all n N. Note that: 2 1. Since in any metric space X is open and closed, so is C = X. 2. Since d = d(cid:22), we have that B 2 (1) = n N : d(cid:22)(1;n) < 2 = N = C, proving that C is bounded. 2 d(cid:22) (cid:8) (cid:9) 3. Recall that x n x if and only if there exists n(cid:22) N such that x n = x for all n n(cid:22) (cf. Exercise ! 2 (cid:21) 4, October 2014 and 2013). Indeed, we have that x n d(cid:22) x " > 0; n " N s.t. d(cid:22)(x n ;x) < " n n " = n 1=2 N s.t. d(cid:22)(x n ;x) < 1=2 n n 1=2 ! () 8 9 2 8 (cid:21) ) 9 2 8 (cid:21) = n 1=2 N s.t. d(cid:22)(x n ;x) = 0 n n 1=2 = x n = x n n 1=2 : ) 9 2 8 (cid:21) ) 8 (cid:21) Viceversa, we have that n(cid:22) N s.t. x n = x n n(cid:22) = " > 0; n " = n(cid:22) N s.t. d(cid:22)(x n ;x) = 0 < " n n " = x n d(cid:22) x: 9 2 8 (cid:21) ) 8 9 2 8 (cid:21) ) ! 4. By point 3, we have that d(cid:22) x n x n(cid:22) N s.t. x n = x n n(cid:22) = n(cid:22) N s.t. f(x n ) = f(x) n n(cid:22) = f(x n ) f(x); ! () 9 2 8 (cid:21) ) 9 2 8 (cid:21) ) ! proving continuity of f. Thus, our choice of X, d, C, and f (cid:133)ts the requirements above. Yet, f does not admit a maximizer on C. By contradiction, assume that n(cid:22) C = N is a maximizer, that is, f(n(cid:22)) f(n) for all 2 (cid:21) n C = N. Consider n^ = n(cid:22) +1. We have that f(n^) = f(n(cid:22)+1) = n(cid:22) +1 > n(cid:22) = f(n(cid:22)) f(n^), a 2 (cid:21) contradiction. (cid:4) 7Recall that d(cid:22)(x;y)=1 if and only if x=y and d(cid:22)(x;y)=0 if and only if x=y. 6'},
#    'Exercise 6': {'question': 'Consider the reduced form problem 1 max (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF) t t+1 t+1 t 0 x 2 8 (cid:21) 2 t=0 X 1. State and prove the Bellman Theorem.',
#     'solution': 'See the lecture notes. (cid:4)'}}},
#  'General_2025-01-27': {'type': 'General',
#   'date': '2025-01-27',
#   'year': 2025,
#   'month': 1,
#   'day': 27,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 27, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let S be a nonempty subset of a vector space V.\n1. De(cid:133)ne spanS.\n2. Fix n\n2\nN. If S =\nf\nx\ni g\nn\ni=1\n, show that\nn\nspanS = x 2 V : 9f (cid:11) i g n i=1 (cid:18) R s.t. x = (cid:11) i x i :\n( )\ni=1\nX\nSolution See the lecture notes. (cid:4)',
#    'Exercise 2 Let (X;d) be a metric space and D a subsetof X such that cl(D) = X.1 Prove that if\nA X is closed and such that cl(intA) = A, then cl(A D) = A.\n(cid:18) \\\nSolution. Since cl(intA) = A, A is empty if and only if intA is empty. If A is empty, trivially, we\nhave that cl(A D) = cl( ) = = A. If A is not empty, we have that intA = . Fix x intA. Since\n\\ ; ; 6 ; 2\ncl(D) = X, there exists a sequence x D such that x x. Since x intA and the latter\nf n gn N (cid:18) n ! 2\nis open, this implies that there exists " >20 such that B (x) intA and, in particular, there exists\n"\n(cid:18)\nn " N such that x n B " (x) intA for all n n " . We can conclude that x cl(intA D). Since x\n2 2 (cid:18) (cid:21) 2 \\\nwas arbitrarily chosen, we have that\nintA cl(intA D) = A = cl(intA) cl(intA D) cl(A D) cl(A) = A;\n(cid:18) \\ ) (cid:18) \\ (cid:18) \\ (cid:18)\nproving the statement. (cid:4)\n1Inthisexercise,givenasubsetB ofX,bycl(B),wemeantheclosureofB,whichisalsodenotedasB(cid:22) inthelecture\nnotes.',
#    'Exercise 3 Prove that a linear operator T : V V between normed vector spaces is continuous at\n1 2\n!\na point v V if and only if it is continuous on V .\n1 1\n2\nSolution See the lecture notes. (cid:4)',
#    'Exercise 4 Consider the space of real-valued bounded sequences, denoted ‘ , endowed with the sup-\n1\nnorm ,2 that is,\nk k\n1\n‘\n1\n= x RN : sup x\nn\n< :\n2 j j 1\n(cid:26) n N (cid:27)\n2\nLet T : ‘ ‘ be such that for each x ‘ we de(cid:133)ne ax = T (x) to be such that\n1 1 1\n! 2\nx +:::+x\nax\nn\n= 1\nn\nn\n8\nn\n2\nN: (1)\n1. Compute the operator norm of T. Motivate your answer!\n2. Is T a contraction? Motivate your answer!\nSolution 1. Fix x ‘ . Observe that\n1\n2\nn n\nx +:::+x 1 1\nj\nax\nn j\n= 1\nn\nn\n(cid:20) n j\nx\ni j (cid:20) n k\nx\nk\n=\nk\nx\nk 8\nn\n2\nN;\n(cid:12) (cid:12) i=1 i=1 1 1\n(cid:12) (cid:12) X X\n(cid:12) (cid:12)\nproving that sup ax(cid:12) x . By(cid:12)de(cid:133)nition of T and since x was arbitrarily chosen, it follows that\nn 2 Nj n j (cid:20) k k 1\nT (x) = sup ax x x ‘ :\nn 1\nk k j j (cid:20) k k 8 2\n1 n N 1\n2\nBy de(cid:133)nition of operator norm, we have that T 1. Next, consider the sequence e ‘ such that\n1\nk k (cid:20) 2\ne\nn\n= 1 for all n N. It follows that (cid:3)\n2\ne +:::+e\nae\nn\n= 1\nn\nn = 1\n8\nn\n2\nN;\nyieldingthatae = eand,inparticular, T (e) = ae = e . Bythecharacterizationofoperator\nk k k k k k\nnorm and since e = sup e = 1, we ha1ve that 1 1\nk k 1 n 2 Nj n j\nT = sup T (x) T (e) = 1:\nk k k k (cid:21) k k\n(cid:3) x ‘ : x =1 1 1\n2 1k k1\nWe can conclude that T = 1 (cf. Exercise 4, January 9th, 2023).\nk k\n(cid:3)\n2. No! Since T is linear, to be a contraction T needs to be such that T < 1, which is not the\nk k\ncase. Alternatively, you can check that it has more than one (cid:133)xed point, for ex(cid:3)ample, e and 0. (cid:4)\n2Recall that\nk\nx\nk1\n=sup\nn 2 Nj\nx\nn j\nfor all x\n2\n‘1.',
#    'Exercise 5 Consider a normed vector space X with norm and a nonempty closed subset C of X.\nk k\nDe(cid:133)ne f : X [0; ) by\n! 1\nf(x) = inf x y x X:\ny Ck (cid:0) k 8 2\n2\nProve that f is convex if and only if C is convex.\nSolution (cid:147)If(cid:148). Consider x\n0\n;x\n1\nX and (cid:21) (0;1). Consider n N. By de(cid:133)nition of inf and f, we\n2 2 2\nhave that there exist y ;y C such that\n0 1\n2\n1 1\nf(x ) = inf x y x y and f(x ) = inf x y x y :\n0 0 0 0 1 1 1 1\ny Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n y Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n\n2 2\nDe(cid:133)ne x = (cid:21)x +(1 (cid:21))x and y = (cid:21)y +(1 (cid:21))y . Since y ;y C and C is convex, we have\n(cid:21) 1 0 (cid:21) 1 0 0 1\n(cid:0) (cid:0) 2\nthat y C. By de(cid:133)nition of f, we can conclude that\n(cid:21)\n2\nf((cid:21)x +(1 (cid:21))x ) = f(x ) = inf x y x y\n1 0 (cid:21) (cid:21) (cid:21) (cid:21)\n(cid:0) y Ck (cid:0) k (cid:20) k (cid:0) k\n2\n= (cid:21)x +(1 (cid:21))x (cid:21)y (1 (cid:21))y = (cid:21)(x y )+(1 (cid:21))(x y )\n1 0 1 0 1 1 0 0\nk (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 1\n(cid:21) x y +(1 (cid:21)) x y (cid:21) f(x )+ +(1 (cid:21)) f(x )+\n1 1 0 0 0 1\n(cid:20) k (cid:0) k (cid:0) k (cid:0) k (cid:20) n (cid:0) n\n(cid:18) (cid:19) (cid:18) (cid:19)\n1\n= (cid:21)f(x )+(1 (cid:21))f(x )+ :\n0 1\n(cid:0) n\nSince x , x , (cid:21), and n were arbitrarily chosen, f is convex and the implication follows (cf. Exercise 4\n0 1\nof the exams of September 2020 or January 8th, 2020).\n(cid:147)Only if(cid:148). First, observe that\nx C f(x) = 0: (2)\n2 ()\nIn fact, by de(cid:133)nition of f, we have that\nx C = 0 = x x inf x y = f(x) 0:\n2 ) k (cid:0) k (cid:21) y Ck (cid:0) k (cid:21)\n2\nMoreover, if inf x y = 0, then there exists a sequence y C such that x y\ninf x y = y 2 f C ( k x) (cid:0) = 0 k . Since C is closed, this implies that f y n gn 2x N , (cid:18) proving that x k C (cid:0) . W n k ith #\ny C n\n2 k (cid:0) k ! 2\nthis, take x ;x C and (cid:21) (0;1). By (2) and since f is convex and x ;x C, we can conclude\n1 0 1 0\n2 2 2\nthat\n0 f((cid:21)x +(1 (cid:21))x ) (cid:21)f(x )+(1 (cid:21))f(x ) = 0 = f((cid:21)x +(1 (cid:21))x ) = 0 = (cid:21)x +(1 (cid:21))x C:\n1 0 1 0 1 0 1 0\n(cid:20) (cid:0) (cid:20) (cid:0) ) (cid:0) ) (cid:0) 2\nSince x 0 , x 1 , and (cid:21) were arbitrarily chosen, C is convex and the implication follows. (cid:4)',
#    'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. De(cid:133)ne the optimal policy correspondence and the optimal policy function.\n2. De(cid:133)ne when a path x =(x ;x ;x ;:::) is sequentially optimal for problem RF (x ).\n0 1 2 0\nSolution 1. See the lecture notes.\n2. See the lecture notes. (cid:4)',
#    'EXTRA PAGE'],
#   'questions': {'Exercise 1': {'question': 'Let S be a nonempty subset of a vector space V. 1. De(cid:133)ne spanS. 2. Fix n 2 N. If S = f x i g n i=1 , show that n spanS = x 2 V : 9f (cid:11) i g n i=1 (cid:18) R s.t. x = (cid:11) i x i : ( ) i=1 X',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 2': {'question': 'Let (X;d) be a metric space and D a subsetof X such that cl(D) = X.1 Prove that if A X is closed and such that cl(intA) = A, then cl(A D) = A. (cid:18) \\',
#     'solution': '. Since cl(intA) = A, A is empty if and only if intA is empty. If A is empty, trivially, we have that cl(A D) = cl( ) = = A. If A is not empty, we have that intA = . Fix x intA. Since \\ ; ; 6 ; 2 cl(D) = X, there exists a sequence x D such that x x. Since x intA and the latter f n gn N (cid:18) n ! 2 is open, this implies that there exists " >20 such that B (x) intA and, in particular, there exists " (cid:18) n " N such that x n B " (x) intA for all n n " . We can conclude that x cl(intA D). Since x 2 2 (cid:18) (cid:21) 2 \\ was arbitrarily chosen, we have that intA cl(intA D) = A = cl(intA) cl(intA D) cl(A D) cl(A) = A; (cid:18) \\ ) (cid:18) \\ (cid:18) \\ (cid:18) proving the statement. (cid:4) 1Inthisexercise,givenasubsetB ofX,bycl(B),wemeantheclosureofB,whichisalsodenotedasB(cid:22) inthelecture notes.'},
#    'Exercise 3': {'question': 'Prove that a linear operator T : V V between normed vector spaces is continuous at 1 2 ! a point v V if and only if it is continuous on V . 1 1 2',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 4': {'question': 'Consider the space of real-valued bounded sequences, denoted ‘ , endowed with the sup- 1 norm ,2 that is, k k 1 ‘ 1 = x RN : sup x n < : 2 j j 1 (cid:26) n N (cid:27) 2 Let T : ‘ ‘ be such that for each x ‘ we de(cid:133)ne ax = T (x) to be such that 1 1 1 ! 2 x +:::+x ax n = 1 n n 8 n 2 N: (1) 1. Compute the operator norm of T. Motivate your answer! 2. Is T a contraction? Motivate your answer!',
#     'solution': '1. Fix x ‘ . Observe that 1 2 n n x +:::+x 1 1 j ax n j = 1 n n (cid:20) n j x i j (cid:20) n k x k = k x k 8 n 2 N; (cid:12) (cid:12) i=1 i=1 1 1 (cid:12) (cid:12) X X (cid:12) (cid:12) proving that sup ax(cid:12) x . By(cid:12)de(cid:133)nition of T and since x was arbitrarily chosen, it follows that n 2 Nj n j (cid:20) k k 1 T (x) = sup ax x x ‘ : n 1 k k j j (cid:20) k k 8 2 1 n N 1 2 By de(cid:133)nition of operator norm, we have that T 1. Next, consider the sequence e ‘ such that 1 k k (cid:20) 2 e n = 1 for all n N. It follows that (cid:3) 2 e +:::+e ae n = 1 n n = 1 8 n 2 N; yieldingthatae = eand,inparticular, T (e) = ae = e . Bythecharacterizationofoperator k k k k k k norm and since e = sup e = 1, we ha1ve that 1 1 k k 1 n 2 Nj n j T = sup T (x) T (e) = 1: k k k k (cid:21) k k (cid:3) x ‘ : x =1 1 1 2 1k k1 We can conclude that T = 1 (cf.'},
#    'Exercise 5': {'question': ', January 9th, 2023). k k (cid:3) 2. No! Since T is linear, to be a contraction T needs to be such that T < 1, which is not the k k case. Alternatively, you can check that it has more than one (cid:133)xed point, for ex(cid:3)ample, e and 0. (cid:4) 2Recall that k x k1 =sup n 2 Nj x n j for all x 2 ‘1.'},
#    'Exercise 6': {'question': 'Consider a normed vector space X with norm and a nonempty closed subset C of X. k k De(cid:133)ne f : X [0; ) by ! 1 f(x) = inf x y x X: y Ck (cid:0) k 8 2 2 Prove that f is convex if and only if C is convex.',
#     'solution': '(cid:147)If(cid:148). Consider x 0 ;x 1 X and (cid:21) (0;1). Consider n N. By de(cid:133)nition of inf and f, we 2 2 2 have that there exist y ;y C such that 0 1 2 1 1 f(x ) = inf x y x y and f(x ) = inf x y x y : 0 0 0 0 1 1 1 1 y Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n y Ck (cid:0) k (cid:21) k (cid:0) k(cid:0) n 2 2 De(cid:133)ne x = (cid:21)x +(1 (cid:21))x and y = (cid:21)y +(1 (cid:21))y . Since y ;y C and C is convex, we have (cid:21) 1 0 (cid:21) 1 0 0 1 (cid:0) (cid:0) 2 that y C. By de(cid:133)nition of f, we can conclude that (cid:21) 2 f((cid:21)x +(1 (cid:21))x ) = f(x ) = inf x y x y 1 0 (cid:21) (cid:21) (cid:21) (cid:21) (cid:0) y Ck (cid:0) k (cid:20) k (cid:0) k 2 = (cid:21)x +(1 (cid:21))x (cid:21)y (1 (cid:21))y = (cid:21)(x y )+(1 (cid:21))(x y ) 1 0 1 0 1 1 0 0 k (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) (cid:0) (cid:0) k 1 1 (cid:21) x y +(1 (cid:21)) x y (cid:21) f(x )+ +(1 (cid:21)) f(x )+ 1 1 0 0 0 1 (cid:20) k (cid:0) k (cid:0) k (cid:0) k (cid:20) n (cid:0) n (cid:18) (cid:19) (cid:18) (cid:19) 1 = (cid:21)f(x )+(1 (cid:21))f(x )+ : 0 1 (cid:0) n Since x , x , (cid:21), and n were arbitrarily chosen, f is convex and the implication follows (cf.'},
#    'Exercise 7': {'question': '0 1 of the exams of September 2020 or January 8th, 2020). (cid:147)Only if(cid:148). First, observe that x C f(x) = 0: (2) 2 () In fact, by de(cid:133)nition of f, we have that x C = 0 = x x inf x y = f(x) 0: 2 ) k (cid:0) k (cid:21) y Ck (cid:0) k (cid:21) 2 Moreover, if inf x y = 0, then there exists a sequence y C such that x y inf x y = y 2 f C ( k x) (cid:0) = 0 k . Since C is closed, this implies that f y n gn 2x N , (cid:18) proving that x k C (cid:0) . W n k ith # y C n 2 k (cid:0) k ! 2 this, take x ;x C and (cid:21) (0;1). By (2) and since f is convex and x ;x C, we can conclude 1 0 1 0 2 2 2 that 0 f((cid:21)x +(1 (cid:21))x ) (cid:21)f(x )+(1 (cid:21))f(x ) = 0 = f((cid:21)x +(1 (cid:21))x ) = 0 = (cid:21)x +(1 (cid:21))x C: 1 0 1 0 1 0 1 0 (cid:20) (cid:0) (cid:20) (cid:0) ) (cid:0) ) (cid:0) 2 Since x 0 , x 1 , and (cid:21) were arbitrarily chosen, C is convex and the implication follows. (cid:4)'},
#    'Exercise 8': {'question': 'Consider the reduced form problem 1 max (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF) t t+1 t+1 t 0 x 2 8 (cid:21) 2 t=0 X 1. De(cid:133)ne the optimal policy correspondence and the optimal policy function. 2. De(cid:133)ne when a path x =(x ;x ;x ;:::) is sequentially optimal for problem RF (x ). 0 1 2 0',
#     'solution': '1. See the lecture notes. 2. See the lecture notes. (cid:4)'}}},
#  'General_2025-01-07': {'type': 'General',
#   'date': '2025-01-07',
#   'year': 2025,
#   'month': 1,
#   'day': 7,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam (cid:150)January 7, 2025\nSurname Student ID\nName Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and undersign my presence\nat the exam.\nSignature:\nExercise 1 Let V be a vector space.\n1. Give the de(cid:133)nition of vector subspace.\n2. Prove that the intersection of any family of vector subspaces of V is a vector subspace of V.\nSolution See the lecture notes. (cid:4)',
#    'Exercise 2 Consider a nonempty set X and assume that d and d are two di⁄erent distances on X.\na b\nAssume that the following property holds: each convergent sequence with respect to d is convergent\na\nwith respect to d and the limit is the same, that is, in symbols, for each x X\nb f n gn N (cid:18)\n2\nx\nda\nx = x\ndb\nx: (1)\nn n\n! ) !\n1. Prove that if O X is open with respect to d , then it is open with respect to d .\nb a\n(cid:18)\n2. Prove that if K is compact with respect to d , then it is compact with respect to d .\na b\nSolution 1. Consider a set O which is open with respect to d . It follows that C = Oc is closed\nb\nwith respect to d . We next show that C is closed also with respect to d . Consider a sequence\nb a\nx C such that x\nda\nx. By (1), it follows that x\ndb\nx. Since C is d -closed, we can conclude\nf n gn N (cid:18) n ! n ! b\nthat x2 C. Since x was arbitrarily chosen, it follows that C is d -closed and, in particular,\nO = (O 2 c)c = Cc is o f pe n n gn w2i N th respect to d , proving the statement. a\na\n2. Proof1. Consideracollection O suchthatO isd -openforall(cid:11) AandK O .\nIn other words, O is an open f co (cid:11) ve g r (cid:11) 2f A or K with re (cid:11) spect b to d . Since se 2 ts that are (cid:18) op [ e (cid:11) n 2 A wit (cid:11) h\nf (cid:11) g(cid:11) A b\nrespect to d are open w2ith respect to d , we have that O is an open cover for K with respect\nb a f (cid:11) g(cid:11) A\nto d . Since K is compact with respect to d , we have that the2re exists a (cid:133)nite subcover of O ,\na a f (cid:11) g(cid:11) A\nproving that K is compact with respect to d . 2\nb\nProof 2. Consider a sequence x in K. By Bolzano-Weierstrass Theorem and (1) and\nf n gn N\nsince K is compact with respect to d , th2ere exists a subsequence x x such that\na f nkgk N (cid:18) f n gn N\nx\nda\nx K, proving that x\ndb\nx K. This implies that each sequence in\n2\nK admits a\n2\nsubsequence\nnk\n! 2\nnk\n! 2\nwhich converges, with respect to d , to a point in K. By Bolzano-Weierstrass Theorem, we can\nb\nconclude that K is compact with respect to d b . (cid:4)',
#    'Exercise 3 Consider R 3 and de(cid:133)ne : R 3 [0; ) by\nk k ! 1\nk x k = j x 1 j + x2 2 +x2 3 8 x 2 R 3:\nq\nIs a norm?\nk k\nSolution Yes! De(cid:133)ne (cid:25) : R 3 R 2 by (cid:25)(x) = (x 2 ;x 3 ) for all x R 3, that is,\n! 2\nx\n0 1 0 1\n(cid:25)(x) = 0 0 1 0 x 2 1 8 x 2 R 3:\n(cid:18) (cid:19) x 3\n@ A\nIt follows that\nk x k = j x 1 j + k (cid:25)(x) k2 8 x 2 R 3\nwhere : R 2 [0; ) is the Euclidean norm, that is, z = z2+z2 for all z R 2. We now\nk k2 ! 1 k k2 1 2 2\nprove the three properties of norm.\np\n1. Since is a norm, note that\nk k2\nx = 0 x + (cid:25)(x) = 0 x = (cid:25)(x) = 0 x = 0 and (cid:25)(x) = 0\nk k () j 1 j k k2 () j 1 j k k2 () 1\nx = x = x = 0 x = 0:\n1 2 3\n() ()\n2. Since is a norm and (cid:25) is linear, for each (cid:21) R and for each x R 3, we have that\nk k2 2 2\n(cid:21)x = (cid:21)x + (cid:25)((cid:21)x) = (cid:21) x + (cid:21)(cid:25)(x) = (cid:21) ( x + (cid:25)(x) ) = (cid:21) x :\nk k j 1 j k k2 j jj 1 j k k2 j j j 1 j k k2 j jk k\n3. Since is a norm and (cid:25) is linear, for each x;y R 3, we have that\nk k2 2\nx+y = x +y + (cid:25)(x+y) = x +y + (cid:25)(x)+(cid:25)(y)\nk k j 1 1 j k k2 j 1 1 j k k2\nx + (cid:25)(x) + y + (cid:25)(y) = x + y :\n(cid:20) j 1 j k k2 j 1 j k k2 k k k k\nThe three properties prove that is a norm. (cid:4)\nk k',
#    'Exercise 4 Consider R n endowed with the supnorm .1 Let T : R n R n be such that\nk k !\n1\nT (x) T (y) x y x;y R n: (2)\nk (cid:0) k (cid:20) k (cid:0) k 8 2\n1 1\n1. If x R n and (cid:11) (0;1), prove that there exist two unique points in R n, x (cid:11) and x~ (cid:11) , such that\n2 2\nx = T ((1 (cid:11))x+(cid:11)x ) and x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11) (cid:11) (cid:11)\n(cid:0) (cid:0)\n2. Prove that x~ = (1 (cid:11))x+(cid:11)x .\n(cid:11) (cid:11)\n(cid:0)\nSolution De(cid:133)ne T (cid:11);x ;T~ (cid:11);x : R n R n by\n!\nT (cid:11);x (y) = T ((1 (cid:11))x+(cid:11)y) and T~ (cid:11);x (y) = (1 (cid:11))x+(cid:11)T (y) y R n:\n(cid:0) (cid:0) 8 2\nNote that\nx = T (x ) x = T ((1 (cid:11))x+(cid:11)x )\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nand\nx~ = T~ (x~ ) x~ = (1 (cid:11))x+(cid:11)T (x~ ):\n(cid:11) (cid:11);x (cid:11) (cid:11) (cid:11)\n() (cid:0)\nIn other words, the points (x and x~ ) we are after are the (cid:133)xed points of the two operators T and\n(cid:11) (cid:11) (cid:11);x\nT~ , respectively.\n(cid:11);x\n1. Since T satis(cid:133)es (2), we have that\nT (y) T (z) = T ((1 (cid:11))x+(cid:11)y) T ((1 (cid:11))x+(cid:11)z)\n(cid:11);x (cid:11);x\nk (cid:0) k k (cid:0) (cid:0) (cid:0) k\n1 (1 (cid:11))x+(cid:11)y (1 (cid:11))x (cid:11)z = (cid:11) 1 y z y;z R n\n(cid:20) k (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) k 8 2\n1 1\nand\nT~ (y) T~ (z) = (1 (cid:11))x+(cid:11)T (y) (1 (cid:11))x (cid:11)T (z)\n(cid:11);x (cid:11);x\n(cid:0) k (cid:0) (cid:0) (cid:0) (cid:0) k\n1\n(cid:13) (cid:13) (cid:13) (cid:13) 1 = (cid:11) T (y) T (z) (cid:11) y z y;z R n:\n(cid:13) (cid:13) k (cid:0) k 1 (cid:20) k (cid:0) k 1 8 2\nInotherwords,since(cid:11) (0;1),T andT~ are(cid:11)-contractions. BytheBanachContractionprinciple\n(cid:11);x (cid:11);x\nand since (R n; ) is 2 complete, this implies that T\n(cid:11);x\nand T~\n(cid:11);x\nhave each a unique (cid:133)xed point which\nk k\nwe denote respect1ively x and x~ , that is,\n(cid:11) (cid:11)\nT ((1 (cid:11))x+(cid:11)x ) = T (x ) = x\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nand\n(1 (cid:11))x+(cid:11)T (x~ ) = T~ (x~ ) = x~ ;\n(cid:11) (cid:11);x (cid:11) (cid:11)\n(cid:0)\nproving that x and x~ exist and are unique.\n(cid:11) (cid:11)\n2. Set x^ = (1 (cid:11))x+(cid:11)x . We have that\n(cid:11) (cid:11)\n(cid:0)\nx^ = (1 (cid:11))x+(cid:11)x = (1 (cid:11))x+(cid:11)T ((1 (cid:11))x+(cid:11)x ) = (1 (cid:11))x+(cid:11)T (x^ ) = T~ (x^ );\n(cid:11) (cid:11) (cid:11) (cid:11) (cid:11);x (cid:11)\n(cid:0) (cid:0) (cid:0) (cid:0)\nproving that x^ is a (cid:133)xed point of T~ . Since this point is unique and is x~ . It follows that x~ =\n(cid:11) (cid:11);x (cid:11) (cid:11)\nx^ = (1 (cid:11))x+(cid:11)x , proving the equality (cf. Exercise 4 of the exams of September 2024, 2021, and\n(cid:11) (cid:11)\n(cid:0)\n2019). (cid:4)\n1Recall that k x k1 =max i 2f 1;:::;n gj x i j for all x 2 R n.',
#    'Exercise 5 State and prove the Blackwell(cid:146)s theorem.\nSolution See the lecture notes. (cid:4)',
#    'Exercise 6 Consider the reduced form problem\n1\nmax (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 (cid:21) 2\nt=0\nX\n1. State and prove the Optimality Principle.\nSolution See the lecture notes. (cid:4)',
#    'EXTRA PAGE'],
#   'questions': {'Exercise 1': {'question': 'Let V be a vector space. 1. Give the de(cid:133)nition of vector subspace. 2. Prove that the intersection of any family of vector subspaces of V is a vector subspace of V.',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 2': {'question': 'Consider a nonempty set X and assume that d and d are two di⁄erent distances on X. a b Assume that the following property holds: each convergent sequence with respect to d is convergent a with respect to d and the limit is the same, that is, in symbols, for each x X b f n gn N (cid:18) 2 x da x = x db x: (1) n n ! ) ! 1. Prove that if O X is open with respect to d , then it is open with respect to d . b a (cid:18) 2. Prove that if K is compact with respect to d , then it is compact with respect to d . a b',
#     'solution': '1. Consider a set O which is open with respect to d . It follows that C = Oc is closed b with respect to d . We next show that C is closed also with respect to d . Consider a sequence b a x C such that x da x. By (1), it follows that x db x. Since C is d -closed, we can conclude f n gn N (cid:18) n ! n ! b that x2 C. Since x was arbitrarily chosen, it follows that C is d -closed and, in particular, O = (O 2 c)c = Cc is o f pe n n gn w2i N th respect to d , proving the statement. a a 2. Proof1. Consideracollection O suchthatO isd -openforall(cid:11) AandK O . In other words, O is an open f co (cid:11) ve g r (cid:11) 2f A or K with re (cid:11) spect b to d . Since se 2 ts that are (cid:18) op [ e (cid:11) n 2 A wit (cid:11) h f (cid:11) g(cid:11) A b respect to d are open w2ith respect to d , we have that O is an open cover for K with respect b a f (cid:11) g(cid:11) A to d . Since K is compact with respect to d , we have that the2re exists a (cid:133)nite subcover of O , a a f (cid:11) g(cid:11) A proving that K is compact with respect to d . 2 b Proof 2. Consider a sequence x in K. By Bolzano-Weierstrass Theorem and (1) and f n gn N since K is compact with respect to d , th2ere exists a subsequence x x such that a f nkgk N (cid:18) f n gn N x da x K, proving that x db x K. This implies that each sequence in 2 K admits a 2 subsequence nk ! 2 nk ! 2 which converges, with respect to d , to a point in K. By Bolzano-Weierstrass Theorem, we can b conclude that K is compact with respect to d b . (cid:4)'},
#    'Exercise 3': {'question': 'Consider R 3 and de(cid:133)ne : R 3 [0; ) by k k ! 1 k x k = j x 1 j + x2 2 +x2 3 8 x 2 R 3: q Is a norm? k k',
#     'solution': 'Yes! De(cid:133)ne (cid:25) : R 3 R 2 by (cid:25)(x) = (x 2 ;x 3 ) for all x R 3, that is, ! 2 x 0 1 0 1 (cid:25)(x) = 0 0 1 0 x 2 1 8 x 2 R 3: (cid:18) (cid:19) x 3 @ A It follows that k x k = j x 1 j + k (cid:25)(x) k2 8 x 2 R 3 where : R 2 [0; ) is the Euclidean norm, that is, z = z2+z2 for all z R 2. We now k k2 ! 1 k k2 1 2 2 prove the three properties of norm. p 1. Since is a norm, note that k k2 x = 0 x + (cid:25)(x) = 0 x = (cid:25)(x) = 0 x = 0 and (cid:25)(x) = 0 k k () j 1 j k k2 () j 1 j k k2 () 1 x = x = x = 0 x = 0: 1 2 3 () () 2. Since is a norm and (cid:25) is linear, for each (cid:21) R and for each x R 3, we have that k k2 2 2 (cid:21)x = (cid:21)x + (cid:25)((cid:21)x) = (cid:21) x + (cid:21)(cid:25)(x) = (cid:21) ( x + (cid:25)(x) ) = (cid:21) x : k k j 1 j k k2 j jj 1 j k k2 j j j 1 j k k2 j jk k 3. Since is a norm and (cid:25) is linear, for each x;y R 3, we have that k k2 2 x+y = x +y + (cid:25)(x+y) = x +y + (cid:25)(x)+(cid:25)(y) k k j 1 1 j k k2 j 1 1 j k k2 x + (cid:25)(x) + y + (cid:25)(y) = x + y : (cid:20) j 1 j k k2 j 1 j k k2 k k k k The three properties prove that is a norm. (cid:4) k k'},
#    'Exercise 4': {'question': 'Consider R n endowed with the supnorm .1 Let T : R n R n be such that k k ! 1 T (x) T (y) x y x;y R n: (2) k (cid:0) k (cid:20) k (cid:0) k 8 2 1 1 1. If x R n and (cid:11) (0;1), prove that there exist two unique points in R n, x (cid:11) and x~ (cid:11) , such that 2 2 x = T ((1 (cid:11))x+(cid:11)x ) and x~ = (1 (cid:11))x+(cid:11)T (x~ ): (cid:11) (cid:11) (cid:11) (cid:11) (cid:0) (cid:0) 2. Prove that x~ = (1 (cid:11))x+(cid:11)x . (cid:11) (cid:11) (cid:0)',
#     'solution': 'De(cid:133)ne T (cid:11);x ;T~ (cid:11);x : R n R n by ! T (cid:11);x (y) = T ((1 (cid:11))x+(cid:11)y) and T~ (cid:11);x (y) = (1 (cid:11))x+(cid:11)T (y) y R n: (cid:0) (cid:0) 8 2 Note that x = T (x ) x = T ((1 (cid:11))x+(cid:11)x ) (cid:11) (cid:11);x (cid:11) (cid:11) (cid:11) () (cid:0) and x~ = T~ (x~ ) x~ = (1 (cid:11))x+(cid:11)T (x~ ): (cid:11) (cid:11);x (cid:11) (cid:11) (cid:11) () (cid:0) In other words, the points (x and x~ ) we are after are the (cid:133)xed points of the two operators T and (cid:11) (cid:11) (cid:11);x T~ , respectively. (cid:11);x 1. Since T satis(cid:133)es (2), we have that T (y) T (z) = T ((1 (cid:11))x+(cid:11)y) T ((1 (cid:11))x+(cid:11)z) (cid:11);x (cid:11);x k (cid:0) k k (cid:0) (cid:0) (cid:0) k 1 (1 (cid:11))x+(cid:11)y (1 (cid:11))x (cid:11)z = (cid:11) 1 y z y;z R n (cid:20) k (cid:0) (cid:0) (cid:0) (cid:0) k k (cid:0) k 8 2 1 1 and T~ (y) T~ (z) = (1 (cid:11))x+(cid:11)T (y) (1 (cid:11))x (cid:11)T (z) (cid:11);x (cid:11);x (cid:0) k (cid:0) (cid:0) (cid:0) (cid:0) k 1 (cid:13) (cid:13) (cid:13) (cid:13) 1 = (cid:11) T (y) T (z) (cid:11) y z y;z R n: (cid:13) (cid:13) k (cid:0) k 1 (cid:20) k (cid:0) k 1 8 2 Inotherwords,since(cid:11) (0;1),T andT~ are(cid:11)-contractions. BytheBanachContractionprinciple (cid:11);x (cid:11);x and since (R n; ) is 2 complete, this implies that T (cid:11);x and T~ (cid:11);x have each a unique (cid:133)xed point which k k we denote respect1ively x and x~ , that is, (cid:11) (cid:11) T ((1 (cid:11))x+(cid:11)x ) = T (x ) = x (cid:11) (cid:11);x (cid:11) (cid:11) (cid:0) and (1 (cid:11))x+(cid:11)T (x~ ) = T~ (x~ ) = x~ ; (cid:11) (cid:11);x (cid:11) (cid:11) (cid:0) proving that x and x~ exist and are unique. (cid:11) (cid:11) 2. Set x^ = (1 (cid:11))x+(cid:11)x . We have that (cid:11) (cid:11) (cid:0) x^ = (1 (cid:11))x+(cid:11)x = (1 (cid:11))x+(cid:11)T ((1 (cid:11))x+(cid:11)x ) = (1 (cid:11))x+(cid:11)T (x^ ) = T~ (x^ ); (cid:11) (cid:11) (cid:11) (cid:11) (cid:11);x (cid:11) (cid:0) (cid:0) (cid:0) (cid:0) proving that x^ is a (cid:133)xed point of T~ . Since this point is unique and is x~ . It follows that x~ = (cid:11) (cid:11);x (cid:11) (cid:11) x^ = (1 (cid:11))x+(cid:11)x , proving the equality (cf.'},
#    'Exercise 5': {'question': 'of the exams of September 2024, 2021, and (cid:11) (cid:11) (cid:0) 2019). (cid:4) 1Recall that k x k1 =max i 2f 1;:::;n gj x i j for all x 2 R n.'},
#    'Exercise 6': {'question': 'State and prove the Blackwell(cid:146)s theorem.',
#     'solution': 'See the lecture notes. (cid:4)'},
#    'Exercise 7': {'question': 'Consider the reduced form problem 1 max (cid:12)t(cid:30)(x ;x ) sub x (cid:0)(x ) t 0, x X given (RF) t t+1 t+1 t 0 x 2 8 (cid:21) 2 t=0 X 1. State and prove the Optimality Principle.',
#     'solution': 'See the lecture notes. (cid:4)'}}},
#  'Midterm_2024-10-24': {'type': 'Midterm',
#   'date': '2024-10-24',
#   'year': 2024,
#   'month': 10,
#   'day': 24,
#   'content': ['Advanced Mathematics (Cod. 20136)\nMidterm Exam (cid:150)October 24, 2024\nName and Last Name\nStudent ID Exam Code 20136\nRules of conduct during exams or other tests:\nI hereby undertake to respect the regulations described in the Honor Code and sign my presence at\nthe exam.\nSignature:\nExercise 1 Consider the vector space RR of real valued functions over the real line. For each (cid:13) R\n2\nde(cid:133)ne the function f (cid:13) : R ! R by f (cid:13) (x) = j x (cid:0) (cid:13) j for all x 2 R.1 De(cid:133)ne S = f f n gn N .\n2\n1. Is spanS = RR? Motivate your answer!\n2. Is S linearly independent? Motivate your answer!\n3. Is S a basis of RR? Motivate your answer!\nSolution See also extra page. 1. No, spanS = RR. In fact, consider f : R R de(cid:133)ned by\n6 !\nf(x) = x2 for all x R. By contradiction, assume that f spanS. It follows that there exist\nf f nig k i=1 (cid:18) S and f (cid:11) i g 2k i=1 (cid:18) R such that f = k i=1 (cid:11) i f ni . It fol 2 lows that\nk P k\nx2 = f(x) = (cid:11)\ni\nf\nni\n(x) = (cid:11)\ni\nj\nx\n(cid:0)\nn\ni\nj 8\nx\n2\nR:\ni=1 i=1\nX X\ndef\nBy passing to the limit, if we consider x > n(cid:22) = max n : i 1;:::;k , then we have that\ni\nf 2 f gg\nk k k\nn\nx2 = (cid:11)\ni\n(x n\ni\n) x > n(cid:22) = x = (cid:11)\ni\n1 i x > n(cid:22) = = (cid:11)\ni\nR;\n(cid:0) 8 ) (cid:0) x 8 ) 1 2\nX i=1 X i=1 (cid:16) (cid:17) X i=1\na contradiction.\n2. Yes, S is linearly independent! De(cid:133)ne S = f n . We are (cid:133)rst going to show that S is\nn f i gi=1 n\nlinearly independent for all n N. We proceed by induction.\n2\nInitial step. n = 1. We need to show that (cid:11) f = 0 implies that (cid:11) = 0, that is, (cid:11) f (x) = 0 for all\n1 1 1 1 1\nx R implies that (cid:11) 1 = 0. If we consider x(cid:22) = 2, then we have that\n2\n(cid:11) f = 0 = (cid:11) = (cid:11) f (x(cid:22)) = 0;\n1 1 1 1 1\n)\nproving the statement.\n1In other words, f is such that\n(cid:13)\nx (cid:13) if x (cid:13)\nf (cid:13) (x)= (cid:13) (cid:0) x if x< (cid:21) (cid:13) 8 x 2 R:\n(cid:26) (cid:0)',
# ...
#     'solution': '. See the lecture notes. !'},
#    'Exercise 2': {'question': 'Consider a metric space (X;d). 1. Give the deÖnition of compact set. 2. Assume that X =R and d is the discrete metric, that is, 1 if x=y d(x;y)= 6 x;y R: 0 if x=y 8 2 ! Is X closed and bounded? Is X compact?',
#     'solution': '. 1. See the lecture notes. 2. Since X and the empty set are always open, X, being the complement of the empty set, is closed. Sinced(0;x) 1forallx R,X isalsobounded. Nevertheless,X isnotcompact. Underthe % 2 discretemetric,singletonsareopensets. Itfollowsthat x isanopencoverforX,but,clearly, w co e nt c r a a n d n i o ct t io s n el . ect a Önite subcover for X out of ff x ggx 2 f R f , g o g th x 2er R wise X = R itself would be Önite, ! a'},
#    'Exercise 3': {'question': 'Consider R 3. Let L 1 ;L 2 :R 3 R be the linear functionals deÖned by ! L 1 (x)=x 1 +x 2 x R 3 8 2 and L 2 (x)=x 2 +x 3 x R 3: 8 2 1. Give the deÖnition of norm. 2. DeÖne p:R 3 R by ! p(x)= max L i (x) x R 3: i 1;2 j j 8 2 2f g Show that p satisÖes all the properties of a norm but one.',
#     'solution': '. 1. See the lecture notes. 2. We prove that p satisÖes just two of the three properties deÖning a norm. a) Since L and L are linear, L and L are additive. Thus, we can conclude that 1 2 1 2 p(x+y) = max L (x+y) = max L (x)+L (y) i i i i 1;2 j j i 1;2 j j 2f g 2f g max [L (x) + L (y)] max L (x) + max L (y) i i i i % i 1;2 j j j j %i 1;2 j j i 1;2 j j 2f g 2f g 2f g = p(x)+p(y) x;y R 3; 8 2 that is, p is subadditive. b) Since L and L are linear, L and L are homogeneous. Thus, we can also conclude that 1 2 1 2 p(+x) = max L (+x) = max +L (x) = max + L (x) i i i i 1;2 j j i 1;2 j j i 1;2 j jj j 2f g 2f g 2f g = + max L i (x) = + p(x) x R 3; + R; j ji 1;2 j j j j 8 2 8 2 2f g that is, p has the same properties of homogeneity of a norm. c) Finally, notice that x- = (1; 1;1) = 0 is such that L (x-) = 0 = L (x-). We thus have that 1 2 ) 6 p(x-)=0 and x- =0. On the other hand, if p were to be a norm we would have that p(x)=0 if and 6 only if x=0. !'},
#    'Exercise 4': {'question': 'This exercise has two parts. 1. For the autonomous di§erence equation: x =f(x ) t+1 t state the stability criterion by linearization for an equilibrium point. 2. Consider ax t x t+1 = 1+x2 ; a 2 R; a 6 =0: t (a) With respect to the parameter a; determine the equilibria and study their nature. (b) Fora=1;representthegeneratrixfunctionandthephasediagramtovisualizethestairstep behavior of some signiÖcative orbit.'},
#    'Exercise 5': {'question': 'Consider R 3 endowed with the norm k+k1 .1 1. Give the deÖnition of contraction for a map T :R 3 R 3. ! 2. Consider T :R 3 R 3 deÖned by ! T(x)=(x 3 ;x 2 ;x 1 ) x R 3: 8 2 (a) Show that T is linear. (b) DeÖne when x- R 3 is a Öxed point for T. 2 (c) Is T a contraction? (d) Does T have a Öxed point? Is it unique? (e) DeÖne L= x- R 3 :x- is a Öxed point for T . Is L a vector subspace of R 3? 2',
#     'solution': '. DeÖne d(x; " y)= k x ) y k1 for all x;y 2 R 3. # 1. See the lecture notes. 0 0 1 2.a DeÖne the 3 3 matrix A = 0 1 0 . It is immediate to see that T(x) = Ax for all , 0 1 1 0 0 x R 3. By Rieszís representation theo@rem, it folloAws that T is linear. 2 2. b. x- is a Öxed point for T if and only if T(x-)=x-. 2. c. No, it is not. In fact, we have that k T(x) k1 = k x k1 for all x 2 R 3. 2. d. BydeÖnitionofT, allvectorsoftheformx=(k;k;k)withk inRareÖxedpoints. Forsuch a reason, T has inÖnitely many Öxed points. 2.e. Yes, it is. In fact, pick x- 1 ;x- 2 L and + 1 ;+ 2 R. Since T is a linear map and T(x- i )=x- i for 2 2 i 1;2 , it follows that 2f g T(+ x- ++ x- )=+ T(x- )++ T(x- )=+ x- ++ x- ; 1 1 2 2 1 1 2 2 1 1 2 2 proving that, + 1 x- 1 ++ 2 x- 2 L. ! 2 1Recallthat k x k1 = j x1 j + j x2 j + j x3 j 8 x 2 R 3:'},
#    'Exercise 6': {'question': 'Consider the reduced form problem max 1 0t1(x ;x ) sub x 3(x ) t 0, x X given (RF) t t+1 t+1 t 0 x 2 8 - 2 t=0 X 1. DeÖne its value function and write its Bellman equation. 2. State and prove the Bellman Theorem and discuss its importance.',
#     'solution': '. See the lecture notes. !'}}},
#  'General_2013-02-01': {'type': 'General',
#   'date': '2013-02-01',
#   'year': 2013,
#   'month': 2,
#   'day': 1,
#   'content': ['Advanced Mathematics (Cod. 20136)\nGeneral Exam ñ February 1, 2013\nSurname Student ID\nName Exam Code\nRules of conduct during exams or other tests:\nIherebyundertaketorespecttheregulationsdescribedintheHonorCode andundersignmypresence\nat the exam.\nSignature:\nExercise 1 Consider a function f :R n R.\n!\n1. State and prove the Riesz representation theorem (that is, the theorem that provides a charac-\nterization for linear functionals).\nSolution. See the lecture notes. !',
#    'Exercise 2 Consider a metric space (X;d).\n1. Give the deÖnition of open set.\n2. Consider x X and ">0. DeÖne\n2\nS = y X :d(y;x)>" :\nf 2 g\nProve that the set S is open.\nSolution. 1. See the lecture notes.\n2. If S is empty then there is nothing to prove. Otherwise, consider y& S. DeÖne + =d(y&;x) ".\n2 %\nIt is immediate to see that + > 0. Next, consider z B (y&), that is, z X such that d(z;y&) < +.\n"\n2 2\nSince d is a distance function, it follows that d(y&;x) d(y&;z)+d(z;x). This yields that\n&\nd(z;x) d(y&;x) d(y&;z)>d(y&;x) + =d(y&;x) d(y&;x)+"=";\n\' % % %\nproving that z S. Since zwas chosen to be generic, we can conclude that B (y&) S, proving that\n"\n2 (\ny&is an interior point. Since y&was chosen to be generic, it follows that S is open. !',
#    'Exercise 3 Consider R 3.\n1. Give the deÖnition of norm.\n2. DeÖne f :R 3 R by\n! f(x)= x 1 + x 2 x R 3:\nj j j j 8 2\nProve that f satisÖes just two of the three properties that characterize a norm.\nSolution. 1. See the lecture notes.\n2. Notice that for each / R and for each x R 3\n2 2\nf(/x)= /x + /x = / (x + x )= / f(x):\n1 2 1 2\nj j j j j j j j j j j j\nFor each x;y R 3, we have that\n2\nf(x+y)= x +y + x +y (x + x )+(y + y )=f(x)+f(y):\n1 1 2 2 1 2 1 2\nj j j j& j j j j j j j j\nThus, f satisÖes at least two of the three properties that deÖne a norm. At the same time, we have\nthat there exists a vector x = 0 such that f(x) = 0, for example, (0;0;1), proving that f does not\n6\nsatisfy all the three properties which deÖne a norm. !',
#    "Exercise 4 This exercise has two parts.\n1. Consider the linear system:\nx_ =ax+by\ny_ =cx+dy:\n!\nWith respect to the coe¢cients a;b;c;d R how many equilibria it has? Give a formula for the\n2\ngeneral solution in the case of real and distinct eigenvalues associated to the coe¢cient matrix.\n2. Consider the non linear system\nx_ =x y\n%\n8 2x\n>< y_ =\n1+x2 %\ny:\n(a) Draw the phase portrait, where\n>:you\ndetermine, in particular, the equilibria, the vertical-\nand horizontal-slope isoclines and the orientation of the trajectories. Are rotations allowed\nin the neighborhood of equilibria?\n(b) Check that the origin is a critical point; can the linearization criterion be used in order to\ndetermine its stability?\nSolution. 1. If ad bc = 0 the system has one single equilibrium (the origin) else the system\n% 6\nhas inÖnite equilibria, along one straight line (that is the eigenvector associated with the zero eigen-\nvalue). Assuming thet 3 and 3 are real and distinct eigenvalues and h and h the corresponding\n1 2 1 2\neigenvectors, the general solution is\nx(t)\n=c e#1th +c e#2th\ny(t) 1 1 2 2\n& '\nwhere c\n1\n;c\n2\nR.\n2\n2. a. The equilibria solve the algebraic system\nx y =0\n%\n8 2x\n><\n1+x2 %\ny =0;\nthey are P = (0;0), P = (1;1) and P\n>:=\n( 1; 1). The vertical-slope isocline is the straight line\n1 2 3\n% % 2x\ny = x (represented in red in the Ögure below) the horizontal-slope isocline is the curve y =\n1+x2\n(representedinblue)ThepathsorientationisshownintheÖgure. AmongthethreeequilibriaP , P ,\n1 2\nP rotations are allowed just around P .\n3 1\n2. b. We have already seen that the origin is one of the equilibria of the system. The jacobian\nmatrix is\n1 1\n%\nJ(x;y)= 2 1 x2 :\n2 % 1 3\n(1+x2)2 %\n* +\n4 5\n1 1\nSince J(0;0) = 2 % 1 has eigenvalues 3 1 = % i and 3 2 = i; hence the origin of the linearized\n& % '\nsystem is a center. On the other hand, the origin of the original system can be either a center or a\nfocus (anyway rotations are compatible with the nature of this equilibrium point). The linearization\ncriterion is not conclusive in this case. !",
#    '1. (a)\n1\n0.8\n0.6\n0.4\n0.2\n0\n-0.2\n-0.4\n-0.6\n-0.8\n-1\n-3 -2 -1 0 1 2 3\nExercise 5 Consider the space B(X) of bounded functions over a set X.\n1. State (without proof) the Blackwell Theorem.\n2. Given a function 8 : X X R such that 8(x;y) < 1 for all x;y X and a function\n, ! j j 2\n9 :X R such that 0<9(x)<1=2 for all x X, consider the operator T :B(X) B(X),\n! 2 !\ndeÖned by\nT(v)(x)= sup 8(x;y)+9(y)v(y) x X: (1)\nf g 8 2\ny X\n2\n(a) DeÖne when v& B(X) is a Öxed point for T.\n2\n(b) Is T is a contraction?\n(c) Does T have a Öxed point? Is it unique?\nSolution. Observe that B(X) is endowed with the supnorm.\n1. See the lecture notes.\n2. a. v& is a Öxed point for T if and only if T(v&)=v&.\n2. b. Observe that:\n(i). Since 9 is positive, if v w then for each x X\n& 2\n8(x;y)+9(y)v(y) 8(x;y)+9(y)w(y) y X:\n& 8 2\nThis implies that for each x X\n2\nT(v)(x) = sup 8(x;y)+9(y)v(y)\nf g\ny X\n2\nsup 8(x;y)+9(y)w(y)\n& f g\ny X\n2\n= T(w)(x);\nproving that if v w then T(v) T(w).\n& &\n(ii). If v B(X) and c R+ then\n2 2\nT(v+c)(x) = sup 8(x;y)+9(y)(v(y)+c)\nf g\ny X\n2\n1\nsup 8(x;y)+9(y)v(y)+ c\n& 2\ny 2 X! .\n1\nsup 8(x;y)+9(y)v(y) + c\n& f g 2\ny X\n2\n1\n= T(v)(x)+ c;\n2',
#    'proving that T(v+c) T(v)+ 1c.\nBy points (i) and (i & i) and the 2 Blackwell Theorem, T is a 1-contraction.\n2\n2. c. By the Banach Contraction Principle and since B(X), endowed with the distance induced\nby the supnorm, is a complete metric space and T is a contraction, it follows that T admits a unique\nÖxed point. !',
#    "Exercise 6 Consider the reduced form problem\nmax 1 9t8(x ;x ) sub x 3(x ) t 0, x X given (RF)\nt t+1 t+1 t 0\nx 2 8 ' 2\nt=0\nX\n1. State and prove the Optimality Principle. Discuss its importance.\n2. DeÖnetheoptimalpolicycorrespondenceandtheoptimalpolicyfunction. Discussitsimportance.\nSolution. See the lecture notes. !"],
#   'questions': {'Exercise 1': {'question': 'Consider a function f :R n R. ! 1. State and prove the Riesz representation theorem (that is, the theorem that provides a charac- terization for linear functionals).',
#     'solution': '. See the lecture notes. !'},
#    'Exercise 2': {'question': 'Consider a metric space (X;d). 1. Give the deÖnition of open set. 2. Consider x X and ">0. DeÖne 2 S = y X :d(y;x)>" : f 2 g Prove that the set S is open.',
#     'solution': '. 1. See the lecture notes. 2. If S is empty then there is nothing to prove. Otherwise, consider y& S. DeÖne + =d(y&;x) ". 2 % It is immediate to see that + > 0. Next, consider z B (y&), that is, z X such that d(z;y&) < +. " 2 2 Since d is a distance function, it follows that d(y&;x) d(y&;z)+d(z;x). This yields that & d(z;x) d(y&;x) d(y&;z)>d(y&;x) + =d(y&;x) d(y&;x)+"="; \' % % % proving that z S. Since zwas chosen to be generic, we can conclude that B (y&) S, proving that " 2 ( y&is an interior point. Since y&was chosen to be generic, it follows that S is open. !'},
#    'Exercise 3': {'question': 'Consider R 3. 1. Give the deÖnition of norm. 2. DeÖne f :R 3 R by ! f(x)= x 1 + x 2 x R 3: j j j j 8 2 Prove that f satisÖes just two of the three properties that characterize a norm.',
#     'solution': '. 1. See the lecture notes. 2. Notice that for each / R and for each x R 3 2 2 f(/x)= /x + /x = / (x + x )= / f(x): 1 2 1 2 j j j j j j j j j j j j For each x;y R 3, we have that 2 f(x+y)= x +y + x +y (x + x )+(y + y )=f(x)+f(y): 1 1 2 2 1 2 1 2 j j j j& j j j j j j j j Thus, f satisÖes at least two of the three properties that deÖne a norm. At the same time, we have that there exists a vector x = 0 such that f(x) = 0, for example, (0;0;1), proving that f does not 6 satisfy all the three properties which deÖne a norm. !'},
#    'Exercise 4': {'question': 'This exercise has two parts. 1. Consider the linear system: x_ =ax+by y_ =cx+dy: ! With respect to the coe¢cients a;b;c;d R how many equilibria it has? Give a formula for the 2 general solution in the case of real and distinct eigenvalues associated to the coe¢cient matrix. 2. Consider the non linear system x_ =x y % 8 2x >< y_ = 1+x2 % y: (a) Draw the phase portrait, where >:you determine, in particular, the equilibria, the vertical- and horizontal-slope isoclines and the orientation of the trajectories. Are rotations allowed in the neighborhood of equilibria? (b) Check that the origin is a critical point; can the linearization criterion be used in order to determine its stability?',
#     'solution': ". 1. If ad bc = 0 the system has one single equilibrium (the origin) else the system % 6 has inÖnite equilibria, along one straight line (that is the eigenvector associated with the zero eigen- value). Assuming thet 3 and 3 are real and distinct eigenvalues and h and h the corresponding 1 2 1 2 eigenvectors, the general solution is x(t) =c e#1th +c e#2th y(t) 1 1 2 2 & ' where c 1 ;c 2 R. 2 2. a. The equilibria solve the algebraic system x y =0 % 8 2x >< 1+x2 % y =0; they are P = (0;0), P = (1;1) and P >:= ( 1; 1). The vertical-slope isocline is the straight line 1 2 3 % % 2x y = x (represented in red in the Ögure below) the horizontal-slope isocline is the curve y = 1+x2 (representedinblue)ThepathsorientationisshownintheÖgure. AmongthethreeequilibriaP , P , 1 2 P rotations are allowed just around P . 3 1 2. b. We have already seen that the origin is one of the equilibria of the system. The jacobian matrix is 1 1 % J(x;y)= 2 1 x2 : 2 % 1 3 (1+x2)2 % * + 4 5 1 1 Since J(0;0) = 2 % 1 has eigenvalues 3 1 = % i and 3 2 = i; hence the origin of the linearized & % ' system is a center. On the other hand, the origin of the original system can be either a center or a focus (anyway rotations are compatible with the nature of this equilibrium point). The linearization criterion is not conclusive in this case. ! 1. (a) 1 0.8 0.6 0.4 0.2 0 -0.2 -0.4 -0.6 -0.8 -1 -3 -2 -1 0 1 2 3"},
#    'Exercise 5': {'question': 'Consider the space B(X) of bounded functions over a set X. 1. State (without proof) the Blackwell Theorem. 2. Given a function 8 : X X R such that 8(x;y) < 1 for all x;y X and a function , ! j j 2 9 :X R such that 0<9(x)<1=2 for all x X, consider the operator T :B(X) B(X), ! 2 ! deÖned by T(v)(x)= sup 8(x;y)+9(y)v(y) x X: (1) f g 8 2 y X 2 (a) DeÖne when v& B(X) is a Öxed point for T. 2 (b) Is T is a contraction? (c) Does T have a Öxed point? Is it unique?',
#     'solution': '. Observe that B(X) is endowed with the supnorm. 1. See the lecture notes. 2. a. v& is a Öxed point for T if and only if T(v&)=v&. 2. b. Observe that: (i). Since 9 is positive, if v w then for each x X & 2 8(x;y)+9(y)v(y) 8(x;y)+9(y)w(y) y X: & 8 2 This implies that for each x X 2 T(v)(x) = sup 8(x;y)+9(y)v(y) f g y X 2 sup 8(x;y)+9(y)w(y) & f g y X 2 = T(w)(x); proving that if v w then T(v) T(w). & & (ii). If v B(X) and c R+ then 2 2 T(v+c)(x) = sup 8(x;y)+9(y)(v(y)+c) f g y X 2 1 sup 8(x;y)+9(y)v(y)+ c & 2 y 2 X! . 1 sup 8(x;y)+9(y)v(y) + c & f g 2 y X 2 1 = T(v)(x)+ c; 2 proving that T(v+c) T(v)+ 1c. By points (i) and (i & i) and the 2 Blackwell Theorem, T is a 1-contraction. 2 2. c. By the Banach Contraction Principle and since B(X), endowed with the distance induced by the supnorm, is a complete metric space and T is a contraction, it follows that T admits a unique Öxed point. !'},
#    'Exercise 6': {'question': "Consider the reduced form problem max 1 9t8(x ;x ) sub x 3(x ) t 0, x X given (RF) t t+1 t+1 t 0 x 2 8 ' 2 t=0 X 1. State and prove the Optimality Principle. Discuss its importance. 2. DeÖnetheoptimalpolicycorrespondenceandtheoptimalpolicyfunction. Discussitsimportance.",
#     'solution': '. See the lecture notes. !'}}}}

# %%
len(classified_exams['General_2025-08-29']['questions'])
# Out:
# 6

# %%
final_exams = {}

# %%
for exam in classified_exams.keys():
    if len(classified_exams[exam]['questions']) <= 6 :
        final_exams[exam] = {
            'type': classified_exams[exam]['type'],
            'date': classified_exams[exam]['date'],
            'year': classified_exams[exam]['year'],
            'questions': classified_exams[exam]['questions']
        }

# %%
# Save the classified exams to a JSON file
output_path = os.path.join(main, 'data', 'processed', 'classified_exams.json')

# Create the processed directory if it doesn't exist
os.makedirs(os.path.dirname(output_path), exist_ok=True)

# Save to JSON with proper formatting and UTF-8 encoding
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(final_exams, f, ensure_ascii=False, indent=4)

print(f"Saved classified exams to: {output_path}")
# Out:
# Saved classified exams to: d:\ESS\ocr_math_q\data\processed\classified_exams.json

# %%
with open(main + '\\data\\processed\\classified_exams.json', 'r', encoding='utf-8') as f:
    final_exams = json.load(f)

# %% [markdown]
# # data frame

# %%
# 1) Flatten your dict -> rows: one per Exercise
import re, pandas as pd
from datetime import datetime

exams = final_exams  # <-- put your dict variable here

def clean_text(s:str) -> str:
    if not s: return ""
    s = re.sub(r"\(cid:\d+\)", " ", s)     # drop cid artifacts
    s = s.replace(" (cid:150) ", " - ")    # just in case
    s = re.sub(r"\s+", " ", s).strip()
    return s

rows = []
for exam_key, meta in exams.items():
    etype = meta.get("type")
    date_str = meta.get("date")            # looks like 'YYYY-MM-DD'
    dt = None
    try:
        dt = datetime.strptime(date_str, "%Y-%m-%d")
    except Exception:
        dt = None
    for qid, qa in meta.get("questions", {}).items():
        rows.append({
            "exam_id": exam_key,
            "exam_type": etype,
            "date": date_str,
            "year": meta.get("year"),
            "month": dt.month if dt else None,
            "day": dt.day if dt else None,
            "exercise_id": qid,
            "question": clean_text(qa.get("question","")),
            "solution": clean_text(qa.get("solution","")),
        })

df = pd.DataFrame(rows).sort_values(["date","exam_type","exercise_id"]).reset_index(drop=True)
df.head()
# Out:
#               exam_id exam_type        date  year  month  day exercise_id  \
# 0  General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 1
# 1  General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 2
# 2  General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 3
# 3  General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 4
# 4  General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 5
#
#                                             question  \
# 0  Consider a vector space V and a subset W of V....
# 1  Consider a metric space (X;d). 1. Give the deÖ...
# 2  Consider a metric space (X;d) where X has at l...
# 3  This exercise has two parts. 1. Referring to t...
# 4               State and prove Blackwellís theorem.
#
#                                             solution
# 0  . Before starting recall that spanW is the sma...
# 1                         . See the lecture notes. !
# 2  . 1. See the lecture notes. 2. SinceX contains...
# 3  1. (a) The steady state p =(x ;y ) such that f...
# 4                         . See the lecture notes. !

# %%
df
# Out:
#                 exam_id exam_type        date  year  month  day exercise_id  \
# 0    General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 1
# 1    General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 2
# 2    General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 3
# 3    General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 4
# 4    General_2013-01-31   General  2013-01-31  2013      1   31  Exercise 5
# ..                  ...       ...         ...   ...    ...  ...         ...
# 190  General_2025-08-29   General  2025-08-29  2025      8   29  Exercise 2
# 191  General_2025-08-29   General  2025-08-29  2025      8   29  Exercise 3
# 192  General_2025-08-29   General  2025-08-29  2025      8   29  Exercise 4
# 193  General_2025-08-29   General  2025-08-29  2025      8   29  Exercise 5
# 194  General_2025-08-29   General  2025-08-29  2025      8   29  Exercise 6
#
#                                               question  \
# 0    Consider a vector space V and a subset W of V....
# 1    Consider a metric space (X;d). 1. Give the deÖ...
# 2    Consider a metric space (X;d) where X has at l...
# 3    This exercise has two parts. 1. Referring to t...
# 4                 State and prove Blackwellís theorem.
# ..                                                 ...
# 190  Consider R n endowed with the d 1 distance.1 C...
# 191  Prove that a linear operator T : V V between n...
# 192  Consider R n endowed with the supnorm .3 We sa...
# 193  Consider a metric space (X;d) and a continuous...
# 194  Consider the reduced form problem 1 max t (x ;...
#
#                                               solution
# 0    . Before starting recall that spanW is the sma...
# 1                           . See the lecture notes. !
# 2    . 1. See the lecture notes. 2. SinceX contains...
# 3    1. (a) The steady state p =(x ;y ) such that f...
# 4                           . See the lecture notes. !
# ..                                                 ...
# 190  . 1. If intC = , then trivially we have that i...
# 191                             See the lecture notes.
# 192  1. By the Banach contraction principle and sin...
# 193  No! ConsiderX = Nendowedwiththediscretedistanc...
# 194                             See the lecture notes.
#
# [195 rows x 9 columns]

# %% [markdown]
# # tagging

# %%
pip install 'git+https://github.com/facebookresearch/detectron2.git@a59f05630a8f205756064244bf5beb8661f96180'
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: "'git+https://github.com/facebookresearch/detectron2.git@a59f05630a8f205756064244bf5beb8661f96180'"
#
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pip install scikit-learn pandas numpy scipy
import re, numpy as np, pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from scipy.sparse import hstack

# df must have a 'question' column from your previous step
# df = ...

def clean(s):
    if not s: return ""
    s = re.sub(r"\(cid:\d+\)", " ", s)
    s = re.sub(r"\s+", " ", s)
    return s.strip().lower()

df["q_clean"] = df["question"].map(clean)

# Your topics + a few seed phrases each (edit freely)
topic_seeds = {
    "vector_spaces": [
        "vector space, basis, dimension, linear independence, subspace, span"
    ],
    "linear_functionals_and_operators": [
        "linear functional, bounded operator, operator norm, riesz representation"
    ],
    "isomorphisms": [
        "linear isomorphism, invertible linear map, isomorphic vector spaces"
    ],
    "finance_illustration": [
        "present value, discount factor, asset pricing, arbitrage, consumption savings"
    ],
    "metric_spaces": [
        "metric space, open set, closed set, cauchy sequence, convergence"
    ],
    "normed_vector_spaces": [
        "normed vector space, norm equivalence, banach space, complete norm"
    ],
    "abstract_equations": [
        "abstract equation, operator equation, functional equation, fixed point equation"
    ],
    "banach_contraction_theorem": [
        "banach contraction theorem, contraction mapping, unique fixed point, complete metric space"
    ],
    "brouwer_fixed_point_theorem": [
        "brouwer fixed point theorem, continuous map on compact convex set, fixed point exists"
    ],
    "optimization": [
        "optimization problem, argmax, argmin, lagrangian, first order conditions"
    ],
    "convexity_and_concavity": [
        "convex function, concavity, jensen inequality, subgradient, convex set"
    ],
    "dynamic_optimization": [
        "bellman equation, dynamic programming, value function, optimal policy, intertemporal"
    ],
}

topics = list(topic_seeds.keys())
topic_docs = [clean(" ; ".join(v)) for v in topic_seeds.values()]

# --- Vectorization: words (1–2 grams) + characters (3–5) for robustness to math/typos ---
word_vec = TfidfVectorizer(ngram_range=(1,2), min_df=1)
char_vec = TfidfVectorizer(analyzer="char_wb", ngram_range=(3,5), min_df=1)

corpus = df["q_clean"].tolist() + topic_docs
word_vec.fit(corpus)
char_vec.fit(corpus)

Xq = hstack([
    word_vec.transform(df["q_clean"]),
    char_vec.transform(df["q_clean"])
])
Xt = hstack([
    word_vec.transform(topic_docs),
    char_vec.transform(topic_docs)
])

# cosine via normalized dot product
Xq = normalize(Xq)
Xt = normalize(Xt)
S = Xq @ Xt.T  # (num_questions, num_topics)

best = np.asarray(S.argmax(axis=1)).ravel()
conf = np.asarray(S.max(axis=1)).ravel()

df["topic_pred"]  = [topics[i] for i in best]
#df["topic_score"] = conf

# Optional: mark low confidence as 'uncertain' and keep top-2 for review
#THRESH = 0.28
#df.loc[df["topic_score"] < THRESH, "topic_pred"] = "uncertain"

top2 = np.argsort(-S.A, axis=1)[:, :2]
df["topic_top2"] = [[topics[i0], topics[i1]] for i0, i1 in top2]

#df[["exercise_id","topic_pred","topic_score","topic_top2"]].head()

# %%
df.to_parquet(main + '\\data\\processed\\exams_flattened.parquet', index=False)
